# %% [markdown]
# <h1 style="font-family: 'Times New Roman'; text-align: center; font-weight: bold;">
#     CoxL BLAST Output Preprocessing
# </h1>

# %% [markdown]
# <div style="font-family: 'Times New Roman'; font-size: 15px; text-align: justify; width: 100%;">
#   <div>
#     <span style="display: inline-block; width: 100px;"><b>Date</b></span>: 15<sup>th</sup> November 2024
#   </div>
#   <div>
#     <span style="display: inline-block; width: 100px;"><b>Author</b></span>: Deepan Kanagarajan Babu
#   </div>
#   <div>
#     <span style="display: inline-block; width: 100px;"><b>Description</b></span>: In this document, the BLAST-X outputs are analysed. The coxL gene carriers are shortlised and their genes are fetched for further analysis.
#   </div>
# </div>

# %% [markdown]
# <h2 style="font-family: 'Times New Roman'; font-weight: bold;">
#     Required Libraries
# </h2>

# %%
# importing necessary libraries
import os
import pandas as pd
import numpy as np
from Bio import SeqIO
from Bio.SeqRecord import SeqRecord
from Bio.Seq import Seq

# %% [markdown]
# <h2 style="font-family: 'Times New Roman'; font-weight: bold;">
#     Required Functions
# </h2>

# %%
# Defining single function to open multiple file formats (.csv, .txt, .fasta or .fastq (to display only 1st 100 lines), and .xlsx)
def open_file(file_path):
    if file_path.endswith('.csv'):
        # Read CSV file
        data = pd.read_csv(file_path)
        return data
    elif file_path.endswith('.txt'):
        # Read TXT file
        try:
            with open(file_path, 'r') as file:
                data = file.read()
            return data
        except FileNotFoundError:
            raise FileNotFoundError(f"The file {file_path} does not exist.")
    elif file_path.endswith(('.fasta', '.fastq')):
        # Read FASTA or FASTQ file
        try:
            with open(file_path, 'r') as file:
                data = []
                for _ in range(100):
                    line = file.readline()
                    if not line:
                        break
                    data.append(line.strip())
            return data
        except FileNotFoundError:
            raise FileNotFoundError(f"The file {file_path} does not exist.")
    elif file_path.endswith('.xlsx'):
        # Read XLSX file
        try:
            data = pd.read_excel(file_path)
            return data
        except FileNotFoundError:
            raise FileNotFoundError(f"The file {file_path} does not exist.")
    else:
        raise ValueError("Unsupported file format")

# %%
# Function to find and remove empty CSV, FASTA, and words files
def empty_files(directory):
    empty_files = []

    # Iterate over each file in the directory
    for filename in os.listdir(directory):
        if filename.endswith('.csv') or filename.endswith('.docs') or filename.endswith('.fasta'):
            file_path = os.path.join(directory, filename)
            # Check if the file is empty
            if os.path.getsize(file_path) == 0:
                empty_files.append(file_path)
                os.remove(file_path)
            elif filename.endswith('.csv'):
                # Read the CSV file into a dataframe
                df = pd.read_csv(file_path)
                # Check if the dataframe is empty
                if df.empty:
                    empty_files.append(file_path)
                    os.remove(file_path)
    print(f'Done {directory}')

# %%
# Function to concate CSV files
def concatenate_csv(input_directory, output_file_path):
    # List to hold dataframes
    dataframes = []

    # Iterate over each CSV file in the directory
    for csv_filename in os.listdir(input_directory):
        if csv_filename.endswith('.csv'):
            csv_file_path = os.path.join(input_directory, csv_filename)
            # Read the CSV file into a dataframe
            df = pd.read_csv(csv_file_path)
            # Add a new column with the input file name
            df['source_file'] = csv_filename
            # Append the dataframe to the list
            dataframes.append(df)

    # Concatenate all dataframes
    concatenated_df = pd.concat(dataframes, ignore_index=True)

    # Save the concatenated dataframe to a new CSV file
    concatenated_df.to_csv(output_file_path, index=False)
    # Leave a confirmation
    print(f"{output_file_path} Successful")

# %%
# Function to extract genes from genome when start and end and sequence header are provided
def fetch_genes(df, target_folder, output_folder):
    for target_file in df['target_file'].unique():
        target_df = df[df['target_file'] == target_file]
        target_path = os.path.join(target_folder, target_file)
        
        # Read the genome sequences from the target file
        genome_seqs = {record.id: str(record.seq) for record in SeqIO.parse(target_path, "fasta")}
        
        output_records = []
        query_index = 1  # Initialize query index for each target file
        
        for _, row in target_df.iterrows():
            qseqid = row['qseqid']
            qstart = row['qstart']
            qend = row['qend']
            sseqid = row['sseqid']
            
            # Check if the genome sequence was found
            genome_seq = genome_seqs.get(qseqid, "")
            if not genome_seq:
                print(f"Sequence with ID {qseqid} not found in {target_file}")
                continue
            
            # Extract the gene sequence based on qstart and qend
            if qstart > len(genome_seq) or qend > len(genome_seq):
                print(f"Invalid positions for {qseqid} in {target_file}: qstart={qstart}, qend={qend}, length={len(genome_seq)}")
                continue
            
            if qend < qstart:
                gene_seq = genome_seq[qend-1:qstart][::-1]  # Reverse the sequence
            else:
                gene_seq = genome_seq[qstart-1:qend]
            
            # Check if the extracted gene sequence is empty
            if not gene_seq:
                print(f"Empty gene sequence for {qseqid} in {target_file}: qstart={qstart}, qend={qend}")
                continue
            
            # Create a new sequence record with modified header and description
            seq_record = SeqRecord(
                Seq(gene_seq), 
                id=f"{qseqid} Query{query_index} qstart:{qstart} qend:{qend}", 
                description=sseqid
            )
            output_records.append(seq_record)
            query_index += 1  # Increment query index
        
        # Save all sequence records to a single .fasta file in the output folder
        output_file = os.path.join(output_folder, target_file)
        SeqIO.write(output_records, output_file, "fasta")
        print(f"Saved {output_file}")

# %% [markdown]
# <h2 style="font-family: 'Times New Roman'; font-weight: bold;">
#     Required Directories Path
# </h2>

# %%
# Specify the input folder paths
## Path to Metagenomic Assembled Genomes
mags = 'MAG'

## Form 1 CoxL BLAST results
### CSV Output folder
coxl1_csv_results = "CoxL1_Results/csv"

### Words Output folder
coxl1_docs_results = "CoxL1_Results/docs"

### FASTA Output folder
coxl1_fasta_results = "CoxL1_Results/fasta"

## Form 2 CoxL BLAST results
### CSV Output folder
coxl2_csv_results = "CoxL2_Results/csv"

### Words Output folder
coxl2_docs_results = "CoxL2_Results/docs"

### FASTA Output folder
coxl2_fasta_results = "CoxL2_Results/fasta"

# Output Directories
## Directory to store concatenated BLAST CSV for MOTIF form 1
motif_1_csv = "CoxL1_Results/MOTIF"
## Ensure the output directory exists
os.makedirs(motif_1_csv, exist_ok=True)

## File Path to store concatenated BLAST CSV for MOTIF form 1
motif_1_csv_file_path = "CoxL1_Results/MOTIF/coxl1_csv.csv"

## Directory to store concatenated BLAST CSV for MOTIF form 2
motif_2_csv_file_path = "CoxL2_Results/MOTIF"
## Ensure the output directory exists
os.makedirs(motif_2_csv_file_path, exist_ok=True)

## File Path to store concatenated BLAST CSV for MOTIF form 2
motif_2_csv_file_path = "CoxL2_Results/MOTIF/coxl2_csv.csv"

## Directory to store unaligned sequences for MOTIF form 1
motif_1_fasta_path = "CoxL1_Results/MOTIF/fasta"
## Ensure the output directory exists
os.makedirs(motif_1_fasta_path, exist_ok=True)

## Directory to store unaligned sequences for MOTIF form 2
motif_2_fasta_path = "CoxL2_Results/MOTIF/fasta"
## Ensure the output directory exists
os.makedirs(motif_2_fasta_path, exist_ok=True)

# %% [markdown]
# <h2 style="font-family: 'Times New Roman'; font-weight: bold;">
#     Preprocessing
# </h2>

# %% [markdown]
# <h3 style="font-family: 'Times New Roman'; font-weight: bold;">
#     Remove Empty BLAST Output Files
# </h3>

# %%
# Using the 'empty_files' function defined above, removing empty output files of MOTIF form 1 results
## Removing empyt CSV files
empty_files(coxl1_csv_results)

## Removing empty FASTA files
empty_files(coxl1_fasta_results)

## Removing empty Words files
empty_files(coxl1_docs_results)
# Out:
# Done CoxL1_Results/csv
# Done CoxL1_Results/fasta
# Done CoxL1_Results/docs

# %%
# Using the 'empty_files' function defined above, removing empty output files of MOTIF form 2 results
## Removing empyt CSV files
empty_files(coxl2_csv_results)

## Removing empty FASTA files
empty_files(coxl2_fasta_results)

## Removing empty Words files
empty_files(coxl2_docs_results)
# Out:
# Done CoxL2_Results/csv
# Done CoxL2_Results/fasta
# Done CoxL2_Results/docs

# %% [markdown]
# <h3 style="font-family: 'Times New Roman'; font-weight: bold;">
#     Combine BLAST CSV Outputs
# </h3>

# %%
# Concatenate MOTIF 1 CSV results
concatenate_csv(coxl1_csv_results, motif_1_csv_file_path)
# Out:
# CoxL1_Results/MOTIF/coxl1_csv.csv Successful

# %%
# Concatenate MOTIF 2 CSV results
concatenate_csv(coxl2_csv_results, motif_2_csv_file_path)
# Out:
# CoxL2_Results/MOTIF/coxl2_csv.csv Successful

# %% [markdown]
# <h3 style="font-family: 'Times New Roman'; font-weight: bold;">
#     Fetch genes from MAGs for MOTIF 1 BLAST Results
# </h3>

# %%
# Open the MOTIF 1 concatenated CSV file
coxl1_csv = open_file(motif_1_csv_file_path)
coxl1_csv.head()
# Out:
#                     qseqid                                  sseqid  pident  \
# 0  Genome20_S3Ck127_316360                 Mycobacterium_marinum_M  24.634
# 1  Genome20_S3Ck127_316360      Mycobacterium_tusciae_WP_006247553  24.433
# 2  Genome20_S3Ck127_316360                   Rhodococcus_opacus_B4  24.074
# 3  Genome20_S3Ck127_316360    Micromonospora_aurantiaca_ATCC_27029  24.536
# 4  Genome20_S3Ck127_316360  Mycobacterium_ulcerans_Agy99_YP_904347  24.528
#
#    qcovs        evalue  bitscore  qstart  qend  sstart  send  length  \
# 0     42  5.050000e-43     163.0    4980  2872      53   784     751
# 1     42  2.450000e-41     158.0    4980  2872      53   784     749
# 2     39  4.120000e-41     157.0    4980  3022      56   735     702
# 3     42  4.150000e-41     157.0    4980  2872      53   784     754
# 4     42  5.750000e-41     156.0    4953  2872      62   784     742
#
#                                          source_file
# 0  Bdellovibrionaceae_bacterium_ERS6626579_scores...
# 1  Bdellovibrionaceae_bacterium_ERS6626579_scores...
# 2  Bdellovibrionaceae_bacterium_ERS6626579_scores...
# 3  Bdellovibrionaceae_bacterium_ERS6626579_scores...
# 4  Bdellovibrionaceae_bacterium_ERS6626579_scores...

# %%
# Check the format of source_file
coxl1_csv['source_file'].unique()[0]
# Out:
# 'Bdellovibrionaceae_bacterium_ERS6626579_scores.csv'

# %%
# Create a target_file column, which is the file name of genomes, from the source file 
coxl1_csv['target_file'] = coxl1_csv['source_file'].apply(lambda x: x[:-11] + '.fasta')
coxl1_csv
# Out:
#                         qseqid                                    sseqid  \
# 0      Genome20_S3Ck127_316360                   Mycobacterium_marinum_M
# 1      Genome20_S3Ck127_316360        Mycobacterium_tusciae_WP_006247553
# 2      Genome20_S3Ck127_316360                     Rhodococcus_opacus_B4
# 3      Genome20_S3Ck127_316360      Micromonospora_aurantiaca_ATCC_27029
# 4      Genome20_S3Ck127_316360    Mycobacterium_ulcerans_Agy99_YP_904347
# ...                        ...                                       ...
# 99069    Genome526_k127_368022             Solirubrobacter_sp._URHD008_2
# 99070    Genome526_k127_368022             Pseduonocardia_autotrophica_1
# 99071    Genome526_k127_368022  Salinarimonas_rosea_DSM_21201_2523196126
# 99072    Genome526_k127_368022                  Nocardioides_sp._JS614_2
# 99073    Genome526_k127_368022            Thermocrispum_municipale_coxL1
#
#        pident  qcovs        evalue  bitscore  qstart  qend  sstart  send  \
# 0      24.634     42  5.050000e-43     163.0    4980  2872      53   784
# 1      24.433     42  2.450000e-41     158.0    4980  2872      53   784
# 2      24.074     39  4.120000e-41     157.0    4980  3022      56   735
# 3      24.536     42  4.150000e-41     157.0    4980  2872      53   784
# 4      24.528     42  5.750000e-41     156.0    4953  2872      62   784
# ...       ...    ...           ...       ...     ...   ...     ...   ...
# 99069  24.074     12  2.330000e-15      75.9    2280  3665     272   738
# 99070  27.444      7  1.240000e-14      73.6    2880  3665     486   740
# 99071  21.942     13  7.830000e-14      70.9    2283  3695     291   770
# 99072  27.106      7  9.760000e-14      70.5    2862  3665     491   749
# 99073  24.444     12  7.870000e-13      67.8    2280  3665     275   740
#
#        length                                        source_file  \
# 0         751  Bdellovibrionaceae_bacterium_ERS6626579_scores...
# 1         749  Bdellovibrionaceae_bacterium_ERS6626579_scores...
# 2         702  Bdellovibrionaceae_bacterium_ERS6626579_scores...
# 3         754  Bdellovibrionaceae_bacterium_ERS6626579_scores...
# 4         742  Bdellovibrionaceae_bacterium_ERS6626579_scores...
# ...       ...                                                ...
# 99069     486    uncultured_Xylophilus_sp._ERS6627302_scores.csv
# 99070     266    uncultured_Xylophilus_sp._ERS6627302_scores.csv
# 99071     515    uncultured_Xylophilus_sp._ERS6627302_scores.csv
# 99072     273    uncultured_Xylophilus_sp._ERS6627302_scores.csv
# 99073     495    uncultured_Xylophilus_sp._ERS6627302_scores.csv
#
#                                          target_file
# 0      Bdellovibrionaceae_bacterium_ERS6626579.fasta
# 1      Bdellovibrionaceae_bacterium_ERS6626579.fasta
# 2      Bdellovibrionaceae_bacterium_ERS6626579.fasta
# 3      Bdellovibrionaceae_bacterium_ERS6626579.fasta
# 4      Bdellovibrionaceae_bacterium_ERS6626579.fasta
# ...                                              ...
# 99069     uncultured_Xylophilus_sp._ERS6627302.fasta
# 99070     uncultured_Xylophilus_sp._ERS6627302.fasta
# 99071     uncultured_Xylophilus_sp._ERS6627302.fasta
# 99072     uncultured_Xylophilus_sp._ERS6627302.fasta
# 99073     uncultured_Xylophilus_sp._ERS6627302.fasta
#
# [99074 rows x 13 columns]

# %%
# Save the updated CoxL1 CSV file
coxl1_csv.to_csv(f'{motif_1_csv_file_path}', index=False)

# %%
# Fetch the matches from MOTIF 1 BLAST
fetch_genes(coxl1_csv, mags, motif_1_fasta_path)
# Out:
# Saved CoxL1_Results/MOTIF/fasta\Bdellovibrionaceae_bacterium_ERS6626579.fasta
# Saved CoxL1_Results/MOTIF/fasta\Bdellovibrionaceae_bacterium_ERS6626826.fasta
# Saved CoxL1_Results/MOTIF/fasta\Burkholderiaceae_bacterium_ERS6626828.fasta
# Saved CoxL1_Results/MOTIF/fasta\Burkholderiaceae_bacterium_ERS6626861.fasta
# Saved CoxL1_Results/MOTIF/fasta\Candidatus_Sericytochromatia_bacterium_ERS6626968.fasta
# Saved CoxL1_Results/MOTIF/fasta\Rhizobiaceae_bacterium_ERS6626796.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Achromobacter_sp._ERS6626913.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626561.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626565.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626576.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626591.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626592.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626596.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626599.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626607.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626644.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626705.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626715.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626735.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626737.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626738.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626787.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626798.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626819.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626824.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626827.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626841.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626883.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626889.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626918.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626955.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626991.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626997.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626999.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6627009.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6627016.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6627256.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6627271.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6627284.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6627297.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626567.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626575.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626593.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626600.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626616.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626617.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626625.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626631.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626637.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626640.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626647.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626656.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626674.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626684.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626685.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626690.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626701.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626712.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626717.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626718.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626740.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626745.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626746.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626750.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626751.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626753.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626754.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626761.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626800.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626816.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626821.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626825.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626858.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626912.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626926.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6627024.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6627027.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6627286.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6627310.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626610.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626648.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626649.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626666.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626670.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626766.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626805.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626810.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626818.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626838.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626868.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626908.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626910.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626932.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626956.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626958.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626959.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626971.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626977.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626984.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6627249.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6627262.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6627268.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6627285.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6627329.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Aquabacterium_sp._ERS6627305.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Aureimonas_sp._ERS6626915.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Aureimonas_sp._ERS6627306.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Blastomonas_sp._ERS6626578.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Brevundimonas_sp._ERS6626970.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Caulobacter_sp._ERS6626620.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626590.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626605.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626618.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626662.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626671.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626678.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626682.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626693.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626695.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626697.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626719.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626734.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626736.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626741.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626743.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626744.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626748.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626749.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626755.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626760.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626776.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626817.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626823.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626849.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626863.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626898.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626907.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626996.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6627248.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6627267.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6627296.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6627312.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6627318.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6627325.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6627338.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6627342.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6627343.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Comamonas_sp._ERS6626602.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Comamonas_sp._ERS6626630.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Comamonas_sp._ERS6626638.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Comamonas_sp._ERS6626645.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Comamonas_sp._ERS6626650.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Comamonas_sp._ERS6626814.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Comamonas_sp._ERS6626987.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Comamonas_sp._ERS6627283.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Comamonas_sp._ERS6627300.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Cupriavidus_sp._ERS6626993.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Curtobacterium_sp._ERS6626562.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Curtobacterium_sp._ERS6626839.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Curtobacterium_sp._ERS6626869.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Curtobacterium_sp._ERS6626884.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Curtobacterium_sp._ERS6626897.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Curtobacterium_sp._ERS6626914.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Curtobacterium_sp._ERS6627307.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Cystobacter_sp._ERS6626771.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Deinococcus_sp._ERS6626797.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Deinococcus_sp._ERS6626811.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Deinococcus_sp._ERS6626820.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Deinococcus_sp._ERS6626837.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Deinococcus_sp._ERS6627282.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Deinococcus_sp._ERS6627293.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Deinococcus_sp._ERS6627335.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Devosia_sp._ERS6626765.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Devosia_sp._ERS6626961.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Epilithonimonas_sp._ERS6626655.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Epilithonimonas_sp._ERS6626757.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Epilithonimonas_sp._ERS6626874.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Erwinia_sp._ERS6626634.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Erwinia_sp._ERS6626641.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Herbaspirillum_sp._ERS6626801.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Herbaspirillum_sp._ERS6627023.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Herbaspirillum_sp._ERS6627309.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Herbaspirillum_sp._ERS6627324.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Hymenobacter_sp._ERS6626716.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Hymenobacter_sp._ERS6626733.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Hymenobacter_sp._ERS6626935.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Hymenobacter_sp._ERS6627279.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Klebsiella_sp._ERS6626601.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Luteibacter_sp._ERS6626809.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Massilia_sp._ERS6626633.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Massilia_sp._ERS6626788.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Massilia_sp._ERS6626950.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Massilia_sp._ERS6626988.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Massilia_sp._ERS6627272.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Methylobacterium_sp._ERS6627288.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6626603.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6626604.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6626665.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6626704.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6626721.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6626781.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6626806.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6626906.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6626964.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6627018.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6627019.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6627260.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6627264.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6627311.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6627330.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6627334.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626632.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626762.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626764.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626791.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626799.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626803.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626873.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626894.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626923.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626931.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626962.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626972.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626981.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6627266.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6627275.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6627290.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6627314.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Naasia_sp._ERS6626864.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Naasia_sp._ERS6627002.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Naasia_sp._ERS6627012.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Naasia_sp._ERS6627270.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Naasia_sp._ERS6627292.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Naasia_sp._ERS6627328.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626759.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626775.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626778.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626784.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626786.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626794.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626802.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626829.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626852.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626853.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626854.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626865.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626886.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626887.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626893.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626895.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626901.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626917.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626929.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626942.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626965.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626979.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626989.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6627247.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6627291.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6627336.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Ochrobactrum_sp._ERS6626652.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Ochrobactrum_sp._ERS6627020.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Oxalicibacterium_sp._ERS6626668.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626585.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626614.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626696.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626698.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626700.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626702.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626703.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626842.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626843.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626844.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626855.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626905.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6627323.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6627333.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6626568.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6626595.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6626623.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6626643.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6626657.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6626661.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6626664.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6626752.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6626902.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6626920.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6626969.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6627004.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6627005.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6627022.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6627332.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pedobacter_sp._ERS6626651.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pedobacter_sp._ERS6626667.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pedobacter_sp._ERS6626930.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pelomonas_sp._ERS6626569.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pelomonas_sp._ERS6626597.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pluralibacter_sp._ERS6626635.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudacidovorax_sp._ERS6626577.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudacidovorax_sp._ERS6626767.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudacidovorax_sp._ERS6626850.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudacidovorax_sp._ERS6626909.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudacidovorax_sp._ERS6627003.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudacidovorax_sp._ERS6627320.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudacidovorax_sp._ERS6627321.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudocitrobacter_sp._ERS6626990.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626560.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626563.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626566.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626621.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626626.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626639.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626663.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626673.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626675.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626676.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626710.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626713.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626795.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626822.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626882.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626921.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626934.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626952.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626953.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626976.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626978.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627007.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627014.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627015.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627025.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627026.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627245.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627251.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627265.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627273.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627274.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627287.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627294.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627295.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627315.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Pseudorhodoferax_sp._ERS6626941.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Roseateles_sp._ERS6626963.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Roseateles_sp._ERS6626966.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Serratia_sp._ERS6626624.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Serratia_sp._ERS6626636.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Serratia_sp._ERS6627010.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Siphonobacter_sp._ERS6626689.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Siphonobacter_sp._ERS6626714.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingobium_sp._ERS6626960.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626574.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626580.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626582.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626584.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626586.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626587.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626588.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626589.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626594.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626612.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626622.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626653.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626658.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626669.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626672.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626680.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626686.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626692.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626720.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626768.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626769.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626774.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626780.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626783.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626785.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626831.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626833.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626834.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626835.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626845.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626851.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626856.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626857.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626860.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626866.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626867.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626870.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626871.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626872.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626876.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626881.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626899.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626904.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626911.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626916.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626927.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626936.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626938.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626946.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626948.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626949.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626954.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626957.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626973.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626998.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627000.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627006.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627008.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627013.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627017.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627255.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627257.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627258.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627259.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627261.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627263.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627280.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627281.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627299.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627316.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627317.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626747.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626772.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626782.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626804.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626815.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626890.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626891.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626892.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626982.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626983.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626985.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626995.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6627011.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Stenotrophomonas_sp._ERS6626688.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Stenotrophomonas_sp._ERS6626723.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Stenotrophomonas_sp._ERS6626727.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Stenotrophomonas_sp._ERS6627250.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Stenotrophomonas_sp._ERS6627308.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Stenotrophomonas_sp._ERS6627319.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Stenotrophomonas_sp._ERS6627344.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Variovorax_sp._ERS6626779.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Variovorax_sp._ERS6627246.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626613.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626642.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626687.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626724.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626725.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626726.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626730.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626832.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626836.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626846.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626848.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626859.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626943.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6627001.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6627021.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6627277.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6627278.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6627322.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6627331.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6627339.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6627340.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xylophilus_sp._ERS6626940.fasta
# Saved CoxL1_Results/MOTIF/fasta\uncultured_Xylophilus_sp._ERS6627302.fasta

# %% [markdown]
# <h3 style="font-family: 'Times New Roman'; font-weight: bold;">
#     Fetch genes from MAGs for MOTIF 2 BLAST Results
# </h3>

# %%
# Open the MOTIF 2 concatenated results
coxl2_csv = open_file(motif_2_csv_file_path)
coxl2_csv.head()
# Out:
#                     qseqid                                             sseqid  \
# 0  Genome20_S3Ck127_316360  BAB48572_Form2_Rhodopseudomonas_palustris_BisA...
# 1  Genome20_S3Ck127_316360        BAB48572_Form2_Mesorhizobium_japonicum_MAFF
# 2    Genome267_k127_201050        BAB48572_Form2_Mesorhizobium_japonicum_MAFF
# 3    Genome267_k127_201050  BAB48572_Form2_Rhodopseudomonas_palustris_BisA...
# 4    Genome267_k127_433915  BAB48572_Form2_Rhodopseudomonas_palustris_BisA...
#
#    pident  qcovs        evalue  bitscore  qstart  qend  sstart  send  length  \
# 0  24.931     42  8.800000e-31     119.0    4944  2872      52   754     726
# 1  24.933     41  1.080000e-26     105.0    4953  2911      48   760     742
# 2  23.846     21  4.900000e-35     134.0    6807  8963       7   767     780
# 3  24.791     17  4.110000e-34     130.0    7299  9014     188   766     597
# 4  24.156     20  1.980000e-34     132.0    3178   995       8   741     770
#
#                                          source_file
# 0  Bdellovibrionaceae_bacterium_ERS6626579_scores...
# 1  Bdellovibrionaceae_bacterium_ERS6626579_scores...
# 2  Bdellovibrionaceae_bacterium_ERS6626826_scores...
# 3  Bdellovibrionaceae_bacterium_ERS6626826_scores...
# 4  Bdellovibrionaceae_bacterium_ERS6626826_scores...

# %%
# Create a target_file column, which the file name of genomes, from the source file 
coxl2_csv['target_file'] = coxl2_csv['source_file'].apply(lambda x: x[:-11] + '.fasta')
coxl2_csv
# Out:
#                        qseqid  \
# 0     Genome20_S3Ck127_316360
# 1     Genome20_S3Ck127_316360
# 2       Genome267_k127_201050
# 3       Genome267_k127_201050
# 4       Genome267_k127_433915
# ...                       ...
# 2194     Genome526_k127_12441
# 2195    Genome526_k127_152992
# 2196    Genome526_k127_152992
# 2197    Genome526_k127_368022
# 2198    Genome526_k127_368022
#
#                                                  sseqid  pident  qcovs  \
# 0     BAB48572_Form2_Rhodopseudomonas_palustris_BisA...  24.931     42
# 1           BAB48572_Form2_Mesorhizobium_japonicum_MAFF  24.933     41
# 2           BAB48572_Form2_Mesorhizobium_japonicum_MAFF  23.846     21
# 3     BAB48572_Form2_Rhodopseudomonas_palustris_BisA...  24.791     17
# 4     BAB48572_Form2_Rhodopseudomonas_palustris_BisA...  24.156     20
# ...                                                 ...     ...    ...
# 2194  BAB48572_Form2_Rhodopseudomonas_palustris_BisA...  31.604      1
# 2195  BAB48572_Form2_Rhodopseudomonas_palustris_BisA...  25.142      3
# 2196        BAB48572_Form2_Mesorhizobium_japonicum_MAFF  23.077      3
# 2197        BAB48572_Form2_Mesorhizobium_japonicum_MAFF  25.146     13
# 2198  BAB48572_Form2_Rhodopseudomonas_palustris_BisA...  25.631     13
#
#             evalue  bitscore  qstart   qend  sstart  send  length  \
# 0     8.800000e-31     119.0    4944   2872      52   754     726
# 1     1.080000e-26     105.0    4953   2911      48   760     742
# 2     4.900000e-35     134.0    6807   8963       7   767     780
# 3     4.110000e-34     130.0    7299   9014     188   766     597
# 4     1.980000e-34     132.0    3178    995       8   741     770
# ...            ...       ...     ...    ...     ...   ...     ...
# 2194  4.330000e-07      45.1    1502    903     551   754     212
# 2195  2.390000e-24     102.0   51673  53688       9   688     704
# 2196  2.420000e-17      79.3   51673  53721       7   722     741
# 2197  2.320000e-25     102.0    2199   3680     252   752     513
# 2198  4.800000e-25     102.0    2157   3665     234   718     515
#
#                                             source_file  \
# 0     Bdellovibrionaceae_bacterium_ERS6626579_scores...
# 1     Bdellovibrionaceae_bacterium_ERS6626579_scores...
# 2     Bdellovibrionaceae_bacterium_ERS6626826_scores...
# 3     Bdellovibrionaceae_bacterium_ERS6626826_scores...
# 4     Bdellovibrionaceae_bacterium_ERS6626826_scores...
# ...                                                 ...
# 2194    uncultured_Xylophilus_sp._ERS6627302_scores.csv
# 2195    uncultured_Xylophilus_sp._ERS6627302_scores.csv
# 2196    uncultured_Xylophilus_sp._ERS6627302_scores.csv
# 2197    uncultured_Xylophilus_sp._ERS6627302_scores.csv
# 2198    uncultured_Xylophilus_sp._ERS6627302_scores.csv
#
#                                         target_file
# 0     Bdellovibrionaceae_bacterium_ERS6626579.fasta
# 1     Bdellovibrionaceae_bacterium_ERS6626579.fasta
# 2     Bdellovibrionaceae_bacterium_ERS6626826.fasta
# 3     Bdellovibrionaceae_bacterium_ERS6626826.fasta
# 4     Bdellovibrionaceae_bacterium_ERS6626826.fasta
# ...                                             ...
# 2194     uncultured_Xylophilus_sp._ERS6627302.fasta
# 2195     uncultured_Xylophilus_sp._ERS6627302.fasta
# 2196     uncultured_Xylophilus_sp._ERS6627302.fasta
# 2197     uncultured_Xylophilus_sp._ERS6627302.fasta
# 2198     uncultured_Xylophilus_sp._ERS6627302.fasta
#
# [2199 rows x 13 columns]

# %%
# Save the updated CoxL2 CSV file
coxl2_csv.to_csv(f'{motif_2_csv_file_path}', index=False)

# %%
# Fetch the matches from MOTIF 2 BLAST
fetch_genes(coxl2_csv, mags, motif_2_fasta_path)
# Out:
# Saved CoxL2_Results/MOTIF/fasta\Bdellovibrionaceae_bacterium_ERS6626579.fasta
# Saved CoxL2_Results/MOTIF/fasta\Bdellovibrionaceae_bacterium_ERS6626826.fasta
# Saved CoxL2_Results/MOTIF/fasta\Burkholderiaceae_bacterium_ERS6626828.fasta
# Saved CoxL2_Results/MOTIF/fasta\Burkholderiaceae_bacterium_ERS6626861.fasta
# Saved CoxL2_Results/MOTIF/fasta\Candidatus_Sericytochromatia_bacterium_ERS6626968.fasta
# Saved CoxL2_Results/MOTIF/fasta\Rhizobiaceae_bacterium_ERS6626796.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Achromobacter_sp._ERS6626913.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626561.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626565.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626576.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626591.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626592.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626596.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626599.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626607.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626644.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626705.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626715.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626735.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626737.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626738.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626787.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626798.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626819.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626824.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626827.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626841.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626883.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626889.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626918.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626955.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626991.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626997.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6626999.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6627009.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6627016.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6627256.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6627271.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6627284.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acidovorax_sp._ERS6627297.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626567.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626575.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626593.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626600.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626616.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626617.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626625.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626631.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626637.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626640.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626647.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626656.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626674.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626684.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626685.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626690.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626701.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626712.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626717.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626718.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626740.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626745.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626746.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626750.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626751.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626753.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626754.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626761.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626800.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626816.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626821.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626825.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626858.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626912.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6626926.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6627024.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6627027.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6627286.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Acinetobacter_sp._ERS6627310.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626610.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626648.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626649.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626666.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626670.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626766.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626805.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626810.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626818.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626838.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626868.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626908.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626910.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626932.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626956.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626958.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626959.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626971.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626977.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6626984.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6627249.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6627262.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6627268.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6627285.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Agrobacterium_sp._ERS6627329.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Aquabacterium_sp._ERS6627305.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Aureimonas_sp._ERS6626915.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Aureimonas_sp._ERS6627306.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Blastomonas_sp._ERS6626578.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626590.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626605.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626618.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626662.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626671.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626678.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626682.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626693.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626695.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626697.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626719.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626734.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626736.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626741.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626743.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626744.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626748.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626749.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626755.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626760.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626776.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626817.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626823.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626849.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626863.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626898.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626907.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6626996.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6627248.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6627267.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6627296.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6627312.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6627318.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6627325.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6627338.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6627342.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Chryseobacterium_sp._ERS6627343.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Comamonas_sp._ERS6626602.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Comamonas_sp._ERS6626630.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Comamonas_sp._ERS6626638.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Comamonas_sp._ERS6626645.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Comamonas_sp._ERS6626650.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Comamonas_sp._ERS6626814.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Comamonas_sp._ERS6626987.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Comamonas_sp._ERS6627283.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Comamonas_sp._ERS6627300.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Cupriavidus_sp._ERS6626993.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Curtobacterium_sp._ERS6626562.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Curtobacterium_sp._ERS6626839.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Curtobacterium_sp._ERS6626869.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Curtobacterium_sp._ERS6626884.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Curtobacterium_sp._ERS6626914.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Curtobacterium_sp._ERS6627307.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Cystobacter_sp._ERS6626771.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Deinococcus_sp._ERS6626797.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Deinococcus_sp._ERS6626811.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Deinococcus_sp._ERS6626820.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Deinococcus_sp._ERS6626837.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Deinococcus_sp._ERS6627282.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Deinococcus_sp._ERS6627293.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Deinococcus_sp._ERS6627335.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Devosia_sp._ERS6626765.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Devosia_sp._ERS6626961.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Epilithonimonas_sp._ERS6626655.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Epilithonimonas_sp._ERS6626757.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Epilithonimonas_sp._ERS6626874.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Erwinia_sp._ERS6626634.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Erwinia_sp._ERS6626641.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Herbaspirillum_sp._ERS6626801.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Herbaspirillum_sp._ERS6627023.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Herbaspirillum_sp._ERS6627309.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Herbaspirillum_sp._ERS6627324.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Hymenobacter_sp._ERS6626716.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Hymenobacter_sp._ERS6626733.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Hymenobacter_sp._ERS6626935.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Hymenobacter_sp._ERS6627279.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Klebsiella_sp._ERS6626601.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Luteibacter_sp._ERS6626809.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Massilia_sp._ERS6626633.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Massilia_sp._ERS6626788.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Massilia_sp._ERS6626950.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Massilia_sp._ERS6626988.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Massilia_sp._ERS6627272.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Methylobacterium_sp._ERS6627288.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6626603.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6626604.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6626665.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6626704.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6626721.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6626781.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6626806.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6626906.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6626964.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6627018.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6627019.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6627260.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6627264.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6627311.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6627330.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Microbacterium_sp._ERS6627334.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626632.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626762.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626764.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626791.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626799.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626803.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626873.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626894.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626923.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626931.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626962.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626972.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6626981.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6627266.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6627275.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6627290.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Mucilaginibacter_sp._ERS6627314.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Naasia_sp._ERS6626864.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Naasia_sp._ERS6627002.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Naasia_sp._ERS6627012.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Naasia_sp._ERS6627270.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Naasia_sp._ERS6627292.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Naasia_sp._ERS6627328.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626759.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626775.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626778.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626784.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626786.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626794.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626802.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626829.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626852.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626853.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626854.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626865.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626886.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626887.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626893.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626895.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626901.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626917.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626929.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626942.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626965.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626979.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6626989.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6627247.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6627291.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Novosphingobium_sp._ERS6627336.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Ochrobactrum_sp._ERS6626652.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Ochrobactrum_sp._ERS6627020.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Oxalicibacterium_sp._ERS6626668.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626585.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626614.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626696.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626698.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626700.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626702.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626703.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626842.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626843.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626844.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626855.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6626905.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6627253.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6627323.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Paenibacillus_sp._ERS6627333.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6626568.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6626595.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6626623.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6626643.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6626657.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6626661.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6626664.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6626752.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6626902.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6626920.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6626969.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6627004.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6627005.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6627022.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pantoea_sp._ERS6627332.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pedobacter_sp._ERS6626651.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pedobacter_sp._ERS6626667.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pedobacter_sp._ERS6626930.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pelomonas_sp._ERS6626569.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pelomonas_sp._ERS6626597.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pluralibacter_sp._ERS6626635.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudacidovorax_sp._ERS6626577.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudacidovorax_sp._ERS6626767.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudacidovorax_sp._ERS6626850.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudacidovorax_sp._ERS6626909.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudacidovorax_sp._ERS6627003.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudacidovorax_sp._ERS6627320.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudacidovorax_sp._ERS6627321.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudocitrobacter_sp._ERS6626990.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626560.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626563.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626566.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626621.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626626.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626639.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626663.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626673.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626675.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626676.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626710.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626713.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626822.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626882.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626921.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626934.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626952.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626953.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626976.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6626978.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627007.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627014.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627015.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627025.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627026.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627245.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627251.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627265.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627273.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627274.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627287.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627294.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627295.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudomonas_sp._ERS6627315.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Pseudorhodoferax_sp._ERS6626941.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Roseateles_sp._ERS6626963.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Roseateles_sp._ERS6626966.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Serratia_sp._ERS6626624.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Serratia_sp._ERS6626636.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Serratia_sp._ERS6627010.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Siphonobacter_sp._ERS6626689.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Siphonobacter_sp._ERS6626714.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingobium_sp._ERS6626960.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626574.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626580.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626582.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626584.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626586.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626587.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626588.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626589.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626594.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626612.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626622.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626653.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626658.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626669.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626672.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626680.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626686.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626692.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626720.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626768.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626769.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626774.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626780.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626783.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626785.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626831.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626833.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626834.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626835.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626845.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626851.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626856.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626857.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626860.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626866.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626867.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626870.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626871.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626872.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626876.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626881.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626899.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626904.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626911.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626916.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626927.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626936.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626938.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626946.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626948.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626949.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626954.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626957.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626973.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6626998.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627000.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627006.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627008.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627013.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627017.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627255.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627257.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627258.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627259.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627261.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627263.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627280.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627281.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627299.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627316.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Sphingomonas_sp._ERS6627317.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626747.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626772.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626782.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626804.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626815.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626890.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626891.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626892.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626982.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626983.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626985.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6626995.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Spirosoma_sp._ERS6627011.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Stenotrophomonas_sp._ERS6626688.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Stenotrophomonas_sp._ERS6626723.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Stenotrophomonas_sp._ERS6626727.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Stenotrophomonas_sp._ERS6627250.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Stenotrophomonas_sp._ERS6627308.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Stenotrophomonas_sp._ERS6627319.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Stenotrophomonas_sp._ERS6627344.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Variovorax_sp._ERS6626779.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Variovorax_sp._ERS6627246.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626613.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626642.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626687.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626724.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626725.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626726.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626730.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626832.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626836.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626846.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626848.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626859.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6626943.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6627001.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6627021.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6627277.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6627278.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6627322.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6627331.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6627339.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xanthomonas_sp._ERS6627340.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xylophilus_sp._ERS6626940.fasta
# Saved CoxL2_Results/MOTIF/fasta\uncultured_Xylophilus_sp._ERS6627302.fasta
