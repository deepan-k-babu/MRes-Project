# %% [markdown]
# <h1 style="font-family: 'Times New Roman'; text-align: center; font-weight: bold;">
#     Conserved Domain Search
# </h1>

# %% [markdown]
# <div style="font-family: 'Times New Roman'; font-size: 15px; text-align: justify; width: 100%;">
#   <div>
#     <span style="display: inline-block; width: 100px;"><b>Date</b></span>: 16<sup>th</sup> November 2024
#   </div>
#   <div>
#     <span style="display: inline-block; width: 100px;"><b>Author</b></span>: Deepan Kanagarajan Babu
#   </div>
#   <div>
#     <span style="display: inline-block; width: 100px;"><b>Description</b></span>: In this document, the filtered sequences are BLAST against the conserved domain database of NCBI. Conserved domain search (CDS) is performed in the document and directly uploaded to the server (called as "open_blast" in this document). Both the out put are analysed in the document. In document CDS only gives the .csv file output, to visualize the structure of the sequence domain architecture, use the server. The first hits as coxL gene are consedered as carrying the coxL domain and also based on the e-value signinificance.
#   </div>
# </div>

# %% [markdown]
# <h2 style="font-family: 'Times New Roman'; font-weight: bold;">
#     Required Libraries
# </h2>

# %%
import pandas as pd
import numpy as np
import os
import csv
import time
import shutil
from Bio import SeqIO
from Bio.Blast import NCBIWWW
from xml.etree import ElementTree as ET

# %% [markdown]
# <h2 style="font-family: 'Times New Roman'; font-weight: bold;">
#     Required Functions
# </h2>

# %%
# Defining single function to open multiple file formats (.csv, .txt, .fasta or .fastq (to display only 1st 100 lines), and .xlsx)
def open_file(file_path):
    if file_path.endswith('.csv'):
        # Read CSV file
        data = pd.read_csv(file_path)
        return data
    elif file_path.endswith('.txt'):
        # Read TXT file
        try:
            with open(file_path, 'r') as file:
                data = file.read()
            return data
        except FileNotFoundError:
            raise FileNotFoundError(f"The file {file_path} does not exist.")
    elif file_path.endswith(('.fasta', '.fastq')):
        # Read FASTA or FASTQ file
        try:
            with open(file_path, 'r') as file:
                data = []
                for _ in range(100):
                    line = file.readline()
                    if not line:
                        break
                    data.append(line.strip())
            return data
        except FileNotFoundError:
            raise FileNotFoundError(f"The file {file_path} does not exist.")
    elif file_path.endswith('.xlsx'):
        # Read XLSX file
        try:
            data = pd.read_excel(file_path)
            return data
        except FileNotFoundError:
            raise FileNotFoundError(f"The file {file_path} does not exist.")
    else:
        raise ValueError("Unsupported file format")

# %%
def filter_fasta(csv_file, input_folder, output_folder, duplicates_folder):
    os.makedirs(output_folder, exist_ok=True)
    os.makedirs(duplicates_folder, exist_ok=True)
    
    # Read CSV file and store sequences to extract
    sequences_to_extract = {}
    try:
        with open(csv_file, newline='', encoding='utf-8') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                file_name = row["File_Name"].strip()
                sequence_id = row["ID"].strip()
                sequence = row["Sequence"].strip()
                sequence_length = int(row["sequence_length"].strip())
                
                if file_name not in sequences_to_extract:
                    sequences_to_extract[file_name] = {}
                
                sequences_to_extract[file_name][sequence_id] = (sequence, sequence_length)  # Store ID, sequence, and length
    
    except FileNotFoundError:
        print(f"CSV file not found: {csv_file}")
        return
    except KeyError:
        print("CSV file is missing required columns: 'File_Name', 'ID', 'Sequence', and 'sequence_length'")
        return
    
    # Process each FASTA file
    for file_name, sequence_data in sequences_to_extract.items():
        input_file_path = os.path.join(input_folder, file_name)
        output_file_path = os.path.join(output_folder, f"{os.path.splitext(file_name)[0]}_filtered.faa")
        duplicates_file_path = os.path.join(duplicates_folder, f"{os.path.splitext(file_name)[0]}_duplicates.txt")

        if not os.path.exists(input_file_path):
            print(f"File not found: {input_file_path}")
            continue

        extracted_records = []
        seen_sequences = {}
        duplicate_headers = []

        for record in SeqIO.parse(input_file_path, "fasta"):
            if record.id in sequence_data and str(record.seq) == sequence_data[record.id][0] and len(record.seq) == sequence_data[record.id][1]:
                if str(record.seq) in seen_sequences:
                    duplicate_headers.append(record.id)
                else:
                    seen_sequences[str(record.seq)] = record.id
                    extracted_records.append(record)

        if extracted_records:
            with open(output_file_path, "w") as output_f:
                SeqIO.write(extracted_records, output_f, "fasta")
            print(f"Extracted sequences saved to: {output_file_path}")
        
        if duplicate_headers:
            with open(duplicates_file_path, "w") as duplicates_f:
                duplicates_f.write(f"Duplicate headers in {file_name}:\n")
                for header in duplicate_headers:
                    duplicates_f.write(f"{header}\n")
            print(f"Duplicate headers saved to: {duplicates_file_path}")

    print("Sequence extraction completed.")

# %%
# Function to count number of sequences in every file
def count_sequences_in_fasta_files(folder_path):
    # Dictionary to store the count of sequences in each file
    sequence_counts = {}
    total_sequences = 0

    # Iterate over each file in the folder
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".faa") | file_name.endswith(".fasta") | file_name.endswith(".fna"):
            file_path = os.path.join(folder_path, file_name)
            # Count the number of sequences in the current .faa file
            sequence_count = sum(1 for _ in SeqIO.parse(file_path, "fasta"))
            sequence_counts[file_name] = sequence_count
            total_sequences += sequence_count

    return sequence_counts, total_sequences

# %%
# Function to perform BLAST search for a protein sequence with retry mechanism
def search_cdd(sequence, program="blastp", db="cdd", e_value=0.01, max_hits=10, retries=10, timeout=600):
    for attempt in range(retries):
        try:
            print(f"Attempt {attempt + 1} for sequence.")
            result_handle = NCBIWWW.qblast(
                program=program,
                database=db,
                sequence=sequence,
                expect=e_value,
                hitlist_size=max_hits
            )
            results = result_handle.read()
            result_handle.close()
            return results
        except Exception as e:
            print(f"Attempt {attempt + 1} failed: {e}")
            time.sleep(5)  # Wait before retrying
    print("All attempts failed.")
    return None

# Function to parse BLAST XML and extract summary information
def parse_cdd_xml(xml_content):
    try:
        root = ET.fromstring(xml_content)
        hits = []
        
        # Parse the hits from the XML
        for hit in root.findall(".//Hit"):
            hit_id = hit.findtext("Hit_id")
            hit_def = hit.findtext("Hit_def")
            hit_score = hit.findtext(".//Hsp_bit-score")
            e_value = hit.findtext(".//Hsp_evalue")
            hits.append({
                "hit_id": hit_id,
                "hit_def": hit_def,
                "hit_score": hit_score,
                "e_value": e_value,
            })
        return hits
    except ET.ParseError as e:
        print(f"Error parsing XML: {e}")
        return []

# Function to process all .faa files in a folder
def conserved_domain_search(folder_path, output_folder, summary_csv, program="blastp", db="cdd"):
    os.makedirs(output_folder, exist_ok=True)
    
    with open(summary_csv, "w", newline="") as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(["Fasta File", "Sequence Header", "CDD Hit ID", "CDD Hit Definition", "Bit Score", "E-value"])
        
        for file_name in os.listdir(folder_path):
            if file_name.endswith(".faa"):
                file_path = os.path.join(folder_path, file_name)
                print(f"Processing file: {file_name}")
                
                for record in SeqIO.parse(file_path, "fasta"):
                    sequence_id = record.id
                    sequence = str(record.seq)
                    
                    print(f"Searching CDD for sequence: {sequence_id}")
                    result = search_cdd(sequence, program=program, db=db)
                    
                    if result:
                        output_file = os.path.join(output_folder, f"{file_name}_{sequence_id}_cdd.xml")
                        with open(output_file, "w") as f:
                            f.write(result)
                        print(f"Results saved to: {output_file}")
                        
                        hits = parse_cdd_xml(result)
                        for hit in hits:
                            csv_writer.writerow([
                                file_name,
                                sequence_id,
                                hit["hit_id"],
                                hit["hit_def"],
                                hit["hit_score"],
                                hit["e_value"]
                            ])
                print(f"Completed processing file: {file_name}")

# %% [markdown]
# <h2 style="font-family: 'Times New Roman'; font-weight: bold;">
#     Required Directories Path
# </h2>

# %%
# Specify the input folder paths
## Filtered MOTIF form 1 BLAST CSV file path
motif_1_csv_file_path = "CoxL1_Results/MOTIF/filtered_coxl1_csv.csv"


## Filtered MOTIF form 2 BLAST CSV file path
motif_2_csv_file_path = "CoxL2_Results/MOTIF/filtered_coxl2_csv.csv"

## Filtered CoxL1 MOTIF results
motif_1_results = "CoxL1_Results/MOTIF/coxl1_motif_results.csv"

## Filtered CoxL2 MOTIF results
motif_2_results = "CoxL2_Results/MOTIF/coxl2_motif_results.csv"

## CoxL Form 1 BLAST proteins sequence directory
motif_1_proteins = "CoxL1_Results/MOTIF_proteins"

## CoxL Form 2 BLAST proteins sequence directory
motif_2_proteins = "CoxL2_Results/MOTIF_proteins"

## MOTIF1 results directory
motif1 = "CoxL1_Results/MOTIF"

## MOTIF2 results directory
motif2 = "CoxL2_Results/MOTIF"

## CoxL 2 MOTIF FASTA Output
motif_2_fasta_path = "CoxL2_Results/MOTIF/fasta"

## NCBI Open db BLAST Results Folder
cross_ver = "CoxL2_Results/Cross_Verification"

# Specify the output folder paths
## CoxL Form 1 BLAST proteins sequence directory
motif_1_filtered_proteins = "CoxL1_Results/MOTIF_filtered_proteins"
## Ensure the output directory exists
os.makedirs(motif_1_filtered_proteins, exist_ok=True)

## CoxL Form 2 BLAST proteins sequence directory
motif_2_filtered_proteins = "CoxL2_Results/MOTIF_filtered_proteins"
## Ensure the output directory exists
os.makedirs(motif_2_proteins, exist_ok=True)

## CoxL Form1 BLAST outputs with Form 2 MOTIFs, cds search results directory for .xlm file
xlm1 = "CoxL1_Results/MOTIF/xlm"
## Ensure the output directory exists
os.makedirs(xlm1, exist_ok=True)

## CoxL Form2 BLAST output with Form 2 MOTIFS, cds search results directory for .xlm file
xlm2 = "CoxL2_Results/MOTIF/xlm"
## Ensure the output directory exists
os.makedirs(xlm2, exist_ok=True)

## MOTIF1 BLAST output cds search results directory for .xlm file
duplicate1 = "CoxL1_Results/MOTIF/duplicate_list"
## Ensure the output directory exists
os.makedirs(xlm1, exist_ok=True)

## MOTIF2 BLAST output cds search results directory for .xlm file
duplicate2 = "CoxL2_Results/MOTIF/duplicate"
## Ensure the output directory exists
os.makedirs(xlm2, exist_ok=True)

## CoxL Form 1 BLAST proteins sequence CDS result file path
cds1 = "CoxL1_Results/MOTIF/cds1.csv"

## CoxL Form 2 BLAST proteins sequence CDS result file path
cds2 = "CoxL2_Results/MOTIF/cds2.csv"

## CoxL Form 2 genes directory
coxl2_genes = "Coxl2_Results/Genes"
## Ensure the output directory exists
os.makedirs(coxl2_genes, exist_ok=True)

# %% [markdown]
# <h2 style="font-family: 'Times New Roman'; font-weight: bold;">
#     Filter Fasta Files with Filtered MOTIF Search Results
# </h2>

# %% [markdown]
# <h3 style="font-family: 'Times New Roman'; font-weight: bold;">
#     For Form 1 BLAST Results with Form 2 MOTIFs
# </h3>

# %%
# Run the extraction
filter_fasta(motif_1_results, motif_1_proteins, motif_1_filtered_proteins, duplicate1)
# Out:
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Acidovorax_sp._ERS6626787_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Acidovorax_sp._ERS6626787_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Acidovorax_sp._ERS6627271_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Acidovorax_sp._ERS6627271_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Acinetobacter_sp._ERS6626821_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Acinetobacter_sp._ERS6626858_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Agrobacterium_sp._ERS6626766_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Aureimonas_sp._ERS6626915_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Aureimonas_sp._ERS6626915_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Aureimonas_sp._ERS6627306_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Aureimonas_sp._ERS6627306_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Comamonas_sp._ERS6626602_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Comamonas_sp._ERS6626630_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Comamonas_sp._ERS6626638_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Comamonas_sp._ERS6626638_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Comamonas_sp._ERS6626814_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Comamonas_sp._ERS6627283_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Deinococcus_sp._ERS6626797_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Deinococcus_sp._ERS6626797_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Deinococcus_sp._ERS6626820_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Deinococcus_sp._ERS6626820_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Deinococcus_sp._ERS6626837_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Deinococcus_sp._ERS6626837_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Deinococcus_sp._ERS6627293_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Deinococcus_sp._ERS6627293_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Deinococcus_sp._ERS6627335_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Deinococcus_sp._ERS6627335_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Hymenobacter_sp._ERS6626733_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Hymenobacter_sp._ERS6627279_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Massilia_sp._ERS6627272_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Massilia_sp._ERS6627272_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Methylobacterium_sp._ERS6627288_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Methylobacterium_sp._ERS6627288_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Microbacterium_sp._ERS6626906_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Microbacterium_sp._ERS6626964_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Mucilaginibacter_sp._ERS6626873_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Mucilaginibacter_sp._ERS6626923_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Mucilaginibacter_sp._ERS6626962_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Mucilaginibacter_sp._ERS6626972_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Mucilaginibacter_sp._ERS6626981_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Mucilaginibacter_sp._ERS6627275_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Mucilaginibacter_sp._ERS6627290_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Pantoea_sp._ERS6626643_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Pantoea_sp._ERS6626643_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Pantoea_sp._ERS6627005_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Pelomonas_sp._ERS6626569_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Pelomonas_sp._ERS6626569_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Pluralibacter_sp._ERS6626635_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Pseudacidovorax_sp._ERS6626577_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Pseudacidovorax_sp._ERS6626850_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Pseudacidovorax_sp._ERS6626909_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Pseudacidovorax_sp._ERS6626909_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Pseudacidovorax_sp._ERS6627003_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Pseudacidovorax_sp._ERS6627003_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Pseudacidovorax_sp._ERS6627320_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Pseudacidovorax_sp._ERS6627320_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Pseudacidovorax_sp._ERS6627321_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Pseudacidovorax_sp._ERS6627321_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Pseudomonas_sp._ERS6626673_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Pseudomonas_sp._ERS6626673_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Pseudomonas_sp._ERS6627273_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Pseudomonas_sp._ERS6627273_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Pseudorhodoferax_sp._ERS6626941_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Sphingomonas_sp._ERS6626586_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Sphingomonas_sp._ERS6626586_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Sphingomonas_sp._ERS6626612_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Sphingomonas_sp._ERS6626669_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Sphingomonas_sp._ERS6626680_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Sphingomonas_sp._ERS6626680_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Sphingomonas_sp._ERS6626831_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Sphingomonas_sp._ERS6626845_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Sphingomonas_sp._ERS6626927_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Sphingomonas_sp._ERS6626948_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Sphingomonas_sp._ERS6626948_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Sphingomonas_sp._ERS6626957_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Sphingomonas_sp._ERS6626957_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Sphingomonas_sp._ERS6627258_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Sphingomonas_sp._ERS6627261_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Sphingomonas_sp._ERS6627261_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Spirosoma_sp._ERS6626983_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Spirosoma_sp._ERS6627011_filtered.faa
# Duplicate headers saved to: CoxL1_Results/MOTIF/duplicate_list\uncultured_Spirosoma_sp._ERS6627011_duplicates.txt
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Stenotrophomonas_sp._ERS6627319_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Variovorax_sp._ERS6626779_filtered.faa
# Extracted sequences saved to: CoxL1_Results/MOTIF_filtered_proteins\uncultured_Variovorax_sp._ERS6627246_filtered.faa
# Sequence extraction completed.

# %%
# Get the count of sequences in each .faa file and the total sequences
sequence_counts_1, total_sequences_1 = count_sequences_in_fasta_files(motif_1_filtered_proteins)

# Print the results
for file_name, count in sequence_counts_1.items():
    print(f"{file_name}: {count} sequences")

print(f"Total sequences from all files: {total_sequences_1}")
# Out:
# Burkholderiaceae_bacterium_ERS6626861_filtered.faa: 1 sequences
# uncultured_Acidovorax_sp._ERS6626735_filtered.faa: 1 sequences
# uncultured_Acidovorax_sp._ERS6626737_filtered.faa: 1 sequences
# uncultured_Acidovorax_sp._ERS6626738_filtered.faa: 1 sequences
# uncultured_Acidovorax_sp._ERS6626787_filtered.faa: 1 sequences
# uncultured_Acidovorax_sp._ERS6626883_filtered.faa: 1 sequences
# uncultured_Acidovorax_sp._ERS6627009_filtered.faa: 1 sequences
# uncultured_Acidovorax_sp._ERS6627271_filtered.faa: 1 sequences
# uncultured_Acinetobacter_sp._ERS6626821_filtered.faa: 1 sequences
# uncultured_Acinetobacter_sp._ERS6626858_filtered.faa: 1 sequences
# uncultured_Agrobacterium_sp._ERS6626766_filtered.faa: 1 sequences
# uncultured_Aureimonas_sp._ERS6626915_filtered.faa: 3 sequences
# uncultured_Aureimonas_sp._ERS6627306_filtered.faa: 1 sequences
# uncultured_Comamonas_sp._ERS6626602_filtered.faa: 1 sequences
# uncultured_Comamonas_sp._ERS6626630_filtered.faa: 1 sequences
# uncultured_Comamonas_sp._ERS6626638_filtered.faa: 2 sequences
# uncultured_Comamonas_sp._ERS6626814_filtered.faa: 1 sequences
# uncultured_Comamonas_sp._ERS6627283_filtered.faa: 1 sequences
# uncultured_Curtobacterium_sp._ERS6626839_filtered.faa: 1 sequences
# uncultured_Deinococcus_sp._ERS6626797_filtered.faa: 2 sequences
# uncultured_Deinococcus_sp._ERS6626820_filtered.faa: 2 sequences
# uncultured_Deinococcus_sp._ERS6626837_filtered.faa: 1 sequences
# uncultured_Deinococcus_sp._ERS6627293_filtered.faa: 1 sequences
# uncultured_Deinococcus_sp._ERS6627335_filtered.faa: 1 sequences
# uncultured_Hymenobacter_sp._ERS6626733_filtered.faa: 1 sequences
# uncultured_Hymenobacter_sp._ERS6627279_filtered.faa: 1 sequences
# uncultured_Massilia_sp._ERS6627272_filtered.faa: 1 sequences
# uncultured_Methylobacterium_sp._ERS6627288_filtered.faa: 2 sequences
# uncultured_Microbacterium_sp._ERS6626906_filtered.faa: 1 sequences
# uncultured_Microbacterium_sp._ERS6626964_filtered.faa: 1 sequences
# uncultured_Microbacterium_sp._ERS6627334_filtered.faa: 1 sequences
# uncultured_Mucilaginibacter_sp._ERS6626873_filtered.faa: 1 sequences
# uncultured_Mucilaginibacter_sp._ERS6626923_filtered.faa: 1 sequences
# uncultured_Mucilaginibacter_sp._ERS6626962_filtered.faa: 1 sequences
# uncultured_Mucilaginibacter_sp._ERS6626972_filtered.faa: 1 sequences
# uncultured_Mucilaginibacter_sp._ERS6626981_filtered.faa: 1 sequences
# uncultured_Mucilaginibacter_sp._ERS6627275_filtered.faa: 1 sequences
# uncultured_Mucilaginibacter_sp._ERS6627290_filtered.faa: 1 sequences
# uncultured_Pantoea_sp._ERS6626643_filtered.faa: 1 sequences
# uncultured_Pantoea_sp._ERS6627005_filtered.faa: 1 sequences
# uncultured_Pantoea_sp._ERS6627332_filtered.faa: 1 sequences
# uncultured_Pelomonas_sp._ERS6626569_filtered.faa: 1 sequences
# uncultured_Pluralibacter_sp._ERS6626635_filtered.faa: 1 sequences
# uncultured_Pseudacidovorax_sp._ERS6626577_filtered.faa: 1 sequences
# uncultured_Pseudacidovorax_sp._ERS6626850_filtered.faa: 1 sequences
# uncultured_Pseudacidovorax_sp._ERS6626909_filtered.faa: 1 sequences
# uncultured_Pseudacidovorax_sp._ERS6627003_filtered.faa: 2 sequences
# uncultured_Pseudacidovorax_sp._ERS6627320_filtered.faa: 3 sequences
# uncultured_Pseudacidovorax_sp._ERS6627321_filtered.faa: 2 sequences
# uncultured_Pseudomonas_sp._ERS6626621_filtered.faa: 1 sequences
# uncultured_Pseudomonas_sp._ERS6626673_filtered.faa: 1 sequences
# uncultured_Pseudomonas_sp._ERS6626713_filtered.faa: 1 sequences
# uncultured_Pseudomonas_sp._ERS6627273_filtered.faa: 1 sequences
# uncultured_Pseudorhodoferax_sp._ERS6626941_filtered.faa: 1 sequences
# uncultured_Sphingomonas_sp._ERS6626586_filtered.faa: 1 sequences
# uncultured_Sphingomonas_sp._ERS6626612_filtered.faa: 1 sequences
# uncultured_Sphingomonas_sp._ERS6626658_filtered.faa: 1 sequences
# uncultured_Sphingomonas_sp._ERS6626669_filtered.faa: 1 sequences
# uncultured_Sphingomonas_sp._ERS6626680_filtered.faa: 1 sequences
# uncultured_Sphingomonas_sp._ERS6626831_filtered.faa: 1 sequences
# uncultured_Sphingomonas_sp._ERS6626845_filtered.faa: 1 sequences
# uncultured_Sphingomonas_sp._ERS6626927_filtered.faa: 1 sequences
# uncultured_Sphingomonas_sp._ERS6626948_filtered.faa: 1 sequences
# uncultured_Sphingomonas_sp._ERS6626949_filtered.faa: 1 sequences
# uncultured_Sphingomonas_sp._ERS6626957_filtered.faa: 1 sequences
# uncultured_Sphingomonas_sp._ERS6627017_filtered.faa: 1 sequences
# uncultured_Sphingomonas_sp._ERS6627258_filtered.faa: 1 sequences
# uncultured_Sphingomonas_sp._ERS6627261_filtered.faa: 1 sequences
# uncultured_Sphingomonas_sp._ERS6627280_filtered.faa: 2 sequences
# uncultured_Spirosoma_sp._ERS6626983_filtered.faa: 1 sequences
# uncultured_Spirosoma_sp._ERS6627011_filtered.faa: 1 sequences
# uncultured_Stenotrophomonas_sp._ERS6626688_filtered.faa: 1 sequences
# uncultured_Stenotrophomonas_sp._ERS6627319_filtered.faa: 1 sequences
# uncultured_Variovorax_sp._ERS6626779_filtered.faa: 1 sequences
# uncultured_Variovorax_sp._ERS6627246_filtered.faa: 1 sequences
# uncultured_Xanthomonas_sp._ERS6626846_filtered.faa: 1 sequences
# uncultured_Xanthomonas_sp._ERS6627277_filtered.faa: 1 sequences
# Total sequences from all files: 88

# %% [markdown]
# <h3 style="font-family: 'Times New Roman'; font-weight: bold;">
#     For Form 2 BLAST Results with Form 2 MOTIFs
# </h3>

# %%
# Run the extraction
filter_fasta(motif_2_results, motif_2_proteins, motif_2_filtered_proteins, duplicate2)
# Out:
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\Burkholderiaceae_bacterium_ERS6626861_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Acidovorax_sp._ERS6627271_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Acinetobacter_sp._ERS6626821_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Acinetobacter_sp._ERS6626858_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Aureimonas_sp._ERS6626915_filtered.faa
# Duplicate headers saved to: CoxL2_Results/MOTIF/duplicate\uncultured_Aureimonas_sp._ERS6626915_duplicates.txt
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Aureimonas_sp._ERS6627306_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Comamonas_sp._ERS6626630_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Comamonas_sp._ERS6626638_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Comamonas_sp._ERS6626814_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Comamonas_sp._ERS6627283_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Deinococcus_sp._ERS6626797_filtered.faa
# Duplicate headers saved to: CoxL2_Results/MOTIF/duplicate\uncultured_Deinococcus_sp._ERS6626797_duplicates.txt
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Deinococcus_sp._ERS6626820_filtered.faa
# Duplicate headers saved to: CoxL2_Results/MOTIF/duplicate\uncultured_Deinococcus_sp._ERS6626820_duplicates.txt
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Deinococcus_sp._ERS6626837_filtered.faa
# Duplicate headers saved to: CoxL2_Results/MOTIF/duplicate\uncultured_Deinococcus_sp._ERS6626837_duplicates.txt
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Deinococcus_sp._ERS6627293_filtered.faa
# Duplicate headers saved to: CoxL2_Results/MOTIF/duplicate\uncultured_Deinococcus_sp._ERS6627293_duplicates.txt
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Deinococcus_sp._ERS6627335_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Hymenobacter_sp._ERS6626733_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Hymenobacter_sp._ERS6627279_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Methylobacterium_sp._ERS6627288_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Microbacterium_sp._ERS6626906_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Microbacterium_sp._ERS6626964_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Mucilaginibacter_sp._ERS6626873_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Mucilaginibacter_sp._ERS6626923_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Mucilaginibacter_sp._ERS6626962_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Mucilaginibacter_sp._ERS6626972_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Mucilaginibacter_sp._ERS6626981_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Mucilaginibacter_sp._ERS6627275_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Mucilaginibacter_sp._ERS6627290_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Pantoea_sp._ERS6626643_filtered.faa
# Duplicate headers saved to: CoxL2_Results/MOTIF/duplicate\uncultured_Pantoea_sp._ERS6626643_duplicates.txt
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Pantoea_sp._ERS6627005_filtered.faa
# Duplicate headers saved to: CoxL2_Results/MOTIF/duplicate\uncultured_Pantoea_sp._ERS6627005_duplicates.txt
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Pelomonas_sp._ERS6626569_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Pseudacidovorax_sp._ERS6626577_filtered.faa
# Duplicate headers saved to: CoxL2_Results/MOTIF/duplicate\uncultured_Pseudacidovorax_sp._ERS6626577_duplicates.txt
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Pseudacidovorax_sp._ERS6626850_filtered.faa
# Duplicate headers saved to: CoxL2_Results/MOTIF/duplicate\uncultured_Pseudacidovorax_sp._ERS6626850_duplicates.txt
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Pseudacidovorax_sp._ERS6626909_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Pseudacidovorax_sp._ERS6627003_filtered.faa
# Duplicate headers saved to: CoxL2_Results/MOTIF/duplicate\uncultured_Pseudacidovorax_sp._ERS6627003_duplicates.txt
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Pseudacidovorax_sp._ERS6627320_filtered.faa
# Duplicate headers saved to: CoxL2_Results/MOTIF/duplicate\uncultured_Pseudacidovorax_sp._ERS6627320_duplicates.txt
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Pseudacidovorax_sp._ERS6627321_filtered.faa
# Duplicate headers saved to: CoxL2_Results/MOTIF/duplicate\uncultured_Pseudacidovorax_sp._ERS6627321_duplicates.txt
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Pseudomonas_sp._ERS6626673_filtered.faa
# Duplicate headers saved to: CoxL2_Results/MOTIF/duplicate\uncultured_Pseudomonas_sp._ERS6626673_duplicates.txt
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Pseudomonas_sp._ERS6627273_filtered.faa
# Duplicate headers saved to: CoxL2_Results/MOTIF/duplicate\uncultured_Pseudomonas_sp._ERS6627273_duplicates.txt
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Pseudorhodoferax_sp._ERS6626941_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Sphingomonas_sp._ERS6626680_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Sphingomonas_sp._ERS6626831_filtered.faa
# Duplicate headers saved to: CoxL2_Results/MOTIF/duplicate\uncultured_Sphingomonas_sp._ERS6626831_duplicates.txt
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Sphingomonas_sp._ERS6626957_filtered.faa
# Duplicate headers saved to: CoxL2_Results/MOTIF/duplicate\uncultured_Sphingomonas_sp._ERS6626957_duplicates.txt
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Sphingomonas_sp._ERS6627258_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Spirosoma_sp._ERS6627011_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Stenotrophomonas_sp._ERS6626688_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Stenotrophomonas_sp._ERS6627319_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Variovorax_sp._ERS6626779_filtered.faa
# Extracted sequences saved to: CoxL2_Results/MOTIF_filtered_proteins\uncultured_Variovorax_sp._ERS6627246_filtered.faa
# Sequence extraction completed.

# %%
# Get the count of sequences in each .faa file and the total sequences
sequence_counts_2, total_sequences_2 = count_sequences_in_fasta_files(motif_2_filtered_proteins)

# Print the results
for file_name, count in sequence_counts_2.items():
    print(f"{file_name}: {count} sequences")

print(f"Total sequences from all files: {total_sequences_2}")
# Out:
# Burkholderiaceae_bacterium_ERS6626861_filtered.faa: 1 sequences
# uncultured_Acidovorax_sp._ERS6627271_filtered.faa: 1 sequences
# uncultured_Acinetobacter_sp._ERS6626821_filtered.faa: 1 sequences
# uncultured_Acinetobacter_sp._ERS6626858_filtered.faa: 1 sequences
# uncultured_Aureimonas_sp._ERS6626915_filtered.faa: 2 sequences
# uncultured_Aureimonas_sp._ERS6627306_filtered.faa: 1 sequences
# uncultured_Comamonas_sp._ERS6626630_filtered.faa: 1 sequences
# uncultured_Comamonas_sp._ERS6626638_filtered.faa: 2 sequences
# uncultured_Comamonas_sp._ERS6626814_filtered.faa: 1 sequences
# uncultured_Comamonas_sp._ERS6627283_filtered.faa: 1 sequences
# uncultured_Deinococcus_sp._ERS6626797_filtered.faa: 2 sequences
# uncultured_Deinococcus_sp._ERS6626820_filtered.faa: 2 sequences
# uncultured_Deinococcus_sp._ERS6626837_filtered.faa: 1 sequences
# uncultured_Deinococcus_sp._ERS6627293_filtered.faa: 1 sequences
# uncultured_Deinococcus_sp._ERS6627335_filtered.faa: 1 sequences
# uncultured_Hymenobacter_sp._ERS6626733_filtered.faa: 1 sequences
# uncultured_Hymenobacter_sp._ERS6627279_filtered.faa: 1 sequences
# uncultured_Methylobacterium_sp._ERS6627288_filtered.faa: 2 sequences
# uncultured_Microbacterium_sp._ERS6626906_filtered.faa: 1 sequences
# uncultured_Microbacterium_sp._ERS6626964_filtered.faa: 1 sequences
# uncultured_Mucilaginibacter_sp._ERS6626873_filtered.faa: 1 sequences
# uncultured_Mucilaginibacter_sp._ERS6626923_filtered.faa: 1 sequences
# uncultured_Mucilaginibacter_sp._ERS6626962_filtered.faa: 1 sequences
# uncultured_Mucilaginibacter_sp._ERS6626972_filtered.faa: 1 sequences
# uncultured_Mucilaginibacter_sp._ERS6626981_filtered.faa: 1 sequences
# uncultured_Mucilaginibacter_sp._ERS6627275_filtered.faa: 1 sequences
# uncultured_Mucilaginibacter_sp._ERS6627290_filtered.faa: 1 sequences
# uncultured_Pantoea_sp._ERS6626643_filtered.faa: 1 sequences
# uncultured_Pantoea_sp._ERS6627005_filtered.faa: 1 sequences
# uncultured_Pelomonas_sp._ERS6626569_filtered.faa: 1 sequences
# uncultured_Pseudacidovorax_sp._ERS6626577_filtered.faa: 1 sequences
# uncultured_Pseudacidovorax_sp._ERS6626850_filtered.faa: 1 sequences
# uncultured_Pseudacidovorax_sp._ERS6626909_filtered.faa: 1 sequences
# uncultured_Pseudacidovorax_sp._ERS6627003_filtered.faa: 2 sequences
# uncultured_Pseudacidovorax_sp._ERS6627320_filtered.faa: 3 sequences
# uncultured_Pseudacidovorax_sp._ERS6627321_filtered.faa: 2 sequences
# uncultured_Pseudomonas_sp._ERS6626673_filtered.faa: 1 sequences
# uncultured_Pseudomonas_sp._ERS6627273_filtered.faa: 1 sequences
# uncultured_Pseudorhodoferax_sp._ERS6626941_filtered.faa: 1 sequences
# uncultured_Sphingomonas_sp._ERS6626680_filtered.faa: 1 sequences
# uncultured_Sphingomonas_sp._ERS6626831_filtered.faa: 1 sequences
# uncultured_Sphingomonas_sp._ERS6626957_filtered.faa: 1 sequences
# uncultured_Sphingomonas_sp._ERS6627258_filtered.faa: 1 sequences
# uncultured_Spirosoma_sp._ERS6627011_filtered.faa: 1 sequences
# uncultured_Stenotrophomonas_sp._ERS6626688_filtered.faa: 1 sequences
# uncultured_Stenotrophomonas_sp._ERS6627319_filtered.faa: 1 sequences
# uncultured_Variovorax_sp._ERS6626779_filtered.faa: 1 sequences
# uncultured_Variovorax_sp._ERS6627246_filtered.faa: 1 sequences
# Total sequences from all files: 57

# %% [markdown]
# <h2 style="font-family: 'Times New Roman'; font-weight: bold;">
#     Conserved Domain Search
# </h2>

# %% [markdown]
# <h3 style="font-family: 'Times New Roman'; font-weight: bold;">
#     For Form 1 BLAST Results with Form 2 MOTIFs
# </h3>

# %%
# Conserved Domain Search for CoxL Form 1 BLAST outputs with Form 2 MOTIF
conserved_domain_search(motif_1_filtered_proteins, xlm1, cds1, program="blastp", db="cdd")
print(f"Summary CSV created at: {cds1}")
# Out:
# Processing file: Burkholderiaceae_bacterium_ERS6626861_filtered.faa
# Searching CDD for sequence: Genome302_k127_117597_3
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\Burkholderiaceae_bacterium_ERS6626861_filtered.faa_Genome302_k127_117597_3_cdd.xml
# Completed processing file: Burkholderiaceae_bacterium_ERS6626861_filtered.faa
# Processing file: uncultured_Acidovorax_sp._ERS6626735_filtered.faa
# Searching CDD for sequence: Genome176_S3Ck127_734649_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Acidovorax_sp._ERS6626735_filtered.faa_Genome176_S3Ck127_734649_1_cdd.xml
# Completed processing file: uncultured_Acidovorax_sp._ERS6626735_filtered.faa
# Processing file: uncultured_Acidovorax_sp._ERS6626737_filtered.faa
# Searching CDD for sequence: Genome178_S3Ck127_362732_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Acidovorax_sp._ERS6626737_filtered.faa_Genome178_S3Ck127_362732_1_cdd.xml
# Completed processing file: uncultured_Acidovorax_sp._ERS6626737_filtered.faa
# Processing file: uncultured_Acidovorax_sp._ERS6626738_filtered.faa
# Searching CDD for sequence: Genome179_S1Ck127_19581_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Acidovorax_sp._ERS6626738_filtered.faa_Genome179_S1Ck127_19581_1_cdd.xml
# Completed processing file: uncultured_Acidovorax_sp._ERS6626738_filtered.faa
# Processing file: uncultured_Acidovorax_sp._ERS6626883_filtered.faa
# Searching CDD for sequence: Genome324_k127_296804_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Acidovorax_sp._ERS6626883_filtered.faa_Genome324_k127_296804_1_cdd.xml
# Completed processing file: uncultured_Acidovorax_sp._ERS6626883_filtered.faa
# Processing file: uncultured_Acidovorax_sp._ERS6627009_filtered.faa
# Searching CDD for sequence: Genome450_k127_141799_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Acidovorax_sp._ERS6627009_filtered.faa_Genome450_k127_141799_1_cdd.xml
# Completed processing file: uncultured_Acidovorax_sp._ERS6627009_filtered.faa
# Processing file: uncultured_Acidovorax_sp._ERS6627271_filtered.faa
# Searching CDD for sequence: Genome495_k127_317059_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Acidovorax_sp._ERS6627271_filtered.faa_Genome495_k127_317059_1_cdd.xml
# Completed processing file: uncultured_Acidovorax_sp._ERS6627271_filtered.faa
# Processing file: uncultured_Acinetobacter_sp._ERS6626821_filtered.faa
# Searching CDD for sequence: Genome262_k127_235961_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Acinetobacter_sp._ERS6626821_filtered.faa_Genome262_k127_235961_1_cdd.xml
# Completed processing file: uncultured_Acinetobacter_sp._ERS6626821_filtered.faa
# Processing file: uncultured_Acinetobacter_sp._ERS6626858_filtered.faa
# Searching CDD for sequence: Genome299_k127_417201_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V5U9FKUN016 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF1/xlm\uncultured_Acinetobacter_sp._ERS6626858_filtered.faa_Genome299_k127_417201_1_cdd.xml
# Completed processing file: uncultured_Acinetobacter_sp._ERS6626858_filtered.faa
# Processing file: uncultured_Aureimonas_sp._ERS6626915_filtered.faa
# Searching CDD for sequence: Genome356_k127_610672_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Aureimonas_sp._ERS6626915_filtered.faa_Genome356_k127_610672_1_cdd.xml
# Searching CDD for sequence: Genome356_k127_498042_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Aureimonas_sp._ERS6626915_filtered.faa_Genome356_k127_498042_1_cdd.xml
# Completed processing file: uncultured_Aureimonas_sp._ERS6626915_filtered.faa
# Processing file: uncultured_Aureimonas_sp._ERS6627306_filtered.faa
# Searching CDD for sequence: Genome530_k127_16854_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Aureimonas_sp._ERS6627306_filtered.faa_Genome530_k127_16854_1_cdd.xml
# Completed processing file: uncultured_Aureimonas_sp._ERS6627306_filtered.faa
# Processing file: uncultured_Comamonas_sp._ERS6626602_filtered.faa
# Searching CDD for sequence: Genome43_S3Ck127_66545_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Comamonas_sp._ERS6626602_filtered.faa_Genome43_S3Ck127_66545_1_cdd.xml
# Completed processing file: uncultured_Comamonas_sp._ERS6626602_filtered.faa
# Processing file: uncultured_Comamonas_sp._ERS6626630_filtered.faa
# Searching CDD for sequence: Genome71_S1Ck127_18694_2
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Comamonas_sp._ERS6626630_filtered.faa_Genome71_S1Ck127_18694_2_cdd.xml
# Completed processing file: uncultured_Comamonas_sp._ERS6626630_filtered.faa
# Processing file: uncultured_Comamonas_sp._ERS6627283_filtered.faa
# Searching CDD for sequence: Genome507_k127_91973_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V5VZM7EK013 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF1/xlm\uncultured_Comamonas_sp._ERS6627283_filtered.faa_Genome507_k127_91973_1_cdd.xml
# Completed processing file: uncultured_Comamonas_sp._ERS6627283_filtered.faa
# Processing file: uncultured_Curtobacterium_sp._ERS6626839_filtered.faa
# Searching CDD for sequence: Genome280_k127_966990_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Curtobacterium_sp._ERS6626839_filtered.faa_Genome280_k127_966990_1_cdd.xml
# Completed processing file: uncultured_Curtobacterium_sp._ERS6626839_filtered.faa
# Processing file: uncultured_Deinococcus_sp._ERS6626797_filtered.faa
# Searching CDD for sequence: Genome238_k127_54530_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Deinococcus_sp._ERS6626797_filtered.faa_Genome238_k127_54530_1_cdd.xml
# Searching CDD for sequence: Genome238_k127_17753_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Deinococcus_sp._ERS6626797_filtered.faa_Genome238_k127_17753_1_cdd.xml
# Completed processing file: uncultured_Deinococcus_sp._ERS6626797_filtered.faa
# Processing file: uncultured_Deinococcus_sp._ERS6626820_filtered.faa
# Searching CDD for sequence: Genome261_k127_146972_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Deinococcus_sp._ERS6626820_filtered.faa_Genome261_k127_146972_1_cdd.xml
# Searching CDD for sequence: Genome261_k127_332399_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Deinococcus_sp._ERS6626820_filtered.faa_Genome261_k127_332399_1_cdd.xml
# Completed processing file: uncultured_Deinococcus_sp._ERS6626820_filtered.faa
# Processing file: uncultured_Deinococcus_sp._ERS6626837_filtered.faa
# Searching CDD for sequence: Genome278_k127_88725_3
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Deinococcus_sp._ERS6626837_filtered.faa_Genome278_k127_88725_3_cdd.xml
# Searching CDD for sequence: Genome278_k127_93298_2
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Deinococcus_sp._ERS6626837_filtered.faa_Genome278_k127_93298_2_cdd.xml
# Completed processing file: uncultured_Deinococcus_sp._ERS6626837_filtered.faa
# Processing file: uncultured_Deinococcus_sp._ERS6627293_filtered.faa
# Searching CDD for sequence: Genome517_k127_348199_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V5XNBMYM016 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF1/xlm\uncultured_Deinococcus_sp._ERS6627293_filtered.faa_Genome517_k127_348199_1_cdd.xml
# Completed processing file: uncultured_Deinococcus_sp._ERS6627293_filtered.faa
# Processing file: uncultured_Deinococcus_sp._ERS6627335_filtered.faa
# Searching CDD for sequence: Genome559_k127_243715_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Deinococcus_sp._ERS6627335_filtered.faa_Genome559_k127_243715_1_cdd.xml
# Completed processing file: uncultured_Deinococcus_sp._ERS6627335_filtered.faa
# Processing file: uncultured_Hymenobacter_sp._ERS6626733_filtered.faa
# Searching CDD for sequence: Genome174_S1Ck127_276112_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Hymenobacter_sp._ERS6626733_filtered.faa_Genome174_S1Ck127_276112_1_cdd.xml
# Completed processing file: uncultured_Hymenobacter_sp._ERS6626733_filtered.faa
# Processing file: uncultured_Hymenobacter_sp._ERS6627279_filtered.faa
# Searching CDD for sequence: Genome503_k127_453582_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Hymenobacter_sp._ERS6627279_filtered.faa_Genome503_k127_453582_1_cdd.xml
# Completed processing file: uncultured_Hymenobacter_sp._ERS6627279_filtered.faa
# Processing file: uncultured_Massilia_sp._ERS6627272_filtered.faa
# Searching CDD for sequence: Genome496_k127_402689_5
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Massilia_sp._ERS6627272_filtered.faa_Genome496_k127_402689_5_cdd.xml
# Completed processing file: uncultured_Massilia_sp._ERS6627272_filtered.faa
# Processing file: uncultured_Methylobacterium_sp._ERS6627288_filtered.faa
# Searching CDD for sequence: Genome512_k127_80099_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Methylobacterium_sp._ERS6627288_filtered.faa_Genome512_k127_80099_1_cdd.xml
# Searching CDD for sequence: Genome512_k127_160927_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Methylobacterium_sp._ERS6627288_filtered.faa_Genome512_k127_160927_1_cdd.xml
# Completed processing file: uncultured_Methylobacterium_sp._ERS6627288_filtered.faa
# Processing file: uncultured_Microbacterium_sp._ERS6626906_filtered.faa
# Searching CDD for sequence: Genome347_k127_84820_2
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Microbacterium_sp._ERS6626906_filtered.faa_Genome347_k127_84820_2_cdd.xml
# Completed processing file: uncultured_Microbacterium_sp._ERS6626906_filtered.faa
# Processing file: uncultured_Microbacterium_sp._ERS6626964_filtered.faa
# Searching CDD for sequence: Genome405_k127_107645_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Microbacterium_sp._ERS6626964_filtered.faa_Genome405_k127_107645_1_cdd.xml
# Completed processing file: uncultured_Microbacterium_sp._ERS6626964_filtered.faa
# Processing file: uncultured_Microbacterium_sp._ERS6627334_filtered.faa
# Searching CDD for sequence: Genome558_k127_281833_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V6060RZX016 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF1/xlm\uncultured_Microbacterium_sp._ERS6627334_filtered.faa_Genome558_k127_281833_1_cdd.xml
# Completed processing file: uncultured_Microbacterium_sp._ERS6627334_filtered.faa
# Processing file: uncultured_Mucilaginibacter_sp._ERS6626873_filtered.faa
# Searching CDD for sequence: Genome314_k127_168730_2
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V612RKJ9016 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF1/xlm\uncultured_Mucilaginibacter_sp._ERS6626873_filtered.faa_Genome314_k127_168730_2_cdd.xml
# Completed processing file: uncultured_Mucilaginibacter_sp._ERS6626873_filtered.faa
# Processing file: uncultured_Mucilaginibacter_sp._ERS6626923_filtered.faa
# Searching CDD for sequence: Genome364_k127_154890_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Mucilaginibacter_sp._ERS6626923_filtered.faa_Genome364_k127_154890_1_cdd.xml
# Completed processing file: uncultured_Mucilaginibacter_sp._ERS6626923_filtered.faa
# Processing file: uncultured_Mucilaginibacter_sp._ERS6626962_filtered.faa
# Searching CDD for sequence: Genome403_k127_249621_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Mucilaginibacter_sp._ERS6626962_filtered.faa_Genome403_k127_249621_1_cdd.xml
# Completed processing file: uncultured_Mucilaginibacter_sp._ERS6626962_filtered.faa
# Processing file: uncultured_Mucilaginibacter_sp._ERS6626972_filtered.faa
# Searching CDD for sequence: Genome413_k127_255610_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Mucilaginibacter_sp._ERS6626972_filtered.faa_Genome413_k127_255610_1_cdd.xml
# Completed processing file: uncultured_Mucilaginibacter_sp._ERS6626972_filtered.faa
# Processing file: uncultured_Mucilaginibacter_sp._ERS6626981_filtered.faa
# Searching CDD for sequence: Genome422_k127_88665_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Mucilaginibacter_sp._ERS6626981_filtered.faa_Genome422_k127_88665_1_cdd.xml
# Completed processing file: uncultured_Mucilaginibacter_sp._ERS6626981_filtered.faa
# Processing file: uncultured_Mucilaginibacter_sp._ERS6627275_filtered.faa
# Searching CDD for sequence: Genome499_k127_471593_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V635K90G016 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF1/xlm\uncultured_Mucilaginibacter_sp._ERS6627275_filtered.faa_Genome499_k127_471593_1_cdd.xml
# Completed processing file: uncultured_Mucilaginibacter_sp._ERS6627275_filtered.faa
# Processing file: uncultured_Mucilaginibacter_sp._ERS6627290_filtered.faa
# Searching CDD for sequence: Genome514_k127_4285_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V63WSERG016 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF1/xlm\uncultured_Mucilaginibacter_sp._ERS6627290_filtered.faa_Genome514_k127_4285_1_cdd.xml
# Completed processing file: uncultured_Mucilaginibacter_sp._ERS6627290_filtered.faa
# Processing file: uncultured_Pantoea_sp._ERS6627005_filtered.faa
# Searching CDD for sequence: Genome446_k127_627589_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Pantoea_sp._ERS6627005_filtered.faa_Genome446_k127_627589_1_cdd.xml
# Completed processing file: uncultured_Pantoea_sp._ERS6627005_filtered.faa
# Processing file: uncultured_Pantoea_sp._ERS6627332_filtered.faa
# Searching CDD for sequence: Genome556_k127_19993_2
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V64VZB12016 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF1/xlm\uncultured_Pantoea_sp._ERS6627332_filtered.faa_Genome556_k127_19993_2_cdd.xml
# Completed processing file: uncultured_Pantoea_sp._ERS6627332_filtered.faa
# Processing file: uncultured_Pseudacidovorax_sp._ERS6626577_filtered.faa
# Searching CDD for sequence: Genome18_S1Ck127_217968_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Pseudacidovorax_sp._ERS6626577_filtered.faa_Genome18_S1Ck127_217968_1_cdd.xml
# Searching CDD for sequence: Genome18_S1Ck127_178435_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Pseudacidovorax_sp._ERS6626577_filtered.faa_Genome18_S1Ck127_178435_1_cdd.xml
# Completed processing file: uncultured_Pseudacidovorax_sp._ERS6626577_filtered.faa
# Processing file: uncultured_Pseudacidovorax_sp._ERS6626850_filtered.faa
# Searching CDD for sequence: Genome291_k127_419550_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Pseudacidovorax_sp._ERS6626850_filtered.faa_Genome291_k127_419550_1_cdd.xml
# Completed processing file: uncultured_Pseudacidovorax_sp._ERS6626850_filtered.faa
# Processing file: uncultured_Pseudacidovorax_sp._ERS6626909_filtered.faa
# Searching CDD for sequence: Genome350_k127_213661_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Pseudacidovorax_sp._ERS6626909_filtered.faa_Genome350_k127_213661_1_cdd.xml
# Searching CDD for sequence: Genome350_k127_213661_2
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Pseudacidovorax_sp._ERS6626909_filtered.faa_Genome350_k127_213661_2_cdd.xml
# Completed processing file: uncultured_Pseudacidovorax_sp._ERS6626909_filtered.faa
# Processing file: uncultured_Pseudacidovorax_sp._ERS6627003_filtered.faa
# Searching CDD for sequence: Genome444_k127_2949_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Pseudacidovorax_sp._ERS6627003_filtered.faa_Genome444_k127_2949_1_cdd.xml
# Searching CDD for sequence: Genome444_k127_25498_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Pseudacidovorax_sp._ERS6627003_filtered.faa_Genome444_k127_25498_1_cdd.xml
# Completed processing file: uncultured_Pseudacidovorax_sp._ERS6627003_filtered.faa
# Processing file: uncultured_Pseudacidovorax_sp._ERS6627320_filtered.faa
# Searching CDD for sequence: Genome544_k127_977136_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Pseudacidovorax_sp._ERS6627320_filtered.faa_Genome544_k127_977136_1_cdd.xml
# Searching CDD for sequence: Genome544_k127_833201_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Pseudacidovorax_sp._ERS6627320_filtered.faa_Genome544_k127_833201_1_cdd.xml
# Searching CDD for sequence: Genome544_k127_857444_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V67JVF0B016 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF1/xlm\uncultured_Pseudacidovorax_sp._ERS6627320_filtered.faa_Genome544_k127_857444_1_cdd.xml
# Completed processing file: uncultured_Pseudacidovorax_sp._ERS6627320_filtered.faa
# Processing file: uncultured_Pseudacidovorax_sp._ERS6627321_filtered.faa
# Searching CDD for sequence: Genome545_k127_344480_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Pseudacidovorax_sp._ERS6627321_filtered.faa_Genome545_k127_344480_1_cdd.xml
# Searching CDD for sequence: Genome545_k127_208535_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Pseudacidovorax_sp._ERS6627321_filtered.faa_Genome545_k127_208535_1_cdd.xml
# Completed processing file: uncultured_Pseudacidovorax_sp._ERS6627321_filtered.faa
# Processing file: uncultured_Pseudomonas_sp._ERS6626621_filtered.faa
# Searching CDD for sequence: Genome62_S2Ck127_218854_6
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Pseudomonas_sp._ERS6626621_filtered.faa_Genome62_S2Ck127_218854_6_cdd.xml
# Completed processing file: uncultured_Pseudomonas_sp._ERS6626621_filtered.faa
# Processing file: uncultured_Pseudomonas_sp._ERS6626673_filtered.faa
# Searching CDD for sequence: Genome114_S3Ck127_13141_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Pseudomonas_sp._ERS6626673_filtered.faa_Genome114_S3Ck127_13141_1_cdd.xml
# Completed processing file: uncultured_Pseudomonas_sp._ERS6626673_filtered.faa
# Processing file: uncultured_Pseudomonas_sp._ERS6626713_filtered.faa
# Searching CDD for sequence: Genome154_S3Ck127_221454_4
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V6913NKV016 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF1/xlm\uncultured_Pseudomonas_sp._ERS6626713_filtered.faa_Genome154_S3Ck127_221454_4_cdd.xml
# Completed processing file: uncultured_Pseudomonas_sp._ERS6626713_filtered.faa
# Processing file: uncultured_Pseudomonas_sp._ERS6627273_filtered.faa
# Searching CDD for sequence: Genome497_k127_28836_2
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Pseudomonas_sp._ERS6627273_filtered.faa_Genome497_k127_28836_2_cdd.xml
# Completed processing file: uncultured_Pseudomonas_sp._ERS6627273_filtered.faa
# Processing file: uncultured_Pseudorhodoferax_sp._ERS6626941_filtered.faa
# Searching CDD for sequence: Genome382_k127_146993_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Pseudorhodoferax_sp._ERS6626941_filtered.faa_Genome382_k127_146993_1_cdd.xml
# Completed processing file: uncultured_Pseudorhodoferax_sp._ERS6626941_filtered.faa
# Processing file: uncultured_Sphingomonas_sp._ERS6626586_filtered.faa
# Searching CDD for sequence: Genome27_S3Ck127_309455_2
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Sphingomonas_sp._ERS6626586_filtered.faa_Genome27_S3Ck127_309455_2_cdd.xml
# Searching CDD for sequence: Genome27_S3Ck127_549998_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V6AGKC17016 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF1/xlm\uncultured_Sphingomonas_sp._ERS6626586_filtered.faa_Genome27_S3Ck127_549998_1_cdd.xml
# Completed processing file: uncultured_Sphingomonas_sp._ERS6626586_filtered.faa
# Processing file: uncultured_Sphingomonas_sp._ERS6626658_filtered.faa
# Searching CDD for sequence: Genome99_S1Ck127_187716_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V6BDC9DC016 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF1/xlm\uncultured_Sphingomonas_sp._ERS6626658_filtered.faa_Genome99_S1Ck127_187716_1_cdd.xml
# Completed processing file: uncultured_Sphingomonas_sp._ERS6626658_filtered.faa
# Processing file: uncultured_Sphingomonas_sp._ERS6626669_filtered.faa
# Searching CDD for sequence: Genome110_S3Ck127_116759_5
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Sphingomonas_sp._ERS6626669_filtered.faa_Genome110_S3Ck127_116759_5_cdd.xml
# Searching CDD for sequence: Genome110_S3Ck127_256731_4
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Sphingomonas_sp._ERS6626669_filtered.faa_Genome110_S3Ck127_256731_4_cdd.xml
# Completed processing file: uncultured_Sphingomonas_sp._ERS6626669_filtered.faa
# Processing file: uncultured_Sphingomonas_sp._ERS6626831_filtered.faa
# Searching CDD for sequence: Genome272_k127_58089_2
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Sphingomonas_sp._ERS6626831_filtered.faa_Genome272_k127_58089_2_cdd.xml
# Completed processing file: uncultured_Sphingomonas_sp._ERS6626831_filtered.faa
# Processing file: uncultured_Sphingomonas_sp._ERS6626949_filtered.faa
# Searching CDD for sequence: Genome390_k127_480041_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Sphingomonas_sp._ERS6626949_filtered.faa_Genome390_k127_480041_1_cdd.xml
# Completed processing file: uncultured_Sphingomonas_sp._ERS6626949_filtered.faa
# Processing file: uncultured_Sphingomonas_sp._ERS6627017_filtered.faa
# Searching CDD for sequence: Genome458_k127_153741_6
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Sphingomonas_sp._ERS6627017_filtered.faa_Genome458_k127_153741_6_cdd.xml
# Completed processing file: uncultured_Sphingomonas_sp._ERS6627017_filtered.faa
# Processing file: uncultured_Sphingomonas_sp._ERS6627258_filtered.faa
# Searching CDD for sequence: Genome482_k127_81292_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V6D1VWE7016 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF1/xlm\uncultured_Sphingomonas_sp._ERS6627258_filtered.faa_Genome482_k127_81292_1_cdd.xml
# Completed processing file: uncultured_Sphingomonas_sp._ERS6627258_filtered.faa
# Processing file: uncultured_Sphingomonas_sp._ERS6627261_filtered.faa
# Searching CDD for sequence: Genome485_k127_83547_3
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V6EN3BEU016 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF1/xlm\uncultured_Sphingomonas_sp._ERS6627261_filtered.faa_Genome485_k127_83547_3_cdd.xml
# Completed processing file: uncultured_Sphingomonas_sp._ERS6627261_filtered.faa
# Processing file: uncultured_Sphingomonas_sp._ERS6627280_filtered.faa
# Searching CDD for sequence: Genome504_k127_368_4
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Sphingomonas_sp._ERS6627280_filtered.faa_Genome504_k127_368_4_cdd.xml
# Searching CDD for sequence: Genome504_k127_368_1
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Sphingomonas_sp._ERS6627280_filtered.faa_Genome504_k127_368_1_cdd.xml
# Completed processing file: uncultured_Sphingomonas_sp._ERS6627280_filtered.faa
# Processing file: uncultured_Variovorax_sp._ERS6626779_filtered.faa
# Searching CDD for sequence: Genome220_k127_244806_3
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Variovorax_sp._ERS6626779_filtered.faa_Genome220_k127_244806_3_cdd.xml
# Completed processing file: uncultured_Variovorax_sp._ERS6626779_filtered.faa
# Processing file: uncultured_Variovorax_sp._ERS6627246_filtered.faa
# Searching CDD for sequence: Genome470_k127_43488_2
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Variovorax_sp._ERS6627246_filtered.faa_Genome470_k127_43488_2_cdd.xml
# Completed processing file: uncultured_Variovorax_sp._ERS6627246_filtered.faa
# Processing file: uncultured_Xanthomonas_sp._ERS6626846_filtered.faa
# Searching CDD for sequence: Genome287_k127_622465_6
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Xanthomonas_sp._ERS6626846_filtered.faa_Genome287_k127_622465_6_cdd.xml
# Completed processing file: uncultured_Xanthomonas_sp._ERS6626846_filtered.faa
# Processing file: uncultured_Xanthomonas_sp._ERS6627277_filtered.faa
# Searching CDD for sequence: Genome501_k127_283599_7
# Attempt 1 for sequence.
# Results saved to: MOTIF1/xlm\uncultured_Xanthomonas_sp._ERS6627277_filtered.faa_Genome501_k127_283599_7_cdd.xml
# Completed processing file: uncultured_Xanthomonas_sp._ERS6627277_filtered.faa
# Summary CSV created at: MOTIF1/cds1.csv

# %% [markdown]
# <h3 style="font-family: 'Times New Roman'; font-weight: bold;">
#     For Form 2 BLAST Results with Form 2 MOTIFs
# </h3>

# %%
conserved_domain_search(motif_2_filtered_proteins, xlm2, cds2, program="blastp", db="cdd")
print(f"Summary CSV created at: {cds2}")
# Out:
# Processing file: Burkholderiaceae_bacterium_ERS6626861_filtered.faa
# Searching CDD for sequence: Genome302_k127_117597_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V4UGSV2W013 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF2/xlm\Burkholderiaceae_bacterium_ERS6626861_filtered.faa_Genome302_k127_117597_1_cdd.xml
# Completed processing file: Burkholderiaceae_bacterium_ERS6626861_filtered.faa
# Processing file: uncultured_Acidovorax_sp._ERS6627271_filtered.faa
# Searching CDD for sequence: Genome495_k127_317059_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V4V95HRV013 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF2/xlm\uncultured_Acidovorax_sp._ERS6627271_filtered.faa_Genome495_k127_317059_1_cdd.xml
# Completed processing file: uncultured_Acidovorax_sp._ERS6627271_filtered.faa
# Processing file: uncultured_Acinetobacter_sp._ERS6626821_filtered.faa
# Searching CDD for sequence: Genome262_k127_235961_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Acinetobacter_sp._ERS6626821_filtered.faa_Genome262_k127_235961_1_cdd.xml
# Completed processing file: uncultured_Acinetobacter_sp._ERS6626821_filtered.faa
# Processing file: uncultured_Acinetobacter_sp._ERS6626858_filtered.faa
# Searching CDD for sequence: Genome299_k127_417201_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Acinetobacter_sp._ERS6626858_filtered.faa_Genome299_k127_417201_1_cdd.xml
# Completed processing file: uncultured_Acinetobacter_sp._ERS6626858_filtered.faa
# Processing file: uncultured_Aureimonas_sp._ERS6626915_filtered.faa
# Searching CDD for sequence: Genome356_k127_610672_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V4WXNA3J013 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF2/xlm\uncultured_Aureimonas_sp._ERS6626915_filtered.faa_Genome356_k127_610672_1_cdd.xml
# Searching CDD for sequence: Genome356_k127_498042_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Aureimonas_sp._ERS6626915_filtered.faa_Genome356_k127_498042_1_cdd.xml
# Completed processing file: uncultured_Aureimonas_sp._ERS6626915_filtered.faa
# Processing file: uncultured_Aureimonas_sp._ERS6627306_filtered.faa
# Searching CDD for sequence: Genome530_k127_16854_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Aureimonas_sp._ERS6627306_filtered.faa_Genome530_k127_16854_1_cdd.xml
# Completed processing file: uncultured_Aureimonas_sp._ERS6627306_filtered.faa
# Processing file: uncultured_Comamonas_sp._ERS6626630_filtered.faa
# Searching CDD for sequence: Genome71_S1Ck127_18694_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V4XVN81D013 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF2/xlm\uncultured_Comamonas_sp._ERS6626630_filtered.faa_Genome71_S1Ck127_18694_1_cdd.xml
# Completed processing file: uncultured_Comamonas_sp._ERS6626630_filtered.faa
# Processing file: uncultured_Comamonas_sp._ERS6626638_filtered.faa
# Searching CDD for sequence: Genome79_S3Ck127_287303_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V4YSDNBJ013 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF2/xlm\uncultured_Comamonas_sp._ERS6626638_filtered.faa_Genome79_S3Ck127_287303_1_cdd.xml
# Searching CDD for sequence: Genome79_S3Ck127_287303_3
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Comamonas_sp._ERS6626638_filtered.faa_Genome79_S3Ck127_287303_3_cdd.xml
# Completed processing file: uncultured_Comamonas_sp._ERS6626638_filtered.faa
# Processing file: uncultured_Comamonas_sp._ERS6626814_filtered.faa
# Searching CDD for sequence: Genome255_k127_46261_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Comamonas_sp._ERS6626814_filtered.faa_Genome255_k127_46261_1_cdd.xml
# Completed processing file: uncultured_Comamonas_sp._ERS6626814_filtered.faa
# Processing file: uncultured_Comamonas_sp._ERS6627283_filtered.faa
# Searching CDD for sequence: Genome507_k127_91973_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Comamonas_sp._ERS6627283_filtered.faa_Genome507_k127_91973_1_cdd.xml
# Completed processing file: uncultured_Comamonas_sp._ERS6627283_filtered.faa
# Processing file: uncultured_Deinococcus_sp._ERS6626797_filtered.faa
# Searching CDD for sequence: Genome238_k127_54530_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V5141MAZ016 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Attempt 1 failed: <urlopen error [WinError 10053] An established connection was aborted by the software in your host machine>
# Attempt 2 for sequence.
# Attempt 2 failed: <urlopen error [Errno 11001] getaddrinfo failed>
# Attempt 3 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Deinococcus_sp._ERS6626797_filtered.faa_Genome238_k127_54530_1_cdd.xml
# Searching CDD for sequence: Genome238_k127_17753_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V52CNY22016 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF2/xlm\uncultured_Deinococcus_sp._ERS6626797_filtered.faa_Genome238_k127_17753_1_cdd.xml
# Completed processing file: uncultured_Deinococcus_sp._ERS6626797_filtered.faa
# Processing file: uncultured_Deinococcus_sp._ERS6626820_filtered.faa
# Searching CDD for sequence: Genome261_k127_146972_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Deinococcus_sp._ERS6626820_filtered.faa_Genome261_k127_146972_1_cdd.xml
# Searching CDD for sequence: Genome261_k127_332399_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Deinococcus_sp._ERS6626820_filtered.faa_Genome261_k127_332399_1_cdd.xml
# Completed processing file: uncultured_Deinococcus_sp._ERS6626820_filtered.faa
# Processing file: uncultured_Deinococcus_sp._ERS6626837_filtered.faa
# Searching CDD for sequence: Genome278_k127_93298_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Deinococcus_sp._ERS6626837_filtered.faa_Genome278_k127_93298_1_cdd.xml
# Completed processing file: uncultured_Deinococcus_sp._ERS6626837_filtered.faa
# Processing file: uncultured_Deinococcus_sp._ERS6627293_filtered.faa
# Searching CDD for sequence: Genome517_k127_348199_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Deinococcus_sp._ERS6627293_filtered.faa_Genome517_k127_348199_1_cdd.xml
# Completed processing file: uncultured_Deinococcus_sp._ERS6627293_filtered.faa
# Processing file: uncultured_Deinococcus_sp._ERS6627335_filtered.faa
# Searching CDD for sequence: Genome559_k127_243715_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Deinococcus_sp._ERS6627335_filtered.faa_Genome559_k127_243715_1_cdd.xml
# Completed processing file: uncultured_Deinococcus_sp._ERS6627335_filtered.faa
# Processing file: uncultured_Hymenobacter_sp._ERS6626733_filtered.faa
# Searching CDD for sequence: Genome174_S1Ck127_276112_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Hymenobacter_sp._ERS6626733_filtered.faa_Genome174_S1Ck127_276112_1_cdd.xml
# Completed processing file: uncultured_Hymenobacter_sp._ERS6626733_filtered.faa
# Processing file: uncultured_Hymenobacter_sp._ERS6627279_filtered.faa
# Searching CDD for sequence: Genome503_k127_453582_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Hymenobacter_sp._ERS6627279_filtered.faa_Genome503_k127_453582_1_cdd.xml
# Completed processing file: uncultured_Hymenobacter_sp._ERS6627279_filtered.faa
# Processing file: uncultured_Methylobacterium_sp._ERS6627288_filtered.faa
# Searching CDD for sequence: Genome512_k127_80099_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Methylobacterium_sp._ERS6627288_filtered.faa_Genome512_k127_80099_1_cdd.xml
# Searching CDD for sequence: Genome512_k127_160927_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Methylobacterium_sp._ERS6627288_filtered.faa_Genome512_k127_160927_1_cdd.xml
# Completed processing file: uncultured_Methylobacterium_sp._ERS6627288_filtered.faa
# Processing file: uncultured_Microbacterium_sp._ERS6626906_filtered.faa
# Searching CDD for sequence: Genome347_k127_84820_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Microbacterium_sp._ERS6626906_filtered.faa_Genome347_k127_84820_1_cdd.xml
# Completed processing file: uncultured_Microbacterium_sp._ERS6626906_filtered.faa
# Processing file: uncultured_Microbacterium_sp._ERS6626964_filtered.faa
# Searching CDD for sequence: Genome405_k127_107645_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Microbacterium_sp._ERS6626964_filtered.faa_Genome405_k127_107645_1_cdd.xml
# Completed processing file: uncultured_Microbacterium_sp._ERS6626964_filtered.faa
# Processing file: uncultured_Mucilaginibacter_sp._ERS6626873_filtered.faa
# Searching CDD for sequence: Genome314_k127_168730_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Mucilaginibacter_sp._ERS6626873_filtered.faa_Genome314_k127_168730_1_cdd.xml
# Completed processing file: uncultured_Mucilaginibacter_sp._ERS6626873_filtered.faa
# Processing file: uncultured_Mucilaginibacter_sp._ERS6626923_filtered.faa
# Searching CDD for sequence: Genome364_k127_154890_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V58M1P2C013 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF2/xlm\uncultured_Mucilaginibacter_sp._ERS6626923_filtered.faa_Genome364_k127_154890_1_cdd.xml
# Completed processing file: uncultured_Mucilaginibacter_sp._ERS6626923_filtered.faa
# Processing file: uncultured_Mucilaginibacter_sp._ERS6626962_filtered.faa
# Searching CDD for sequence: Genome403_k127_249621_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Mucilaginibacter_sp._ERS6626962_filtered.faa_Genome403_k127_249621_1_cdd.xml
# Completed processing file: uncultured_Mucilaginibacter_sp._ERS6626962_filtered.faa
# Processing file: uncultured_Mucilaginibacter_sp._ERS6626972_filtered.faa
# Searching CDD for sequence: Genome413_k127_255610_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Mucilaginibacter_sp._ERS6626972_filtered.faa_Genome413_k127_255610_1_cdd.xml
# Completed processing file: uncultured_Mucilaginibacter_sp._ERS6626972_filtered.faa
# Processing file: uncultured_Mucilaginibacter_sp._ERS6626981_filtered.faa
# Searching CDD for sequence: Genome422_k127_88665_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Mucilaginibacter_sp._ERS6626981_filtered.faa_Genome422_k127_88665_1_cdd.xml
# Completed processing file: uncultured_Mucilaginibacter_sp._ERS6626981_filtered.faa
# Processing file: uncultured_Mucilaginibacter_sp._ERS6627275_filtered.faa
# Searching CDD for sequence: Genome499_k127_471593_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Mucilaginibacter_sp._ERS6627275_filtered.faa_Genome499_k127_471593_1_cdd.xml
# Completed processing file: uncultured_Mucilaginibacter_sp._ERS6627275_filtered.faa
# Processing file: uncultured_Mucilaginibacter_sp._ERS6627290_filtered.faa
# Searching CDD for sequence: Genome514_k127_4285_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V59X4KAV013 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF2/xlm\uncultured_Mucilaginibacter_sp._ERS6627290_filtered.faa_Genome514_k127_4285_1_cdd.xml
# Completed processing file: uncultured_Mucilaginibacter_sp._ERS6627290_filtered.faa
# Processing file: uncultured_Pantoea_sp._ERS6626643_filtered.faa
# Searching CDD for sequence: Genome84_S2Ck127_371734_2
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V5BFXBAW013 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF2/xlm\uncultured_Pantoea_sp._ERS6626643_filtered.faa_Genome84_S2Ck127_371734_2_cdd.xml
# Completed processing file: uncultured_Pantoea_sp._ERS6626643_filtered.faa
# Processing file: uncultured_Pantoea_sp._ERS6627005_filtered.faa
# Searching CDD for sequence: Genome446_k127_205538_3
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Pantoea_sp._ERS6627005_filtered.faa_Genome446_k127_205538_3_cdd.xml
# Completed processing file: uncultured_Pantoea_sp._ERS6627005_filtered.faa
# Processing file: uncultured_Pelomonas_sp._ERS6626569_filtered.faa
# Searching CDD for sequence: Genome10_S2Ck127_387977_3
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V5CUDBPY013 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF2/xlm\uncultured_Pelomonas_sp._ERS6626569_filtered.faa_Genome10_S2Ck127_387977_3_cdd.xml
# Completed processing file: uncultured_Pelomonas_sp._ERS6626569_filtered.faa
# Processing file: uncultured_Pseudacidovorax_sp._ERS6626577_filtered.faa
# Searching CDD for sequence: Genome18_S1Ck127_217968_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Pseudacidovorax_sp._ERS6626577_filtered.faa_Genome18_S1Ck127_217968_1_cdd.xml
# Completed processing file: uncultured_Pseudacidovorax_sp._ERS6626577_filtered.faa
# Processing file: uncultured_Pseudacidovorax_sp._ERS6626850_filtered.faa
# Searching CDD for sequence: Genome291_k127_419550_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Pseudacidovorax_sp._ERS6626850_filtered.faa_Genome291_k127_419550_1_cdd.xml
# Completed processing file: uncultured_Pseudacidovorax_sp._ERS6626850_filtered.faa
# Processing file: uncultured_Pseudacidovorax_sp._ERS6626909_filtered.faa
# Searching CDD for sequence: Genome350_k127_213661_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V5EU5FF1013 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF2/xlm\uncultured_Pseudacidovorax_sp._ERS6626909_filtered.faa_Genome350_k127_213661_1_cdd.xml
# Completed processing file: uncultured_Pseudacidovorax_sp._ERS6626909_filtered.faa
# Processing file: uncultured_Pseudacidovorax_sp._ERS6627003_filtered.faa
# Searching CDD for sequence: Genome444_k127_2949_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V5FH9TC7013 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF2/xlm\uncultured_Pseudacidovorax_sp._ERS6627003_filtered.faa_Genome444_k127_2949_1_cdd.xml
# Searching CDD for sequence: Genome444_k127_25498_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Pseudacidovorax_sp._ERS6627003_filtered.faa_Genome444_k127_25498_1_cdd.xml
# Completed processing file: uncultured_Pseudacidovorax_sp._ERS6627003_filtered.faa
# Processing file: uncultured_Pseudacidovorax_sp._ERS6627320_filtered.faa
# Searching CDD for sequence: Genome544_k127_977136_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Pseudacidovorax_sp._ERS6627320_filtered.faa_Genome544_k127_977136_1_cdd.xml
# Searching CDD for sequence: Genome544_k127_833201_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Pseudacidovorax_sp._ERS6627320_filtered.faa_Genome544_k127_833201_1_cdd.xml
# Searching CDD for sequence: Genome544_k127_857444_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V5GV8Y9K013 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF2/xlm\uncultured_Pseudacidovorax_sp._ERS6627320_filtered.faa_Genome544_k127_857444_1_cdd.xml
# Completed processing file: uncultured_Pseudacidovorax_sp._ERS6627320_filtered.faa
# Processing file: uncultured_Pseudacidovorax_sp._ERS6627321_filtered.faa
# Searching CDD for sequence: Genome545_k127_344480_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Pseudacidovorax_sp._ERS6627321_filtered.faa_Genome545_k127_344480_1_cdd.xml
# Searching CDD for sequence: Genome545_k127_208535_1
# Attempt 1 for sequence.
# Attempt 1 failed: <urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond>
# Attempt 2 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V5JCPCBF013 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF2/xlm\uncultured_Pseudacidovorax_sp._ERS6627321_filtered.faa_Genome545_k127_208535_1_cdd.xml
# Completed processing file: uncultured_Pseudacidovorax_sp._ERS6627321_filtered.faa
# Processing file: uncultured_Pseudomonas_sp._ERS6626673_filtered.faa
# Searching CDD for sequence: Genome114_S3Ck127_13141_2
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V5K54CNZ013 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF2/xlm\uncultured_Pseudomonas_sp._ERS6626673_filtered.faa_Genome114_S3Ck127_13141_2_cdd.xml
# Completed processing file: uncultured_Pseudomonas_sp._ERS6626673_filtered.faa
# Processing file: uncultured_Pseudomonas_sp._ERS6627273_filtered.faa
# Searching CDD for sequence: Genome497_k127_28836_2
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V5KW84B8016 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF2/xlm\uncultured_Pseudomonas_sp._ERS6627273_filtered.faa_Genome497_k127_28836_2_cdd.xml
# Completed processing file: uncultured_Pseudomonas_sp._ERS6627273_filtered.faa
# Processing file: uncultured_Pseudorhodoferax_sp._ERS6626941_filtered.faa
# Searching CDD for sequence: Genome382_k127_146993_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Pseudorhodoferax_sp._ERS6626941_filtered.faa_Genome382_k127_146993_1_cdd.xml
# Completed processing file: uncultured_Pseudorhodoferax_sp._ERS6626941_filtered.faa
# Processing file: uncultured_Sphingomonas_sp._ERS6626680_filtered.faa
# Searching CDD for sequence: Genome121_S1Ck127_116016_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V5N13GYH013 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF2/xlm\uncultured_Sphingomonas_sp._ERS6626680_filtered.faa_Genome121_S1Ck127_116016_1_cdd.xml
# Completed processing file: uncultured_Sphingomonas_sp._ERS6626680_filtered.faa
# Processing file: uncultured_Sphingomonas_sp._ERS6626831_filtered.faa
# Searching CDD for sequence: Genome272_k127_58089_2
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Sphingomonas_sp._ERS6626831_filtered.faa_Genome272_k127_58089_2_cdd.xml
# Completed processing file: uncultured_Sphingomonas_sp._ERS6626831_filtered.faa
# Processing file: uncultured_Sphingomonas_sp._ERS6626957_filtered.faa
# Searching CDD for sequence: Genome398_k127_96590_2
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Sphingomonas_sp._ERS6626957_filtered.faa_Genome398_k127_96590_2_cdd.xml
# Completed processing file: uncultured_Sphingomonas_sp._ERS6626957_filtered.faa
# Processing file: uncultured_Sphingomonas_sp._ERS6627258_filtered.faa
# Searching CDD for sequence: Genome482_k127_81292_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V5P4S3GR013 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF2/xlm\uncultured_Sphingomonas_sp._ERS6627258_filtered.faa_Genome482_k127_81292_1_cdd.xml
# Completed processing file: uncultured_Sphingomonas_sp._ERS6627258_filtered.faa
# Processing file: uncultured_Spirosoma_sp._ERS6627011_filtered.faa
# Searching CDD for sequence: Genome452_k127_363663_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Spirosoma_sp._ERS6627011_filtered.faa_Genome452_k127_363663_1_cdd.xml
# Completed processing file: uncultured_Spirosoma_sp._ERS6627011_filtered.faa
# Processing file: uncultured_Stenotrophomonas_sp._ERS6626688_filtered.faa
# Searching CDD for sequence: Genome129_S3Ck127_15574_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Stenotrophomonas_sp._ERS6626688_filtered.faa_Genome129_S3Ck127_15574_1_cdd.xml
# Completed processing file: uncultured_Stenotrophomonas_sp._ERS6626688_filtered.faa
# Processing file: uncultured_Stenotrophomonas_sp._ERS6627319_filtered.faa
# Searching CDD for sequence: Genome543_k127_120424_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V5R0W5GA016 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF2/xlm\uncultured_Stenotrophomonas_sp._ERS6627319_filtered.faa_Genome543_k127_120424_1_cdd.xml
# Completed processing file: uncultured_Stenotrophomonas_sp._ERS6627319_filtered.faa
# Processing file: uncultured_Variovorax_sp._ERS6626779_filtered.faa
# Searching CDD for sequence: Genome220_k127_244806_1
# Attempt 1 for sequence.
# Results saved to: MOTIF2/xlm\uncultured_Variovorax_sp._ERS6626779_filtered.faa_Genome220_k127_244806_1_cdd.xml
# Completed processing file: uncultured_Variovorax_sp._ERS6626779_filtered.faa
# Processing file: uncultured_Variovorax_sp._ERS6627246_filtered.faa
# Searching CDD for sequence: Genome470_k127_43488_1
# Attempt 1 for sequence.
# C:\Users\dkb1g24\AppData\Local\anaconda3\Lib\site-packages\Bio\Blast\NCBIWWW.py:281: BiopythonWarning: BLAST request V5S3V9XH016 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
# Results saved to: MOTIF2/xlm\uncultured_Variovorax_sp._ERS6627246_filtered.faa_Genome470_k127_43488_1_cdd.xml
# Completed processing file: uncultured_Variovorax_sp._ERS6627246_filtered.faa
# Summary CSV created at: MOTIF1/cds2.csv

# %% [markdown]
# <h2 style="font-family: 'Times New Roman'; font-weight: bold;">
#     Conserved Domain Search Output Analysis
# </h2>

# %% [markdown]
# <h3 style="font-family: 'Times New Roman'; font-weight: bold;">
#     For Form 1 BLAST Results with Form 2 MOTIFs
# </h3>

# %%
cds1_out = open_file(cds1)

# %%
cds1_out
# Out:
#                                             Fasta File  \
# 0    uncultured_Acidovorax_sp._ERS6627271_filtered.faa
# 1    uncultured_Acidovorax_sp._ERS6627271_filtered.faa
# 2    uncultured_Acidovorax_sp._ERS6627271_filtered.faa
# 3    uncultured_Acidovorax_sp._ERS6627271_filtered.faa
# 4    uncultured_Acidovorax_sp._ERS6627271_filtered.faa
# ..                                                 ...
# 398  uncultured_Variovorax_sp._ERS6627246_filtered.faa
# 399  uncultured_Variovorax_sp._ERS6627246_filtered.faa
# 400  uncultured_Variovorax_sp._ERS6627246_filtered.faa
# 401  uncultured_Variovorax_sp._ERS6627246_filtered.faa
# 402  uncultured_Variovorax_sp._ERS6627246_filtered.faa
#
#              Sequence Header      CDD Hit ID  \
# 0    Genome495_k127_317059_1  gnl|CDD|131469
# 1    Genome495_k127_317059_1  gnl|CDD|441138
# 2    Genome495_k127_317059_1  gnl|CDD|468947
# 3    Genome495_k127_317059_1  gnl|CDD|468726
# 4    Genome495_k127_317059_1  gnl|CDD|132238
# ..                       ...             ...
# 398   Genome470_k127_43488_2  gnl|CDD|236637
# 399   Genome470_k127_43488_2  gnl|CDD|466407
# 400   Genome470_k127_43488_2  gnl|CDD|460671
# 401   Genome470_k127_43488_2  gnl|CDD|443669
# 402   Genome470_k127_43488_2  gnl|CDD|274367
#
#                                     CDD Hit Definition  Bit Score  \
# 0    TIGR02416, Carbon_monoxide_dehydrogenase_large...    549.280
# 1    COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    539.650
# 2    NF041018, glyceraldDH_alpha, glyceraldehyde de...    502.671
# 3    NF040766, CODH_aero_grp5, aerobic carbon-monox...    445.277
# 4    TIGR03194, 4-hydroxybenzoyl-CoA_reductase_subu...    273.478
# ..                                                 ...        ...
# 398  PRK09970, PRK09970, xanthine dehydrogenase sub...    216.468
# 399  pfam20256, MoCoBD_2, Molybdopterin cofactor-bi...    184.882
# 400  pfam02738, Ald_Xan_dh_C2, Molybdopterin-bindin...    179.489
# 401  COG4631, XdhB, Xanthine dehydrogenase, molybdo...    187.193
# 402  TIGR02965, xanthine_dehydrogenase, xanthine de...    173.326
#
#            E-value
# 0     0.000000e+00
# 1     0.000000e+00
# 2    1.041350e-167
# 3    4.658080e-145
# 4     2.331170e-80
# ..             ...
# 398   1.198080e-60
# 399   1.771450e-53
# 400   6.816020e-52
# 401   2.291670e-50
# 402   1.493550e-45
#
# [403 rows x 6 columns]

# %%
cds1_out['Fasta File'].nunique()
# Out:
# 33

# %%
best_cds1 = cds1_out.loc[cds1_out.groupby('Fasta File')['E-value'].idxmin()]

# %%
best_cds1
# Out:
#                                             Fasta File  \
# 0    uncultured_Acidovorax_sp._ERS6627271_filtered.faa
# 10   uncultured_Acinetobacter_sp._ERS6626821_filter...
# 20   uncultured_Acinetobacter_sp._ERS6626858_filter...
# 40   uncultured_Aureimonas_sp._ERS6626915_filtered.faa
# 50   uncultured_Aureimonas_sp._ERS6627306_filtered.faa
# 60    uncultured_Comamonas_sp._ERS6626630_filtered.faa
# 70    uncultured_Comamonas_sp._ERS6627283_filtered.faa
# 90   uncultured_Deinococcus_sp._ERS6626797_filtered...
# 100  uncultured_Deinococcus_sp._ERS6626820_filtered...
# 120  uncultured_Deinococcus_sp._ERS6626837_filtered...
# 130  uncultured_Deinococcus_sp._ERS6627293_filtered...
# 140  uncultured_Deinococcus_sp._ERS6627335_filtered...
# 150  uncultured_Hymenobacter_sp._ERS6626733_filtere...
# 160  uncultured_Hymenobacter_sp._ERS6627279_filtere...
# 180  uncultured_Methylobacterium_sp._ERS6627288_fil...
# 190  uncultured_Microbacterium_sp._ERS6626906_filte...
# 196  uncultured_Microbacterium_sp._ERS6626964_filte...
# 206  uncultured_Mucilaginibacter_sp._ERS6626873_fil...
# 216  uncultured_Mucilaginibacter_sp._ERS6626923_fil...
# 225  uncultured_Mucilaginibacter_sp._ERS6626962_fil...
# 233  uncultured_Mucilaginibacter_sp._ERS6626972_fil...
# 243  uncultured_Mucilaginibacter_sp._ERS6626981_fil...
# 253  uncultured_Mucilaginibacter_sp._ERS6627275_fil...
# 263  uncultured_Mucilaginibacter_sp._ERS6627290_fil...
# 273  uncultured_Pseudacidovorax_sp._ERS6626577_filt...
# 283  uncultured_Pseudacidovorax_sp._ERS6626850_filt...
# 293  uncultured_Pseudacidovorax_sp._ERS6627003_filt...
# 313  uncultured_Pseudacidovorax_sp._ERS6627320_filt...
# 343  uncultured_Pseudacidovorax_sp._ERS6627321_filt...
# 363  uncultured_Pseudorhodoferax_sp._ERS6626941_fil...
# 373  uncultured_Sphingomonas_sp._ERS6627258_filtere...
# 383  uncultured_Variovorax_sp._ERS6626779_filtered.faa
# 393  uncultured_Variovorax_sp._ERS6627246_filtered.faa
#
#                 Sequence Header      CDD Hit ID  \
# 0       Genome495_k127_317059_1  gnl|CDD|131469
# 10      Genome262_k127_235961_1  gnl|CDD|443669
# 20      Genome299_k127_417201_1  gnl|CDD|443669
# 40      Genome356_k127_498042_1  gnl|CDD|441138
# 50       Genome530_k127_16854_1  gnl|CDD|441138
# 60     Genome71_S1Ck127_18694_2  gnl|CDD|131469
# 70       Genome507_k127_91973_1  gnl|CDD|131469
# 90       Genome238_k127_17753_1  gnl|CDD|131469
# 100     Genome261_k127_146972_1  gnl|CDD|131469
# 120      Genome278_k127_93298_2  gnl|CDD|131469
# 130     Genome517_k127_348199_1  gnl|CDD|131469
# 140     Genome559_k127_243715_1  gnl|CDD|441138
# 150  Genome174_S1Ck127_276112_1  gnl|CDD|469553
# 160     Genome503_k127_453582_1  gnl|CDD|469553
# 180     Genome512_k127_160927_1  gnl|CDD|441138
# 190      Genome347_k127_84820_2  gnl|CDD|441138
# 196     Genome405_k127_107645_1  gnl|CDD|441138
# 206     Genome314_k127_168730_2  gnl|CDD|469553
# 216     Genome364_k127_154890_1  gnl|CDD|441138
# 225     Genome403_k127_249621_1  gnl|CDD|441138
# 233     Genome413_k127_255610_1  gnl|CDD|469553
# 243      Genome422_k127_88665_1  gnl|CDD|469553
# 253     Genome499_k127_471593_1  gnl|CDD|441138
# 263       Genome514_k127_4285_1  gnl|CDD|441138
# 273   Genome18_S1Ck127_217968_1  gnl|CDD|441138
# 283     Genome291_k127_419550_1  gnl|CDD|441138
# 293       Genome444_k127_2949_1  gnl|CDD|441138
# 313     Genome544_k127_977136_1  gnl|CDD|441138
# 343     Genome545_k127_344480_1  gnl|CDD|441138
# 363     Genome382_k127_146993_1  gnl|CDD|441138
# 373      Genome482_k127_81292_1  gnl|CDD|469553
# 383     Genome220_k127_244806_3  gnl|CDD|441138
# 393      Genome470_k127_43488_2  gnl|CDD|441138
#
#                                     CDD Hit Definition  Bit Score  \
# 0    TIGR02416, Carbon_monoxide_dehydrogenase_large...    549.280
# 10   COG4631, XdhB, Xanthine dehydrogenase, molybdo...    737.643
# 20   COG4631, XdhB, Xanthine dehydrogenase, molybdo...    468.003
# 40   COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    362.073
# 50   COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    573.548
# 60   TIGR02416, Carbon_monoxide_dehydrogenase_large...    475.707
# 70   TIGR02416, Carbon_monoxide_dehydrogenase_large...    540.806
# 90   TIGR02416, Carbon_monoxide_dehydrogenase_large...    573.548
# 100  TIGR02416, Carbon_monoxide_dehydrogenase_large...    573.548
# 120  TIGR02416, Carbon_monoxide_dehydrogenase_large...    564.688
# 130  TIGR02416, Carbon_monoxide_dehydrogenase_large...    595.890
# 140  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    434.491
# 150  NF041671, peri_hyde_PaoC, aldehyde oxidoreduct...    445.662
# 160  NF041671, peri_hyde_PaoC, aldehyde oxidoreduct...    443.736
# 180  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    531.561
# 190  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    146.362
# 196  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    431.795
# 206  NF041671, peri_hyde_PaoC, aldehyde oxidoreduct...    359.377
# 216  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    274.633
# 225  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    280.411
# 233  NF041671, peri_hyde_PaoC, aldehyde oxidoreduct...    418.698
# 243  NF041671, peri_hyde_PaoC, aldehyde oxidoreduct...    362.073
# 253  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    436.417
# 263  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    434.876
# 273  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    537.339
# 283  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    539.650
# 293  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    490.345
# 313  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    520.776
# 343  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    541.962
# 363  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    486.878
# 373  NF041671, peri_hyde_PaoC, aldehyde oxidoreduct...    994.571
# 383  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    460.685
# 393  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    456.062
#
#            E-value
# 0     0.000000e+00
# 10    0.000000e+00
# 20   4.776910e-160
# 40   2.648640e-117
# 50    0.000000e+00
# 60   2.056120e-158
# 70    0.000000e+00
# 90    0.000000e+00
# 100   0.000000e+00
# 120   0.000000e+00
# 130   0.000000e+00
# 140  5.209270e-142
# 150  3.447380e-146
# 160  1.953600e-145
# 180  2.206750e-179
# 190   9.039560e-41
# 196  3.964770e-141
# 206  5.037210e-115
# 216   2.986480e-84
# 225   3.782860e-86
# 233  8.704430e-137
# 243  6.751090e-117
# 253  3.182330e-143
# 263  1.323170e-142
# 273   0.000000e+00
# 283   0.000000e+00
# 293  4.970580e-164
# 313  4.291670e-175
# 343   0.000000e+00
# 363  7.663690e-162
# 373   0.000000e+00
# 383  2.583550e-153
# 393  1.444250e-151

# %%
best_cds1['CDD Hit Definition'].unique()
# Out:
# array(['TIGR02416, Carbon_monoxide_dehydrogenase_large_chain, carbon-monoxide dehydrogenase, large subunit.  This model represents the large subunits of group of carbon-monoxide dehydrogenases that include molybdenum as part of the enzymatic cofactor. There are various forms of carbon-monoxide dehydrogenase; Salicibacter pomeroyi DSS-3, for example, has two forms. Note that, at least in some species, the active site Cys is modified with a selenium attached to (rather than replacing) the sulfur atom. This is termed selanylcysteine, and created post-translationally, in contrast to selenocysteine incorporation during translation as for many other selenoproteins. [Energy metabolism, Other].',
#        'COG4631, XdhB, Xanthine dehydrogenase, molybdopterin-binding subunit XdhB [Nucleotide transport and metabolism].  ',
#        'COG1529, CoxL, Aldehyde, CO or xanthine dehydrogenase, Mo-binding subunit [Energy production and conversion].  Aldehyde, CO or xanthine dehydrogenase, Mo-binding subunit is part of the Pathway/BioSystem: Non-phosphorylated Entner-Doudoroff pathway.',
#        'NF041671, peri_hyde_PaoC, aldehyde oxidoreductase molybdenum-binding subunit PaoC.  PaoC is the molybdopterin-cytosine-dinucleotide cofactor-binding subunit of the periplasmic aldehyde oxidoreductase PaoABC. The enzyme is known formally as carboxylate reductase (EC 1.2.99.6).'],
#       dtype=object)

# %%
condition_1 = 'TIGR02416, Carbon_monoxide_dehydrogenase_large_chain, carbon-monoxide dehydrogenase, large subunit.  This model represents the large subunits of group of carbon-monoxide dehydrogenases that include molybdenum as part of the enzymatic cofactor. There are various forms of carbon-monoxide dehydrogenase; Salicibacter pomeroyi DSS-3, for example, has two forms. Note that, at least in some species, the active site Cys is modified with a selenium attached to (rather than replacing) the sulfur atom. This is termed selanylcysteine, and created post-translationally, in contrast to selenocysteine incorporation during translation as for many other selenoproteins. [Energy metabolism, Other].'
condition_2 = 'COG1529, CoxL, Aldehyde, CO or xanthine dehydrogenase, Mo-binding subunit [Energy production and conversion].  Aldehyde, CO or xanthine dehydrogenase, Mo-binding subunit is part of the Pathway/BioSystem: Non-phosphorylated Entner-Doudoroff pathway.'

# %%
best_cds1 = best_cds1[(best_cds1['CDD Hit Definition'] == condition_1) | (best_cds1['CDD Hit Definition'] == condition_2)].reset_index(drop=True)
best_cds1
# Out:
#                                            Fasta File  \
# 0   uncultured_Acidovorax_sp._ERS6627271_filtered.faa
# 1   uncultured_Aureimonas_sp._ERS6626915_filtered.faa
# 2   uncultured_Aureimonas_sp._ERS6627306_filtered.faa
# 3    uncultured_Comamonas_sp._ERS6626630_filtered.faa
# 4    uncultured_Comamonas_sp._ERS6627283_filtered.faa
# 5   uncultured_Deinococcus_sp._ERS6626797_filtered...
# 6   uncultured_Deinococcus_sp._ERS6626820_filtered...
# 7   uncultured_Deinococcus_sp._ERS6626837_filtered...
# 8   uncultured_Deinococcus_sp._ERS6627293_filtered...
# 9   uncultured_Deinococcus_sp._ERS6627335_filtered...
# 10  uncultured_Methylobacterium_sp._ERS6627288_fil...
# 11  uncultured_Microbacterium_sp._ERS6626906_filte...
# 12  uncultured_Microbacterium_sp._ERS6626964_filte...
# 13  uncultured_Mucilaginibacter_sp._ERS6626923_fil...
# 14  uncultured_Mucilaginibacter_sp._ERS6626962_fil...
# 15  uncultured_Mucilaginibacter_sp._ERS6627275_fil...
# 16  uncultured_Mucilaginibacter_sp._ERS6627290_fil...
# 17  uncultured_Pseudacidovorax_sp._ERS6626577_filt...
# 18  uncultured_Pseudacidovorax_sp._ERS6626850_filt...
# 19  uncultured_Pseudacidovorax_sp._ERS6627003_filt...
# 20  uncultured_Pseudacidovorax_sp._ERS6627320_filt...
# 21  uncultured_Pseudacidovorax_sp._ERS6627321_filt...
# 22  uncultured_Pseudorhodoferax_sp._ERS6626941_fil...
# 23  uncultured_Variovorax_sp._ERS6626779_filtered.faa
# 24  uncultured_Variovorax_sp._ERS6627246_filtered.faa
#
#               Sequence Header      CDD Hit ID  \
# 0     Genome495_k127_317059_1  gnl|CDD|131469
# 1     Genome356_k127_498042_1  gnl|CDD|441138
# 2      Genome530_k127_16854_1  gnl|CDD|441138
# 3    Genome71_S1Ck127_18694_2  gnl|CDD|131469
# 4      Genome507_k127_91973_1  gnl|CDD|131469
# 5      Genome238_k127_17753_1  gnl|CDD|131469
# 6     Genome261_k127_146972_1  gnl|CDD|131469
# 7      Genome278_k127_93298_2  gnl|CDD|131469
# 8     Genome517_k127_348199_1  gnl|CDD|131469
# 9     Genome559_k127_243715_1  gnl|CDD|441138
# 10    Genome512_k127_160927_1  gnl|CDD|441138
# 11     Genome347_k127_84820_2  gnl|CDD|441138
# 12    Genome405_k127_107645_1  gnl|CDD|441138
# 13    Genome364_k127_154890_1  gnl|CDD|441138
# 14    Genome403_k127_249621_1  gnl|CDD|441138
# 15    Genome499_k127_471593_1  gnl|CDD|441138
# 16      Genome514_k127_4285_1  gnl|CDD|441138
# 17  Genome18_S1Ck127_217968_1  gnl|CDD|441138
# 18    Genome291_k127_419550_1  gnl|CDD|441138
# 19      Genome444_k127_2949_1  gnl|CDD|441138
# 20    Genome544_k127_977136_1  gnl|CDD|441138
# 21    Genome545_k127_344480_1  gnl|CDD|441138
# 22    Genome382_k127_146993_1  gnl|CDD|441138
# 23    Genome220_k127_244806_3  gnl|CDD|441138
# 24     Genome470_k127_43488_2  gnl|CDD|441138
#
#                                    CDD Hit Definition  Bit Score  \
# 0   TIGR02416, Carbon_monoxide_dehydrogenase_large...    549.280
# 1   COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    362.073
# 2   COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    573.548
# 3   TIGR02416, Carbon_monoxide_dehydrogenase_large...    475.707
# 4   TIGR02416, Carbon_monoxide_dehydrogenase_large...    540.806
# 5   TIGR02416, Carbon_monoxide_dehydrogenase_large...    573.548
# 6   TIGR02416, Carbon_monoxide_dehydrogenase_large...    573.548
# 7   TIGR02416, Carbon_monoxide_dehydrogenase_large...    564.688
# 8   TIGR02416, Carbon_monoxide_dehydrogenase_large...    595.890
# 9   COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    434.491
# 10  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    531.561
# 11  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    146.362
# 12  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    431.795
# 13  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    274.633
# 14  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    280.411
# 15  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    436.417
# 16  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    434.876
# 17  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    537.339
# 18  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    539.650
# 19  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    490.345
# 20  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    520.776
# 21  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    541.962
# 22  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    486.878
# 23  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    460.685
# 24  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    456.062
#
#           E-value
# 0    0.000000e+00
# 1   2.648640e-117
# 2    0.000000e+00
# 3   2.056120e-158
# 4    0.000000e+00
# 5    0.000000e+00
# 6    0.000000e+00
# 7    0.000000e+00
# 8    0.000000e+00
# 9   5.209270e-142
# 10  2.206750e-179
# 11   9.039560e-41
# 12  3.964770e-141
# 13   2.986480e-84
# 14   3.782860e-86
# 15  3.182330e-143
# 16  1.323170e-142
# 17   0.000000e+00
# 18   0.000000e+00
# 19  4.970580e-164
# 20  4.291670e-175
# 21   0.000000e+00
# 22  7.663690e-162
# 23  2.583550e-153
# 24  1.444250e-151

# %%
best_cds1['Fasta File'].unique()
# Out:
# array(['uncultured_Acidovorax_sp._ERS6627271_filtered.faa',
#        'uncultured_Aureimonas_sp._ERS6626915_filtered.faa',
#        'uncultured_Aureimonas_sp._ERS6627306_filtered.faa',
#        'uncultured_Comamonas_sp._ERS6626630_filtered.faa',
#        'uncultured_Comamonas_sp._ERS6627283_filtered.faa',
#        'uncultured_Deinococcus_sp._ERS6626797_filtered.faa',
#        'uncultured_Deinococcus_sp._ERS6626820_filtered.faa',
#        'uncultured_Deinococcus_sp._ERS6626837_filtered.faa',
#        'uncultured_Deinococcus_sp._ERS6627293_filtered.faa',
#        'uncultured_Deinococcus_sp._ERS6627335_filtered.faa',
#        'uncultured_Methylobacterium_sp._ERS6627288_filtered.faa',
#        'uncultured_Microbacterium_sp._ERS6626906_filtered.faa',
#        'uncultured_Microbacterium_sp._ERS6626964_filtered.faa',
#        'uncultured_Mucilaginibacter_sp._ERS6626923_filtered.faa',
#        'uncultured_Mucilaginibacter_sp._ERS6626962_filtered.faa',
#        'uncultured_Mucilaginibacter_sp._ERS6627275_filtered.faa',
#        'uncultured_Mucilaginibacter_sp._ERS6627290_filtered.faa',
#        'uncultured_Pseudacidovorax_sp._ERS6626577_filtered.faa',
#        'uncultured_Pseudacidovorax_sp._ERS6626850_filtered.faa',
#        'uncultured_Pseudacidovorax_sp._ERS6627003_filtered.faa',
#        'uncultured_Pseudacidovorax_sp._ERS6627320_filtered.faa',
#        'uncultured_Pseudacidovorax_sp._ERS6627321_filtered.faa',
#        'uncultured_Pseudorhodoferax_sp._ERS6626941_filtered.faa',
#        'uncultured_Variovorax_sp._ERS6626779_filtered.faa',
#        'uncultured_Variovorax_sp._ERS6627246_filtered.faa'], dtype=object)

# %% [markdown]
# <h3 style="font-family: 'Times New Roman'; font-weight: bold;">
#     For Form 2 BLAST Results with Form 2 MOTIFs
# </h3>

# %%
cds2_out = open_file(cds2)
cds2_out
# Out:
#                                             Fasta File  \
# 0    uncultured_Acidovorax_sp._ERS6627271_filtered.faa
# 1    uncultured_Acidovorax_sp._ERS6627271_filtered.faa
# 2    uncultured_Acidovorax_sp._ERS6627271_filtered.faa
# 3    uncultured_Acidovorax_sp._ERS6627271_filtered.faa
# 4    uncultured_Acidovorax_sp._ERS6627271_filtered.faa
# ..                                                 ...
# 412  uncultured_Variovorax_sp._ERS6627246_filtered.faa
# 413  uncultured_Variovorax_sp._ERS6627246_filtered.faa
# 414  uncultured_Variovorax_sp._ERS6627246_filtered.faa
# 415  uncultured_Variovorax_sp._ERS6627246_filtered.faa
# 416  uncultured_Variovorax_sp._ERS6627246_filtered.faa
#
#              Sequence Header      CDD Hit ID  \
# 0    Genome495_k127_317059_1  gnl|CDD|131469
# 1    Genome495_k127_317059_1  gnl|CDD|441138
# 2    Genome495_k127_317059_1  gnl|CDD|468947
# 3    Genome495_k127_317059_1  gnl|CDD|468726
# 4    Genome495_k127_317059_1  gnl|CDD|132238
# ..                       ...             ...
# 412   Genome470_k127_43488_1  gnl|CDD|132238
# 413   Genome470_k127_43488_1  gnl|CDD|132356
# 414   Genome470_k127_43488_1  gnl|CDD|443669
# 415   Genome470_k127_43488_1  gnl|CDD|274367
# 416   Genome470_k127_43488_1  gnl|CDD|466407
#
#                                     CDD Hit Definition  Bit Score  \
# 0    TIGR02416, Carbon_monoxide_dehydrogenase_large...    548.895
# 1    COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    540.036
# 2    NF041018, glyceraldDH_alpha, glyceraldehyde de...    499.590
# 3    NF040766, CODH_aero_grp5, aerobic carbon-monox...    445.277
# 4    TIGR03194, 4-hydroxybenzoyl-CoA_reductase_subu...    273.478
# ..                                                 ...        ...
# 412  TIGR03194, 4-hydroxybenzoyl-CoA_reductase_subu...    258.070
# 413  TIGR03313, Se_sel_red_Mo, probable selenate re...    235.343
# 414  COG4631, XdhB, Xanthine dehydrogenase, molybdo...    214.927
# 415  TIGR02965, xanthine_dehydrogenase, xanthine de...    201.830
# 416  pfam20256, MoCoBD_2, Molybdopterin cofactor-bi...    184.882
#
#            E-value
# 0     0.000000e+00
# 1     0.000000e+00
# 2    1.025440e-166
# 3    4.983950e-145
# 4     1.968160e-80
# ..             ...
# 412   6.223070e-75
# 413   1.521620e-65
# 414   2.707380e-59
# 415   9.922190e-55
# 416   8.184430e-53
#
# [417 rows x 6 columns]

# %%
cds2_out['Fasta File'].nunique()
# Out:
# 34

# %%
best_cds2 = cds2_out.loc[cds2_out.groupby('Fasta File')['E-value'].idxmin()]
best_cds2
# Out:
#                                             Fasta File  \
# 0    uncultured_Acidovorax_sp._ERS6627271_filtered.faa
# 10   uncultured_Acinetobacter_sp._ERS6626821_filter...
# 20   uncultured_Acinetobacter_sp._ERS6626858_filter...
# 40   uncultured_Aureimonas_sp._ERS6626915_filtered.faa
# 50   uncultured_Aureimonas_sp._ERS6627306_filtered.faa
# 60    uncultured_Comamonas_sp._ERS6626630_filtered.faa
# 70    uncultured_Comamonas_sp._ERS6627283_filtered.faa
# 90   uncultured_Deinococcus_sp._ERS6626797_filtered...
# 100  uncultured_Deinococcus_sp._ERS6626820_filtered...
# 120  uncultured_Deinococcus_sp._ERS6626837_filtered...
# 130  uncultured_Deinococcus_sp._ERS6627293_filtered...
# 140  uncultured_Deinococcus_sp._ERS6627335_filtered...
# 150  uncultured_Hymenobacter_sp._ERS6626733_filtere...
# 160  uncultured_Hymenobacter_sp._ERS6627279_filtere...
# 180  uncultured_Methylobacterium_sp._ERS6627288_fil...
# 190  uncultured_Microbacterium_sp._ERS6626906_filte...
# 200  uncultured_Microbacterium_sp._ERS6626964_filte...
# 210  uncultured_Mucilaginibacter_sp._ERS6626873_fil...
# 220  uncultured_Mucilaginibacter_sp._ERS6626923_fil...
# 229  uncultured_Mucilaginibacter_sp._ERS6626962_fil...
# 237  uncultured_Mucilaginibacter_sp._ERS6626972_fil...
# 247  uncultured_Mucilaginibacter_sp._ERS6626981_fil...
# 257  uncultured_Mucilaginibacter_sp._ERS6627275_fil...
# 267  uncultured_Mucilaginibacter_sp._ERS6627290_fil...
# 277  uncultured_Pseudacidovorax_sp._ERS6626577_filt...
# 287  uncultured_Pseudacidovorax_sp._ERS6626850_filt...
# 297  uncultured_Pseudacidovorax_sp._ERS6626909_filt...
# 307  uncultured_Pseudacidovorax_sp._ERS6627003_filt...
# 337  uncultured_Pseudacidovorax_sp._ERS6627320_filt...
# 357  uncultured_Pseudacidovorax_sp._ERS6627321_filt...
# 377  uncultured_Pseudorhodoferax_sp._ERS6626941_fil...
# 387  uncultured_Sphingomonas_sp._ERS6627258_filtere...
# 397  uncultured_Variovorax_sp._ERS6626779_filtered.faa
# 407  uncultured_Variovorax_sp._ERS6627246_filtered.faa
#
#                 Sequence Header      CDD Hit ID  \
# 0       Genome495_k127_317059_1  gnl|CDD|131469
# 10      Genome262_k127_235961_1  gnl|CDD|443669
# 20      Genome299_k127_417201_1  gnl|CDD|443669
# 40      Genome356_k127_498042_1  gnl|CDD|441138
# 50       Genome530_k127_16854_1  gnl|CDD|441138
# 60     Genome71_S1Ck127_18694_1  gnl|CDD|131469
# 70       Genome507_k127_91973_1  gnl|CDD|131469
# 90       Genome238_k127_17753_1  gnl|CDD|131469
# 100     Genome261_k127_146972_1  gnl|CDD|131469
# 120      Genome278_k127_93298_1  gnl|CDD|131469
# 130     Genome517_k127_348199_1  gnl|CDD|131469
# 140     Genome559_k127_243715_1  gnl|CDD|441138
# 150  Genome174_S1Ck127_276112_1  gnl|CDD|469553
# 160     Genome503_k127_453582_1  gnl|CDD|469553
# 180     Genome512_k127_160927_1  gnl|CDD|441138
# 190      Genome347_k127_84820_1  gnl|CDD|441138
# 200     Genome405_k127_107645_1  gnl|CDD|441138
# 210     Genome314_k127_168730_1  gnl|CDD|469553
# 220     Genome364_k127_154890_1  gnl|CDD|441138
# 229     Genome403_k127_249621_1  gnl|CDD|441138
# 237     Genome413_k127_255610_1  gnl|CDD|441138
# 247      Genome422_k127_88665_1  gnl|CDD|469553
# 257     Genome499_k127_471593_1  gnl|CDD|441138
# 267       Genome514_k127_4285_1  gnl|CDD|441138
# 277   Genome18_S1Ck127_217968_1  gnl|CDD|441138
# 287     Genome291_k127_419550_1  gnl|CDD|441138
# 297     Genome350_k127_213661_1  gnl|CDD|441138
# 307       Genome444_k127_2949_1  gnl|CDD|441138
# 337     Genome544_k127_833201_1  gnl|CDD|441138
# 357     Genome545_k127_344480_1  gnl|CDD|441138
# 377     Genome382_k127_146993_1  gnl|CDD|441138
# 387      Genome482_k127_81292_1  gnl|CDD|469553
# 397     Genome220_k127_244806_1  gnl|CDD|441138
# 407      Genome470_k127_43488_1  gnl|CDD|441138
#
#                                     CDD Hit Definition  Bit Score  \
# 0    TIGR02416, Carbon_monoxide_dehydrogenase_large...    548.895
# 10   COG4631, XdhB, Xanthine dehydrogenase, molybdo...    752.666
# 20   COG4631, XdhB, Xanthine dehydrogenase, molybdo...    533.872
# 40   COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    362.073
# 50   COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    573.548
# 60   TIGR02416, Carbon_monoxide_dehydrogenase_large...    540.036
# 70   TIGR02416, Carbon_monoxide_dehydrogenase_large...    540.806
# 90   TIGR02416, Carbon_monoxide_dehydrogenase_large...    596.660
# 100  TIGR02416, Carbon_monoxide_dehydrogenase_large...    597.045
# 120  TIGR02416, Carbon_monoxide_dehydrogenase_large...    597.045
# 130  TIGR02416, Carbon_monoxide_dehydrogenase_large...    596.660
# 140  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    398.667
# 150  NF041671, peri_hyde_PaoC, aldehyde oxidoreduct...    403.675
# 160  NF041671, peri_hyde_PaoC, aldehyde oxidoreduct...    402.134
# 180  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    532.717
# 190  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    244.588
# 200  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    436.032
# 210  NF041671, peri_hyde_PaoC, aldehyde oxidoreduct...    421.009
# 220  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    289.271
# 229  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    323.553
# 237  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    432.565
# 247  NF041671, peri_hyde_PaoC, aldehyde oxidoreduct...    433.335
# 257  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    434.106
# 267  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    432.180
# 277  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    540.036
# 287  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    542.732
# 297  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    519.620
# 307  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    490.345
# 337  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    547.740
# 357  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    542.732
# 377  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    486.878
# 387  NF041671, peri_hyde_PaoC, aldehyde oxidoreduct...    993.416
# 397  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    524.628
# 407  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    526.554
#
#            E-value
# 0     0.000000e+00
# 10    0.000000e+00
# 20    0.000000e+00
# 40   2.557480e-117
# 50    0.000000e+00
# 60    0.000000e+00
# 70    0.000000e+00
# 90    0.000000e+00
# 100   0.000000e+00
# 120   0.000000e+00
# 130   0.000000e+00
# 140  1.239670e-128
# 150  1.748090e-130
# 160  7.451470e-130
# 180  8.352100e-180
# 190   1.275460e-74
# 200  2.577570e-142
# 210  3.640460e-137
# 220   1.275720e-89
# 229  2.364320e-101
# 237  7.678530e-142
# 247  3.710170e-142
# 257  2.264310e-142
# 267  1.270290e-141
# 277   0.000000e+00
# 287   0.000000e+00
# 297  9.960680e-175
# 307  4.101740e-164
# 337   0.000000e+00
# 357   0.000000e+00
# 377  6.480520e-162
# 387   0.000000e+00
# 397  1.377220e-176
# 407  2.479540e-177

# %%
best_cds2['CDD Hit Definition'].unique()
# Out:
# array(['TIGR02416, Carbon_monoxide_dehydrogenase_large_chain, carbon-monoxide dehydrogenase, large subunit.  This model represents the large subunits of group of carbon-monoxide dehydrogenases that include molybdenum as part of the enzymatic cofactor. There are various forms of carbon-monoxide dehydrogenase; Salicibacter pomeroyi DSS-3, for example, has two forms. Note that, at least in some species, the active site Cys is modified with a selenium attached to (rather than replacing) the sulfur atom. This is termed selanylcysteine, and created post-translationally, in contrast to selenocysteine incorporation during translation as for many other selenoproteins. [Energy metabolism, Other].',
#        'COG4631, XdhB, Xanthine dehydrogenase, molybdopterin-binding subunit XdhB [Nucleotide transport and metabolism].  ',
#        'COG1529, CoxL, Aldehyde, CO or xanthine dehydrogenase, Mo-binding subunit [Energy production and conversion].  Aldehyde, CO or xanthine dehydrogenase, Mo-binding subunit is part of the Pathway/BioSystem: Non-phosphorylated Entner-Doudoroff pathway.',
#        'NF041671, peri_hyde_PaoC, aldehyde oxidoreductase molybdenum-binding subunit PaoC.  PaoC is the molybdopterin-cytosine-dinucleotide cofactor-binding subunit of the periplasmic aldehyde oxidoreductase PaoABC. The enzyme is known formally as carboxylate reductase (EC 1.2.99.6).'],
#       dtype=object)

# %%
best_cds2 = best_cds2[(best_cds2['CDD Hit Definition'] == condition_1) | (best_cds2['CDD Hit Definition'] == condition_2)].reset_index(drop=True)
best_cds2
# Out:
#                                            Fasta File  \
# 0   uncultured_Acidovorax_sp._ERS6627271_filtered.faa
# 1   uncultured_Aureimonas_sp._ERS6626915_filtered.faa
# 2   uncultured_Aureimonas_sp._ERS6627306_filtered.faa
# 3    uncultured_Comamonas_sp._ERS6626630_filtered.faa
# 4    uncultured_Comamonas_sp._ERS6627283_filtered.faa
# 5   uncultured_Deinococcus_sp._ERS6626797_filtered...
# 6   uncultured_Deinococcus_sp._ERS6626820_filtered...
# 7   uncultured_Deinococcus_sp._ERS6626837_filtered...
# 8   uncultured_Deinococcus_sp._ERS6627293_filtered...
# 9   uncultured_Deinococcus_sp._ERS6627335_filtered...
# 10  uncultured_Methylobacterium_sp._ERS6627288_fil...
# 11  uncultured_Microbacterium_sp._ERS6626906_filte...
# 12  uncultured_Microbacterium_sp._ERS6626964_filte...
# 13  uncultured_Mucilaginibacter_sp._ERS6626923_fil...
# 14  uncultured_Mucilaginibacter_sp._ERS6626962_fil...
# 15  uncultured_Mucilaginibacter_sp._ERS6626972_fil...
# 16  uncultured_Mucilaginibacter_sp._ERS6627275_fil...
# 17  uncultured_Mucilaginibacter_sp._ERS6627290_fil...
# 18  uncultured_Pseudacidovorax_sp._ERS6626577_filt...
# 19  uncultured_Pseudacidovorax_sp._ERS6626850_filt...
# 20  uncultured_Pseudacidovorax_sp._ERS6626909_filt...
# 21  uncultured_Pseudacidovorax_sp._ERS6627003_filt...
# 22  uncultured_Pseudacidovorax_sp._ERS6627320_filt...
# 23  uncultured_Pseudacidovorax_sp._ERS6627321_filt...
# 24  uncultured_Pseudorhodoferax_sp._ERS6626941_fil...
# 25  uncultured_Variovorax_sp._ERS6626779_filtered.faa
# 26  uncultured_Variovorax_sp._ERS6627246_filtered.faa
#
#               Sequence Header      CDD Hit ID  \
# 0     Genome495_k127_317059_1  gnl|CDD|131469
# 1     Genome356_k127_498042_1  gnl|CDD|441138
# 2      Genome530_k127_16854_1  gnl|CDD|441138
# 3    Genome71_S1Ck127_18694_1  gnl|CDD|131469
# 4      Genome507_k127_91973_1  gnl|CDD|131469
# 5      Genome238_k127_17753_1  gnl|CDD|131469
# 6     Genome261_k127_146972_1  gnl|CDD|131469
# 7      Genome278_k127_93298_1  gnl|CDD|131469
# 8     Genome517_k127_348199_1  gnl|CDD|131469
# 9     Genome559_k127_243715_1  gnl|CDD|441138
# 10    Genome512_k127_160927_1  gnl|CDD|441138
# 11     Genome347_k127_84820_1  gnl|CDD|441138
# 12    Genome405_k127_107645_1  gnl|CDD|441138
# 13    Genome364_k127_154890_1  gnl|CDD|441138
# 14    Genome403_k127_249621_1  gnl|CDD|441138
# 15    Genome413_k127_255610_1  gnl|CDD|441138
# 16    Genome499_k127_471593_1  gnl|CDD|441138
# 17      Genome514_k127_4285_1  gnl|CDD|441138
# 18  Genome18_S1Ck127_217968_1  gnl|CDD|441138
# 19    Genome291_k127_419550_1  gnl|CDD|441138
# 20    Genome350_k127_213661_1  gnl|CDD|441138
# 21      Genome444_k127_2949_1  gnl|CDD|441138
# 22    Genome544_k127_833201_1  gnl|CDD|441138
# 23    Genome545_k127_344480_1  gnl|CDD|441138
# 24    Genome382_k127_146993_1  gnl|CDD|441138
# 25    Genome220_k127_244806_1  gnl|CDD|441138
# 26     Genome470_k127_43488_1  gnl|CDD|441138
#
#                                    CDD Hit Definition  Bit Score  \
# 0   TIGR02416, Carbon_monoxide_dehydrogenase_large...    548.895
# 1   COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    362.073
# 2   COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    573.548
# 3   TIGR02416, Carbon_monoxide_dehydrogenase_large...    540.036
# 4   TIGR02416, Carbon_monoxide_dehydrogenase_large...    540.806
# 5   TIGR02416, Carbon_monoxide_dehydrogenase_large...    596.660
# 6   TIGR02416, Carbon_monoxide_dehydrogenase_large...    597.045
# 7   TIGR02416, Carbon_monoxide_dehydrogenase_large...    597.045
# 8   TIGR02416, Carbon_monoxide_dehydrogenase_large...    596.660
# 9   COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    398.667
# 10  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    532.717
# 11  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    244.588
# 12  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    436.032
# 13  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    289.271
# 14  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    323.553
# 15  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    432.565
# 16  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    434.106
# 17  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    432.180
# 18  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    540.036
# 19  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    542.732
# 20  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    519.620
# 21  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    490.345
# 22  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    547.740
# 23  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    542.732
# 24  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    486.878
# 25  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    524.628
# 26  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    526.554
#
#           E-value
# 0    0.000000e+00
# 1   2.557480e-117
# 2    0.000000e+00
# 3    0.000000e+00
# 4    0.000000e+00
# 5    0.000000e+00
# 6    0.000000e+00
# 7    0.000000e+00
# 8    0.000000e+00
# 9   1.239670e-128
# 10  8.352100e-180
# 11   1.275460e-74
# 12  2.577570e-142
# 13   1.275720e-89
# 14  2.364320e-101
# 15  7.678530e-142
# 16  2.264310e-142
# 17  1.270290e-141
# 18   0.000000e+00
# 19   0.000000e+00
# 20  9.960680e-175
# 21  4.101740e-164
# 22   0.000000e+00
# 23   0.000000e+00
# 24  6.480520e-162
# 25  1.377220e-176
# 26  2.479540e-177

# %%
best_cds2['Fasta File'].unique()
# Out:
# array(['uncultured_Acidovorax_sp._ERS6627271_filtered.faa',
#        'uncultured_Aureimonas_sp._ERS6626915_filtered.faa',
#        'uncultured_Aureimonas_sp._ERS6627306_filtered.faa',
#        'uncultured_Comamonas_sp._ERS6626630_filtered.faa',
#        'uncultured_Comamonas_sp._ERS6627283_filtered.faa',
#        'uncultured_Deinococcus_sp._ERS6626797_filtered.faa',
#        'uncultured_Deinococcus_sp._ERS6626820_filtered.faa',
#        'uncultured_Deinococcus_sp._ERS6626837_filtered.faa',
#        'uncultured_Deinococcus_sp._ERS6627293_filtered.faa',
#        'uncultured_Deinococcus_sp._ERS6627335_filtered.faa',
#        'uncultured_Methylobacterium_sp._ERS6627288_filtered.faa',
#        'uncultured_Microbacterium_sp._ERS6626906_filtered.faa',
#        'uncultured_Microbacterium_sp._ERS6626964_filtered.faa',
#        'uncultured_Mucilaginibacter_sp._ERS6626923_filtered.faa',
#        'uncultured_Mucilaginibacter_sp._ERS6626962_filtered.faa',
#        'uncultured_Mucilaginibacter_sp._ERS6626972_filtered.faa',
#        'uncultured_Mucilaginibacter_sp._ERS6627275_filtered.faa',
#        'uncultured_Mucilaginibacter_sp._ERS6627290_filtered.faa',
#        'uncultured_Pseudacidovorax_sp._ERS6626577_filtered.faa',
#        'uncultured_Pseudacidovorax_sp._ERS6626850_filtered.faa',
#        'uncultured_Pseudacidovorax_sp._ERS6626909_filtered.faa',
#        'uncultured_Pseudacidovorax_sp._ERS6627003_filtered.faa',
#        'uncultured_Pseudacidovorax_sp._ERS6627320_filtered.faa',
#        'uncultured_Pseudacidovorax_sp._ERS6627321_filtered.faa',
#        'uncultured_Pseudorhodoferax_sp._ERS6626941_filtered.faa',
#        'uncultured_Variovorax_sp._ERS6626779_filtered.faa',
#        'uncultured_Variovorax_sp._ERS6627246_filtered.faa'], dtype=object)

# %% [markdown]
# <h3 style="font-family: 'Times New Roman'; font-weight: bold;">
#     Find Unique MAGs from both the Outputs
# </h3>

# %%
unique_in_best_cds1 = np.setdiff1d(best_cds1['Fasta File'].unique(), best_cds2['Fasta File'].unique())
unique_in_best_cds2 = np.setdiff1d(best_cds2['Fasta File'].unique(), best_cds1['Fasta File'].unique())

print("Unique in best_cds1:", unique_in_best_cds1)
print("Unique in best_cds2:", unique_in_best_cds2)
# Out:
# Unique in best_cds1: []
# Unique in best_cds2: ['uncultured_Mucilaginibacter_sp._ERS6626972_filtered.faa'
#  'uncultured_Pseudacidovorax_sp._ERS6626909_filtered.faa']

# %% [markdown]
# <h3 style="font-family: 'Times New Roman'; font-weight: bold;">
#     Cross Check
# </h3>

# %%
best_cds2['source_file'] = best_cds2['Fasta File'].str.replace('_filtered.faa', '.fasta')
best_cds2
# Out:
#                                            Fasta File  \
# 0   uncultured_Acidovorax_sp._ERS6627271_filtered.faa
# 1   uncultured_Aureimonas_sp._ERS6626915_filtered.faa
# 2   uncultured_Aureimonas_sp._ERS6627306_filtered.faa
# 3    uncultured_Comamonas_sp._ERS6626630_filtered.faa
# 4    uncultured_Comamonas_sp._ERS6627283_filtered.faa
# 5   uncultured_Deinococcus_sp._ERS6626797_filtered...
# 6   uncultured_Deinococcus_sp._ERS6626820_filtered...
# 7   uncultured_Deinococcus_sp._ERS6626837_filtered...
# 8   uncultured_Deinococcus_sp._ERS6627293_filtered...
# 9   uncultured_Deinococcus_sp._ERS6627335_filtered...
# 10  uncultured_Methylobacterium_sp._ERS6627288_fil...
# 11  uncultured_Microbacterium_sp._ERS6626906_filte...
# 12  uncultured_Microbacterium_sp._ERS6626964_filte...
# 13  uncultured_Mucilaginibacter_sp._ERS6626923_fil...
# 14  uncultured_Mucilaginibacter_sp._ERS6626962_fil...
# 15  uncultured_Mucilaginibacter_sp._ERS6626972_fil...
# 16  uncultured_Mucilaginibacter_sp._ERS6627275_fil...
# 17  uncultured_Mucilaginibacter_sp._ERS6627290_fil...
# 18  uncultured_Pseudacidovorax_sp._ERS6626577_filt...
# 19  uncultured_Pseudacidovorax_sp._ERS6626850_filt...
# 20  uncultured_Pseudacidovorax_sp._ERS6626909_filt...
# 21  uncultured_Pseudacidovorax_sp._ERS6627003_filt...
# 22  uncultured_Pseudacidovorax_sp._ERS6627320_filt...
# 23  uncultured_Pseudacidovorax_sp._ERS6627321_filt...
# 24  uncultured_Pseudorhodoferax_sp._ERS6626941_fil...
# 25  uncultured_Variovorax_sp._ERS6626779_filtered.faa
# 26  uncultured_Variovorax_sp._ERS6627246_filtered.faa
#
#               Sequence Header      CDD Hit ID  \
# 0     Genome495_k127_317059_1  gnl|CDD|131469
# 1     Genome356_k127_498042_1  gnl|CDD|441138
# 2      Genome530_k127_16854_1  gnl|CDD|441138
# 3    Genome71_S1Ck127_18694_1  gnl|CDD|131469
# 4      Genome507_k127_91973_1  gnl|CDD|131469
# 5      Genome238_k127_17753_1  gnl|CDD|131469
# 6     Genome261_k127_146972_1  gnl|CDD|131469
# 7      Genome278_k127_93298_1  gnl|CDD|131469
# 8     Genome517_k127_348199_1  gnl|CDD|131469
# 9     Genome559_k127_243715_1  gnl|CDD|441138
# 10    Genome512_k127_160927_1  gnl|CDD|441138
# 11     Genome347_k127_84820_1  gnl|CDD|441138
# 12    Genome405_k127_107645_1  gnl|CDD|441138
# 13    Genome364_k127_154890_1  gnl|CDD|441138
# 14    Genome403_k127_249621_1  gnl|CDD|441138
# 15    Genome413_k127_255610_1  gnl|CDD|441138
# 16    Genome499_k127_471593_1  gnl|CDD|441138
# 17      Genome514_k127_4285_1  gnl|CDD|441138
# 18  Genome18_S1Ck127_217968_1  gnl|CDD|441138
# 19    Genome291_k127_419550_1  gnl|CDD|441138
# 20    Genome350_k127_213661_1  gnl|CDD|441138
# 21      Genome444_k127_2949_1  gnl|CDD|441138
# 22    Genome544_k127_833201_1  gnl|CDD|441138
# 23    Genome545_k127_344480_1  gnl|CDD|441138
# 24    Genome382_k127_146993_1  gnl|CDD|441138
# 25    Genome220_k127_244806_1  gnl|CDD|441138
# 26     Genome470_k127_43488_1  gnl|CDD|441138
#
#                                    CDD Hit Definition  Bit Score  \
# 0   TIGR02416, Carbon_monoxide_dehydrogenase_large...    548.895
# 1   COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    362.073
# 2   COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    573.548
# 3   TIGR02416, Carbon_monoxide_dehydrogenase_large...    540.036
# 4   TIGR02416, Carbon_monoxide_dehydrogenase_large...    540.806
# 5   TIGR02416, Carbon_monoxide_dehydrogenase_large...    596.660
# 6   TIGR02416, Carbon_monoxide_dehydrogenase_large...    597.045
# 7   TIGR02416, Carbon_monoxide_dehydrogenase_large...    597.045
# 8   TIGR02416, Carbon_monoxide_dehydrogenase_large...    596.660
# 9   COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    398.667
# 10  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    532.717
# 11  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    244.588
# 12  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    436.032
# 13  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    289.271
# 14  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    323.553
# 15  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    432.565
# 16  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    434.106
# 17  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    432.180
# 18  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    540.036
# 19  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    542.732
# 20  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    519.620
# 21  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    490.345
# 22  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    547.740
# 23  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    542.732
# 24  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    486.878
# 25  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    524.628
# 26  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    526.554
#
#           E-value                                       source_file
# 0    0.000000e+00        uncultured_Acidovorax_sp._ERS6627271.fasta
# 1   2.557480e-117        uncultured_Aureimonas_sp._ERS6626915.fasta
# 2    0.000000e+00        uncultured_Aureimonas_sp._ERS6627306.fasta
# 3    0.000000e+00         uncultured_Comamonas_sp._ERS6626630.fasta
# 4    0.000000e+00         uncultured_Comamonas_sp._ERS6627283.fasta
# 5    0.000000e+00       uncultured_Deinococcus_sp._ERS6626797.fasta
# 6    0.000000e+00       uncultured_Deinococcus_sp._ERS6626820.fasta
# 7    0.000000e+00       uncultured_Deinococcus_sp._ERS6626837.fasta
# 8    0.000000e+00       uncultured_Deinococcus_sp._ERS6627293.fasta
# 9   1.239670e-128       uncultured_Deinococcus_sp._ERS6627335.fasta
# 10  8.352100e-180  uncultured_Methylobacterium_sp._ERS6627288.fasta
# 11   1.275460e-74    uncultured_Microbacterium_sp._ERS6626906.fasta
# 12  2.577570e-142    uncultured_Microbacterium_sp._ERS6626964.fasta
# 13   1.275720e-89  uncultured_Mucilaginibacter_sp._ERS6626923.fasta
# 14  2.364320e-101  uncultured_Mucilaginibacter_sp._ERS6626962.fasta
# 15  7.678530e-142  uncultured_Mucilaginibacter_sp._ERS6626972.fasta
# 16  2.264310e-142  uncultured_Mucilaginibacter_sp._ERS6627275.fasta
# 17  1.270290e-141  uncultured_Mucilaginibacter_sp._ERS6627290.fasta
# 18   0.000000e+00   uncultured_Pseudacidovorax_sp._ERS6626577.fasta
# 19   0.000000e+00   uncultured_Pseudacidovorax_sp._ERS6626850.fasta
# 20  9.960680e-175   uncultured_Pseudacidovorax_sp._ERS6626909.fasta
# 21  4.101740e-164   uncultured_Pseudacidovorax_sp._ERS6627003.fasta
# 22   0.000000e+00   uncultured_Pseudacidovorax_sp._ERS6627320.fasta
# 23   0.000000e+00   uncultured_Pseudacidovorax_sp._ERS6627321.fasta
# 24  6.480520e-162  uncultured_Pseudorhodoferax_sp._ERS6626941.fasta
# 25  1.377220e-176        uncultured_Variovorax_sp._ERS6626779.fasta
# 26  2.479540e-177        uncultured_Variovorax_sp._ERS6627246.fasta

# %%
# Adding column 'qseqid' from the updated sequence ID coulmn in the dataframe
best_cds2['qseqid'] = best_cds2['Sequence Header'].apply(lambda x: x[:-2])
best_cds2
# Out:
#                                            Fasta File  \
# 0   uncultured_Acidovorax_sp._ERS6627271_filtered.faa
# 1   uncultured_Aureimonas_sp._ERS6626915_filtered.faa
# 2   uncultured_Aureimonas_sp._ERS6627306_filtered.faa
# 3    uncultured_Comamonas_sp._ERS6626630_filtered.faa
# 4    uncultured_Comamonas_sp._ERS6627283_filtered.faa
# 5   uncultured_Deinococcus_sp._ERS6626797_filtered...
# 6   uncultured_Deinococcus_sp._ERS6626820_filtered...
# 7   uncultured_Deinococcus_sp._ERS6626837_filtered...
# 8   uncultured_Deinococcus_sp._ERS6627293_filtered...
# 9   uncultured_Deinococcus_sp._ERS6627335_filtered...
# 10  uncultured_Methylobacterium_sp._ERS6627288_fil...
# 11  uncultured_Microbacterium_sp._ERS6626906_filte...
# 12  uncultured_Microbacterium_sp._ERS6626964_filte...
# 13  uncultured_Mucilaginibacter_sp._ERS6626923_fil...
# 14  uncultured_Mucilaginibacter_sp._ERS6626962_fil...
# 15  uncultured_Mucilaginibacter_sp._ERS6626972_fil...
# 16  uncultured_Mucilaginibacter_sp._ERS6627275_fil...
# 17  uncultured_Mucilaginibacter_sp._ERS6627290_fil...
# 18  uncultured_Pseudacidovorax_sp._ERS6626577_filt...
# 19  uncultured_Pseudacidovorax_sp._ERS6626850_filt...
# 20  uncultured_Pseudacidovorax_sp._ERS6626909_filt...
# 21  uncultured_Pseudacidovorax_sp._ERS6627003_filt...
# 22  uncultured_Pseudacidovorax_sp._ERS6627320_filt...
# 23  uncultured_Pseudacidovorax_sp._ERS6627321_filt...
# 24  uncultured_Pseudorhodoferax_sp._ERS6626941_fil...
# 25  uncultured_Variovorax_sp._ERS6626779_filtered.faa
# 26  uncultured_Variovorax_sp._ERS6627246_filtered.faa
#
#               Sequence Header      CDD Hit ID  \
# 0     Genome495_k127_317059_1  gnl|CDD|131469
# 1     Genome356_k127_498042_1  gnl|CDD|441138
# 2      Genome530_k127_16854_1  gnl|CDD|441138
# 3    Genome71_S1Ck127_18694_1  gnl|CDD|131469
# 4      Genome507_k127_91973_1  gnl|CDD|131469
# 5      Genome238_k127_17753_1  gnl|CDD|131469
# 6     Genome261_k127_146972_1  gnl|CDD|131469
# 7      Genome278_k127_93298_1  gnl|CDD|131469
# 8     Genome517_k127_348199_1  gnl|CDD|131469
# 9     Genome559_k127_243715_1  gnl|CDD|441138
# 10    Genome512_k127_160927_1  gnl|CDD|441138
# 11     Genome347_k127_84820_1  gnl|CDD|441138
# 12    Genome405_k127_107645_1  gnl|CDD|441138
# 13    Genome364_k127_154890_1  gnl|CDD|441138
# 14    Genome403_k127_249621_1  gnl|CDD|441138
# 15    Genome413_k127_255610_1  gnl|CDD|441138
# 16    Genome499_k127_471593_1  gnl|CDD|441138
# 17      Genome514_k127_4285_1  gnl|CDD|441138
# 18  Genome18_S1Ck127_217968_1  gnl|CDD|441138
# 19    Genome291_k127_419550_1  gnl|CDD|441138
# 20    Genome350_k127_213661_1  gnl|CDD|441138
# 21      Genome444_k127_2949_1  gnl|CDD|441138
# 22    Genome544_k127_833201_1  gnl|CDD|441138
# 23    Genome545_k127_344480_1  gnl|CDD|441138
# 24    Genome382_k127_146993_1  gnl|CDD|441138
# 25    Genome220_k127_244806_1  gnl|CDD|441138
# 26     Genome470_k127_43488_1  gnl|CDD|441138
#
#                                    CDD Hit Definition  Bit Score  \
# 0   TIGR02416, Carbon_monoxide_dehydrogenase_large...    548.895
# 1   COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    362.073
# 2   COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    573.548
# 3   TIGR02416, Carbon_monoxide_dehydrogenase_large...    540.036
# 4   TIGR02416, Carbon_monoxide_dehydrogenase_large...    540.806
# 5   TIGR02416, Carbon_monoxide_dehydrogenase_large...    596.660
# 6   TIGR02416, Carbon_monoxide_dehydrogenase_large...    597.045
# 7   TIGR02416, Carbon_monoxide_dehydrogenase_large...    597.045
# 8   TIGR02416, Carbon_monoxide_dehydrogenase_large...    596.660
# 9   COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    398.667
# 10  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    532.717
# 11  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    244.588
# 12  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    436.032
# 13  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    289.271
# 14  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    323.553
# 15  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    432.565
# 16  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    434.106
# 17  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    432.180
# 18  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    540.036
# 19  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    542.732
# 20  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    519.620
# 21  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    490.345
# 22  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    547.740
# 23  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    542.732
# 24  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    486.878
# 25  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    524.628
# 26  COG1529, CoxL, Aldehyde, CO or xanthine dehydr...    526.554
#
#           E-value                                       source_file  \
# 0    0.000000e+00        uncultured_Acidovorax_sp._ERS6627271.fasta
# 1   2.557480e-117        uncultured_Aureimonas_sp._ERS6626915.fasta
# 2    0.000000e+00        uncultured_Aureimonas_sp._ERS6627306.fasta
# 3    0.000000e+00         uncultured_Comamonas_sp._ERS6626630.fasta
# 4    0.000000e+00         uncultured_Comamonas_sp._ERS6627283.fasta
# 5    0.000000e+00       uncultured_Deinococcus_sp._ERS6626797.fasta
# 6    0.000000e+00       uncultured_Deinococcus_sp._ERS6626820.fasta
# 7    0.000000e+00       uncultured_Deinococcus_sp._ERS6626837.fasta
# 8    0.000000e+00       uncultured_Deinococcus_sp._ERS6627293.fasta
# 9   1.239670e-128       uncultured_Deinococcus_sp._ERS6627335.fasta
# 10  8.352100e-180  uncultured_Methylobacterium_sp._ERS6627288.fasta
# 11   1.275460e-74    uncultured_Microbacterium_sp._ERS6626906.fasta
# 12  2.577570e-142    uncultured_Microbacterium_sp._ERS6626964.fasta
# 13   1.275720e-89  uncultured_Mucilaginibacter_sp._ERS6626923.fasta
# 14  2.364320e-101  uncultured_Mucilaginibacter_sp._ERS6626962.fasta
# 15  7.678530e-142  uncultured_Mucilaginibacter_sp._ERS6626972.fasta
# 16  2.264310e-142  uncultured_Mucilaginibacter_sp._ERS6627275.fasta
# 17  1.270290e-141  uncultured_Mucilaginibacter_sp._ERS6627290.fasta
# 18   0.000000e+00   uncultured_Pseudacidovorax_sp._ERS6626577.fasta
# 19   0.000000e+00   uncultured_Pseudacidovorax_sp._ERS6626850.fasta
# 20  9.960680e-175   uncultured_Pseudacidovorax_sp._ERS6626909.fasta
# 21  4.101740e-164   uncultured_Pseudacidovorax_sp._ERS6627003.fasta
# 22   0.000000e+00   uncultured_Pseudacidovorax_sp._ERS6627320.fasta
# 23   0.000000e+00   uncultured_Pseudacidovorax_sp._ERS6627321.fasta
# 24  6.480520e-162  uncultured_Pseudorhodoferax_sp._ERS6626941.fasta
# 25  1.377220e-176        uncultured_Variovorax_sp._ERS6626779.fasta
# 26  2.479540e-177        uncultured_Variovorax_sp._ERS6627246.fasta
#
#                      qseqid
# 0     Genome495_k127_317059
# 1     Genome356_k127_498042
# 2      Genome530_k127_16854
# 3    Genome71_S1Ck127_18694
# 4      Genome507_k127_91973
# 5      Genome238_k127_17753
# 6     Genome261_k127_146972
# 7      Genome278_k127_93298
# 8     Genome517_k127_348199
# 9     Genome559_k127_243715
# 10    Genome512_k127_160927
# 11     Genome347_k127_84820
# 12    Genome405_k127_107645
# 13    Genome364_k127_154890
# 14    Genome403_k127_249621
# 15    Genome413_k127_255610
# 16    Genome499_k127_471593
# 17      Genome514_k127_4285
# 18  Genome18_S1Ck127_217968
# 19    Genome291_k127_419550
# 20    Genome350_k127_213661
# 21      Genome444_k127_2949
# 22    Genome544_k127_833201
# 23    Genome545_k127_344480
# 24    Genome382_k127_146993
# 25    Genome220_k127_244806
# 26     Genome470_k127_43488

# %%
# Create the destination folder if it doesn't exist
if not os.path.exists(coxl2_genes):
    os.makedirs(coxl2_genes)

# Get the list of files in the source folder
files_in_source_folder = os.listdir(motif_2_fasta_path)

# Iterate over each file in the source folder
for file in files_in_source_folder:
    if file in best_cds2['source_file'].values:
        # Move the file if it is in the DataFrame
        shutil.move(os.path.join(motif_2_fasta_path, file), os.path.join(coxl2_genes, file))

print("Files have been filtered and transferred successfully.")
# Out:
# Files have been filtered and transferred successfully.

# %%
parent_directory = os.path.dirname(coxl2_genes)
duplicates_folder = os.path.join(parent_directory, 'gene_duplicates')

# Create the duplicates folder if it doesn't exist
os.makedirs(duplicates_folder, exist_ok=True)

# Assuming best_cds2 is your DataFrame
# Extract sequences to extract from the DataFrame
sequences_to_extract = {}
for index, row in best_cds2.iterrows():
    file_name = row["source_file"].strip()
    sequence_id = row["qseqid"].strip()
    
    if file_name not in sequences_to_extract:
        sequences_to_extract[file_name] = set()
    
    sequences_to_extract[file_name].add(sequence_id)  # Store ID

# Process each FASTA file
for file_name, sequence_ids in sequences_to_extract.items():
    input_file_path = os.path.join(coxl2_genes, file_name)
    output_file_path = os.path.join(coxl2_genes, f"{os.path.splitext(file_name)[0]}.fasta")
    duplicates_file_path = os.path.join(duplicates_folder, f"{os.path.splitext(file_name)[0]}_duplicates.txt")

    if not os.path.exists(input_file_path):
        print(f"File not found: {input_file_path}")
        continue

    extracted_records = []
    seen_sequences = set()
    duplicate_headers = []

    for record in SeqIO.parse(input_file_path, "fasta"):
        if record.id in sequence_ids:
            if str(record.seq) in seen_sequences:
                duplicate_headers.append(record.id)
            else:
                seen_sequences.add(str(record.seq))
                extracted_records.append(record)

    if extracted_records:
        with open(output_file_path, "w") as output_f:
            SeqIO.write(extracted_records, output_f, "fasta")
        print(f"Extracted sequences saved to: {output_file_path}")
    
    if duplicate_headers:
        with open(duplicates_file_path, "w") as duplicates_f:
            duplicates_f.write(f"Duplicate headers in {file_name}:\n")
            for header in duplicate_headers:
                duplicates_f.write(f"{header}\n")
        print(f"Duplicate headers saved to: {duplicates_file_path}")

print("Sequence extraction completed.")
# Out:
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Acidovorax_sp._ERS6627271.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Aureimonas_sp._ERS6626915.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Aureimonas_sp._ERS6627306.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Comamonas_sp._ERS6626630.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Comamonas_sp._ERS6627283.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Deinococcus_sp._ERS6626797.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Deinococcus_sp._ERS6626820.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Deinococcus_sp._ERS6626837.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Deinococcus_sp._ERS6627293.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Deinococcus_sp._ERS6627335.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Methylobacterium_sp._ERS6627288.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Microbacterium_sp._ERS6626906.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Microbacterium_sp._ERS6626964.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Mucilaginibacter_sp._ERS6626923.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Mucilaginibacter_sp._ERS6626962.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Mucilaginibacter_sp._ERS6626972.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Mucilaginibacter_sp._ERS6627275.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Mucilaginibacter_sp._ERS6627290.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Pseudacidovorax_sp._ERS6626577.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Pseudacidovorax_sp._ERS6626850.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Pseudacidovorax_sp._ERS6626909.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Pseudacidovorax_sp._ERS6627003.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Pseudacidovorax_sp._ERS6627320.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Pseudacidovorax_sp._ERS6627321.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Pseudorhodoferax_sp._ERS6626941.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Variovorax_sp._ERS6626779.fasta
# Extracted sequences saved to: Coxl2_Results/Genes\uncultured_Variovorax_sp._ERS6627246.fasta
# Sequence extraction completed.

# %%
# Get the count of sequences in each .faa file and the total sequences
sequence_counts, total_sequences = count_sequences_in_fasta_files(coxl2_genes)

# Print the results
for file_name, count in sequence_counts.items():
    print(f"{file_name}: {count} sequences")

print(f"Total sequences from all files: {total_sequences}")
# Out:
# uncultured_Acidovorax_sp._ERS6627271.fasta: 2 sequences
# uncultured_Aureimonas_sp._ERS6626915.fasta: 2 sequences
# uncultured_Aureimonas_sp._ERS6627306.fasta: 2 sequences
# uncultured_Comamonas_sp._ERS6626630.fasta: 2 sequences
# uncultured_Comamonas_sp._ERS6627283.fasta: 2 sequences
# uncultured_Deinococcus_sp._ERS6626797.fasta: 1 sequences
# uncultured_Deinococcus_sp._ERS6626820.fasta: 1 sequences
# uncultured_Deinococcus_sp._ERS6626837.fasta: 1 sequences
# uncultured_Deinococcus_sp._ERS6627293.fasta: 1 sequences
# uncultured_Deinococcus_sp._ERS6627335.fasta: 2 sequences
# uncultured_Methylobacterium_sp._ERS6627288.fasta: 2 sequences
# uncultured_Microbacterium_sp._ERS6626906.fasta: 2 sequences
# uncultured_Microbacterium_sp._ERS6626964.fasta: 2 sequences
# uncultured_Mucilaginibacter_sp._ERS6626923.fasta: 2 sequences
# uncultured_Mucilaginibacter_sp._ERS6626962.fasta: 2 sequences
# uncultured_Mucilaginibacter_sp._ERS6626972.fasta: 2 sequences
# uncultured_Mucilaginibacter_sp._ERS6627275.fasta: 2 sequences
# uncultured_Mucilaginibacter_sp._ERS6627290.fasta: 2 sequences
# uncultured_Pseudacidovorax_sp._ERS6626577.fasta: 1 sequences
# uncultured_Pseudacidovorax_sp._ERS6626850.fasta: 1 sequences
# uncultured_Pseudacidovorax_sp._ERS6626909.fasta: 2 sequences
# uncultured_Pseudacidovorax_sp._ERS6627003.fasta: 1 sequences
# uncultured_Pseudacidovorax_sp._ERS6627320.fasta: 1 sequences
# uncultured_Pseudacidovorax_sp._ERS6627321.fasta: 1 sequences
# uncultured_Pseudorhodoferax_sp._ERS6626941.fasta: 2 sequences
# uncultured_Variovorax_sp._ERS6626779.fasta: 2 sequences
# uncultured_Variovorax_sp._ERS6627246.fasta: 2 sequences
# Total sequences from all files: 45

# %%
# List to store dataframes
dfs = []

# Iterate over each file in the directory
for filename in os.listdir(cross_ver):
    if filename.endswith('.csv'):
        # Read the CSV file
        df = pd.read_csv(os.path.join(cross_ver, filename))
        
        # Add 'MAG' and 'query_index' columns
        if filename.endswith('_1.csv'):
            mag_value = filename[:-6]  
            query_index_value = 'Query 2'
        else:
            mag_value = filename[:-4]  
            query_index_value = 'Query 1'
        
        df['MAG'] = mag_value
        df['query_index'] = query_index_value
        
        # Append the dataframe to the list
        dfs.append(df)

# Concatenate all dataframes
result_df = pd.concat(dfs, ignore_index=True)

# Save the concatenated dataframe to a new CSV file
result_df.to_csv('open_blast.csv', index=False)

print("All files have been concatenated into 'concatenated_file.csv'.")
# Out:
# All files have been concatenated into 'concatenated_file.csv'.

# %%
open_blast = open_file('open_blast.csv')
open_blast
# Out:
#                                             Description  \
# 0     xanthine dehydrogenase family protein molybdop...
# 1     xanthine dehydrogenase family protein molybdop...
# 2     xanthine dehydrogenase family protein molybdop...
# 3     xanthine dehydrogenase family protein molybdop...
# 4     xanthine dehydrogenase family protein molybdop...
# ...                                                 ...
# 4495  xanthine dehydrogenase family protein molybdop...
# 4496  MULTISPECIES: xanthine dehydrogenase family pr...
# 4497  MULTISPECIES: xanthine dehydrogenase family pr...
# 4498  xanthine dehydrogenase family protein molybdop...
# 4499  xanthine dehydrogenase family protein molybdop...
#
#                 Scientific Name  Max Score  Total Score Query Cover  E value  \
# 0     uncultured Acidovorax sp.       1548         1548        100%      0.0
# 1          Acidovorax temperans       1545         1545        100%      0.0
# 2          Acidovorax temperans       1545         1545        100%      0.0
# 3          Acidovorax temperans       1545         1545        100%      0.0
# 4           Acidovorax sp. IB03       1544         1544        100%      0.0
# ...                         ...        ...          ...         ...      ...
# 4495       Variovorax paradoxus       1342         1342        100%      0.0
# 4496                 Variovorax       1341         1341        100%      0.0
# 4497                 Variovorax       1341         1341        100%      0.0
# 4498       Variovorax paradoxus       1341         1341        100%      0.0
# 4499       Variovorax sp. S12S4       1341         1341        100%      0.0
#
#       Per. ident  Acc. Len                                        Accession    \
# 0         100.00       795  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 1          99.62       795  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 2          99.36       795  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 3          99.62       795  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 4          99.49       795  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# ...          ...       ...                                                ...
# 4495       91.00       776  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 4496       90.85       769  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 4497       91.26       776  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 4498       91.13       776  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 4499       91.13       776  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
#
#                                        MAG query_index
# 0     uncultured_Acidovorax_sp._ERS6627271     Query 1
# 1     uncultured_Acidovorax_sp._ERS6627271     Query 1
# 2     uncultured_Acidovorax_sp._ERS6627271     Query 1
# 3     uncultured_Acidovorax_sp._ERS6627271     Query 1
# 4     uncultured_Acidovorax_sp._ERS6627271     Query 1
# ...                                    ...         ...
# 4495  uncultured_Variovorax_sp._ERS6627246     Query 2
# 4496  uncultured_Variovorax_sp._ERS6627246     Query 2
# 4497  uncultured_Variovorax_sp._ERS6627246     Query 2
# 4498  uncultured_Variovorax_sp._ERS6627246     Query 2
# 4499  uncultured_Variovorax_sp._ERS6627246     Query 2
#
# [4500 rows x 11 columns]

# %%
# Fetch the best hits for every sequence
open_blast = open_blast.sort_values(by=['MAG', 'query_index', 'E value', 'Per. ident'], ascending=[True, True, True, False]).drop_duplicates(subset=['MAG', 'query_index']).reset_index(drop=True)
open_blast
# Out:
#                                           Description  \
# 0   xanthine dehydrogenase family protein molybdop...
# 1   xanthine dehydrogenase family protein molybdop...
# 2   xanthine dehydrogenase family protein molybdop...
# 3   xanthine dehydrogenase family protein molybdop...
# 4   xanthine dehydrogenase family protein molybdop...
# 5   xanthine dehydrogenase family protein molybdop...
# 6   xanthine dehydrogenase family protein molybdop...
# 7   xanthine dehydrogenase family protein molybdop...
# 8   xanthine dehydrogenase family protein molybdop...
# 9   xanthine dehydrogenase family protein molybdop...
# 10  xanthine dehydrogenase family protein molybdop...
# 11  xanthine dehydrogenase family protein molybdop...
# 12  xanthine dehydrogenase family protein molybdop...
# 13  xanthine dehydrogenase family protein molybdop...
# 14  xanthine dehydrogenase family protein molybdop...
# 15  xanthine dehydrogenase family protein molybdop...
# 16  xanthine dehydrogenase family protein molybdop...
# 17  xanthine dehydrogenase family protein molybdop...
# 18  xanthine dehydrogenase family protein molybdop...
# 19  MULTISPECIES: xanthine dehydrogenase family pr...
# 20  molybdopterin-dependent oxidoreductase [Microb...
# 21  molybdopterin-dependent oxidoreductase [Microb...
# 22  xanthine dehydrogenase family protein molybdop...
# 23  xanthine dehydrogenase family protein molybdop...
# 24  xanthine dehydrogenase family protein molybdop...
# 25  xanthine dehydrogenase family protein molybdop...
# 26  xanthine dehydrogenase family protein molybdop...
# 27  xanthine dehydrogenase family protein molybdop...
# 28  xanthine dehydrogenase family protein molybdop...
# 29  xanthine dehydrogenase family protein molybdop...
# 30  xanthine dehydrogenase family protein molybdop...
# 31  xanthine dehydrogenase family protein molybdop...
# 32  xanthine dehydrogenase family protein molybdop...
# 33  xanthine dehydrogenase family protein molybdop...
# 34  xanthine dehydrogenase family protein molybdop...
# 35  xanthine dehydrogenase family protein molybdop...
# 36  xanthine dehydrogenase family protein molybdop...
# 37  xanthine dehydrogenase family protein molybdop...
# 38  xanthine dehydrogenase family protein molybdop...
# 39  xanthine dehydrogenase family protein molybdop...
# 40  xanthine dehydrogenase family protein molybdop...
# 41  xanthine dehydrogenase family protein molybdop...
# 42  xanthine dehydrogenase family protein molybdop...
# 43  xanthine dehydrogenase family protein molybdop...
# 44  xanthine dehydrogenase family protein molybdop...
#
#                      Scientific Name  Max Score  Total Score Query Cover  \
# 0          uncultured Acidovorax sp.       1548         1548        100%
# 1          uncultured Acidovorax sp.       1545         1545        100%
# 2   Bosea sp. (in: a-proteobacteria)        996          996        100%
# 3   Bosea sp. (in: a-proteobacteria)        998          998        100%
# 4          uncultured Aureimonas sp.       1531         1531        100%
# 5          uncultured Aureimonas sp.       1523         1523        100%
# 6                Delftia acidovorans       1521         1521        100%
# 7                Delftia acidovorans       1515         1515        100%
# 8                   Delftia sp. DT-2       1507         1507        100%
# 9                   Delftia sp. DT-2       1502         1502        100%
# 10             Deinococcus gobiensis       1504         1504        100%
# 11             Deinococcus gobiensis       1502         1502        100%
# 12        uncultured Deinococcus sp.       1511         1511        100%
# 13        uncultured Deinococcus sp.       1504         1504        100%
# 14        uncultured Deinococcus sp.       1388         1388        100%
# 15        uncultured Deinococcus sp.       1386         1386        100%
# 16   uncultured Methylobacterium sp.       1355         1355        100%
# 17   uncultured Methylobacterium sp.       1343         1343        100%
# 18   uncultured Methylobacterium sp.        555          555        100%
# 19                  Methylobacterium        545          545        100%
# 20      Microbacterium hydrothermale       1212         1212        100%
# 21      Microbacterium hydrothermale       1256         1256        100%
# 22      Mucilaginibacter sp. CSA2-8R        983          983        100%
# 23      Mucilaginibacter sp. CSA2-8R        966          966        100%
# 24      Mucilaginibacter sp. CSA2-8R       1145         1145        100%
# 25      Mucilaginibacter sp. CSA2-8R        920          920        100%
# 26      Mucilaginibacter sp. CSA2-8R       1348         1348        100%
# 27      Mucilaginibacter sp. CSA2-8R       1311         1311        100%
# 28      Mucilaginibacter sp. CSA2-8R       1309         1309        100%
# 29      Mucilaginibacter sp. CSA2-8R       1251         1251        100%
# 30      Mucilaginibacter sp. CSA2-8R       1305         1305        100%
# 31      Mucilaginibacter sp. CSA2-8R       1077         1077        100%
# 32       Pseudacidovorax intermedius       1537         1537        100%
# 33    uncultured Pseudacidovorax sp.       1544         1544        100%
# 34       Pseudacidovorax intermedius       1367         1367        100%
# 35       Pseudacidovorax intermedius       1370         1370        100%
# 36    uncultured Pseudacidovorax sp.       1403         1403        100%
# 37    uncultured Pseudacidovorax sp.       1545         1545        100%
# 38    uncultured Pseudacidovorax sp.       1544         1544        100%
# 39       Pseudorhodoferax aquiterrae       1348         1348        100%
# 40       Pseudorhodoferax aquiterrae       1337         1337        100%
# 41         uncultured Variovorax sp.       1458         1458        100%
# 42         uncultured Variovorax sp.       1467         1467        100%
# 43         uncultured Variovorax sp.       1445         1445        100%
# 44         uncultured Variovorax sp.       1454         1454        100%
#
#     E value  Per. ident  Acc. Len  \
# 0       0.0      100.00       795
# 1       0.0      100.00       795
# 2       0.0       96.78       769
# 3       0.0       96.79       769
# 4       0.0      100.00       784
# 5       0.0      100.00       784
# 6       0.0       99.87       796
# 7       0.0       99.87       796
# 8       0.0      100.00       796
# 9       0.0      100.00       796
# 10      0.0       99.87       796
# 11      0.0       99.87       796
# 12      0.0      100.00       796
# 13      0.0      100.00       796
# 14      0.0      100.00       744
# 15      0.0      100.00       744
# 16      0.0      100.00       771
# 17      0.0      100.00       771
# 18      0.0       97.98       771
# 19      0.0       97.95       771
# 20      0.0       95.77      1024
# 21      0.0       95.97      1024
# 22      0.0       96.11       721
# 23      0.0       96.03       721
# 24      0.0       96.10       721
# 25      0.0       95.62       721
# 26      0.0       97.29       721
# 27      0.0       97.26       721
# 28      0.0       97.15       721
# 29      0.0       97.11       721
# 30      0.0       96.43       721
# 31      0.0       97.04       721
# 32      0.0       99.36       813
# 33      0.0      100.00       813
# 34      0.0       99.87       784
# 35      0.0       99.87       784
# 36      0.0      100.00       813
# 37      0.0      100.00       813
# 38      0.0      100.00       813
# 39      0.0       93.35       774
# 40      0.0       93.31       774
# 41      0.0      100.00       776
# 42      0.0      100.00       776
# 43      0.0       99.48       776
# 44      0.0       99.48       776
#
#                                           Accession    \
# 0   =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 1   =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 2   =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 3   =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 4   =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 5   =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 6   =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 7   =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 8   =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 9   =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 10  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 11  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 12  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 13  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 14  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 15  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 16  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 17  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 18  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 19  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 20  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 21  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 22  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 23  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 24  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 25  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 26  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 27  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 28  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 29  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 30  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 31  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 32  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 33  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 34  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 35  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 36  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 37  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 38  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 39  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 40  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 41  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 42  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 43  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 44  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
#
#                                            MAG query_index
# 0         uncultured_Acidovorax_sp._ERS6627271     Query 1
# 1         uncultured_Acidovorax_sp._ERS6627271     Query 2
# 2         uncultured_Aureimonas_sp._ERS6626915     Query 1
# 3         uncultured_Aureimonas_sp._ERS6626915     Query 2
# 4         uncultured_Aureimonas_sp._ERS6627306     Query 1
# 5         uncultured_Aureimonas_sp._ERS6627306     Query 2
# 6          uncultured_Comamonas_sp._ERS6626630     Query 1
# 7          uncultured_Comamonas_sp._ERS6626630     Query 2
# 8          uncultured_Comamonas_sp._ERS6627283     Query 1
# 9          uncultured_Comamonas_sp._ERS6627283     Query 2
# 10       uncultured_Deinococcus_sp._ERS6626797     Query 1
# 11       uncultured_Deinococcus_sp._ERS6626820     Query 1
# 12       uncultured_Deinococcus_sp._ERS6626837     Query 1
# 13       uncultured_Deinococcus_sp._ERS6627293     Query 1
# 14       uncultured_Deinococcus_sp._ERS6627335     Query 1
# 15       uncultured_Deinococcus_sp._ERS6627335     Query 2
# 16  uncultured_Methylobacterium_sp._ERS6627288     Query 1
# 17  uncultured_Methylobacterium_sp._ERS6627288     Query 2
# 18    uncultured_Microbacterium_sp._ERS6626906     Query 1
# 19    uncultured_Microbacterium_sp._ERS6626906     Query 2
# 20    uncultured_Microbacterium_sp._ERS6626964     Query 1
# 21    uncultured_Microbacterium_sp._ERS6626964     Query 2
# 22  uncultured_Mucilaginibacter_sp._ERS6626923     Query 1
# 23  uncultured_Mucilaginibacter_sp._ERS6626923     Query 2
# 24  uncultured_Mucilaginibacter_sp._ERS6626962     Query 1
# 25  uncultured_Mucilaginibacter_sp._ERS6626962     Query 2
# 26  uncultured_Mucilaginibacter_sp._ERS6626972     Query 1
# 27  uncultured_Mucilaginibacter_sp._ERS6626972     Query 2
# 28  uncultured_Mucilaginibacter_sp._ERS6627275     Query 1
# 29  uncultured_Mucilaginibacter_sp._ERS6627275     Query 2
# 30  uncultured_Mucilaginibacter_sp._ERS6627290     Query 1
# 31  uncultured_Mucilaginibacter_sp._ERS6627290     Query 2
# 32   uncultured_Pseudacidovorax_sp._ERS6626577     Query 1
# 33   uncultured_Pseudacidovorax_sp._ERS6626850     Query 1
# 34   uncultured_Pseudacidovorax_sp._ERS6626909     Query 1
# 35   uncultured_Pseudacidovorax_sp._ERS6626909     Query 2
# 36   uncultured_Pseudacidovorax_sp._ERS6627003     Query 1
# 37   uncultured_Pseudacidovorax_sp._ERS6627320     Query 1
# 38   uncultured_Pseudacidovorax_sp._ERS6627321     Query 1
# 39  uncultured_Pseudorhodoferax_sp._ERS6626941     Query 1
# 40  uncultured_Pseudorhodoferax_sp._ERS6626941     Query 2
# 41        uncultured_Variovorax_sp._ERS6626779     Query 1
# 42        uncultured_Variovorax_sp._ERS6626779     Query 2
# 43        uncultured_Variovorax_sp._ERS6627246     Query 1
# 44        uncultured_Variovorax_sp._ERS6627246     Query 2

# %%
open_blast['Description'].unique()
# Out:
# array(['xanthine dehydrogenase family protein molybdopterin-binding subunit [uncultured Acidovorax sp.]',
#        'xanthine dehydrogenase family protein molybdopterin-binding subunit [Bosea sp. (in: a-proteobacteria)]',
#        'xanthine dehydrogenase family protein molybdopterin-binding subunit [uncultured Aureimonas sp.]',
#        'xanthine dehydrogenase family protein molybdopterin-binding subunit [Delftia acidovorans]',
#        'xanthine dehydrogenase family protein molybdopterin-binding subunit [Delftia sp. DT-2]',
#        'xanthine dehydrogenase family protein molybdopterin-binding subunit [Deinococcus gobiensis]',
#        'xanthine dehydrogenase family protein molybdopterin-binding subunit [uncultured Deinococcus sp.]',
#        'xanthine dehydrogenase family protein molybdopterin-binding subunit [uncultured Methylobacterium sp.]',
#        'MULTISPECIES: xanthine dehydrogenase family protein molybdopterin-binding subunit [Methylobacterium]',
#        'molybdopterin-dependent oxidoreductase [Microbacterium hydrothermale]',
#        'xanthine dehydrogenase family protein molybdopterin-binding subunit [Mucilaginibacter sp. CSA2-8R]',
#        'xanthine dehydrogenase family protein molybdopterin-binding subunit [Pseudacidovorax intermedius]',
#        'xanthine dehydrogenase family protein molybdopterin-binding subunit [uncultured Pseudacidovorax sp.]',
#        'xanthine dehydrogenase family protein molybdopterin-binding subunit [Pseudorhodoferax aquiterrae]',
#        'xanthine dehydrogenase family protein molybdopterin-binding subunit [uncultured Variovorax sp.]'],
#       dtype=object)

# %%
open_blast[open_blast['Description'] == 'molybdopterin-dependent oxidoreductase [Microbacterium hydrothermale]']
# Out:
#                                           Description  \
# 20  molybdopterin-dependent oxidoreductase [Microb...
# 21  molybdopterin-dependent oxidoreductase [Microb...
#
#                  Scientific Name  Max Score  Total Score Query Cover  E value  \
# 20  Microbacterium hydrothermale       1212         1212        100%      0.0
# 21  Microbacterium hydrothermale       1256         1256        100%      0.0
#
#     Per. ident  Acc. Len                                        Accession    \
# 20       95.77      1024  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
# 21       95.97      1024  =HYPERLINK("https://www.ncbi.nlm.nih.gov/prote...
#
#                                          MAG query_index
# 20  uncultured_Microbacterium_sp._ERS6626964     Query 1
# 21  uncultured_Microbacterium_sp._ERS6626964     Query 2

# %% [markdown]
# <p style="font-family: 'Times New Roman'; font-size: 15px; text-align: justify; width: 100%;">
#     Open BLAST (open_blast) df refers to the output downloaded from the NCBI server CDD BLAST analysis.
# </p>
